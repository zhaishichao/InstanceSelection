# %% [markdown]
# # E-SEIC
# Selection of evolutionary instances with constraints for unbalanced datasets

# %%
import statistics
from utils.dataset_utils import get_distribution, k_fold_cross_validation
from instance_selection.parameter.parameter import *  # 导入参数的设定
from instance_selection.operator.init_toolbox import init_toolbox_eseic
from instance_selection.operator.metrics import calculate_accuracy
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.base import clone
import scipy.io as sio  # 从.mat文件中读取数据集
import random
import warnings
import numpy as np
import os
from openpyxl import Workbook

warnings.filterwarnings("ignore")  # 忽略警告
from utils.excel_utils import save_to_excel_2

# 数据的预处理
def data_process(dataset=None, distribution=False):
    datasetname = dataset.DATASETNAME.split('.')[0]
    mat_data = sio.loadmat(IMBALANCED_DATASET_PATH + dataset.DATASETNAME)  # 加载、划分数据集
    x = mat_data['X']
    y = mat_data['Y'][:, 0]  # mat_data['Y']得到的形状为[n,1]，通过[:,0]，得到形状[n,]
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y,
                                                        random_state=RANDOM_SEED)  # 划分数据集
    scaler = StandardScaler()  # 数据的标准化
    x_train = scaler.fit_transform(x_train)
    x_test = scaler.transform(x_test)
    unique_elements_all, classes_all, counts_all = get_distribution(y)  # 获取原始数据集分布
    unique_elements_train, classes_train, counts_train = get_distribution(y_train)  # 获取训练集分布
    unique_elements_test, classes_test, counts_test = get_distribution(y_test)  # 获取测试集分布
    weights_train = (1 / counts_train.astype(float)) / np.sum(1 / counts_train.astype(float))  # 计算每个类的权重，用于计算每个类别的权重
    if distribution:
        print(datasetname + f' distribution: {counts_all}')
        print(f'trainset distribution: {counts_train}')
        print(f'testset distribution: {counts_test}')
    model = MLPClassifier(hidden_layer_sizes=(dataset.HIDDEN_SIZE,), max_iter=dataset.MAX_ITER,
                          random_state=RANDOM_SEED, learning_rate_init=dataset.LEARNING_RATE)
    y_train_pred_proba = k_fold_cross_validation(model=clone(model), X=x_train, y=y_train, n_splits=N_SPLITS - 2,
                                                 method='soft',
                                                 random_state=RANDOM_SEED)  # 交叉验证得到软标签
    # 将概率转化为预测结果
    y_train_pred = np.argmax(y_train_pred_proba, axis=1)

    Acc1, Acc2, Acc3 = calculate_accuracy(y_train_pred, y_train, weights_train)
    constraints = [Acc1, Acc2, Acc3]

    return x_train, x_test, y_train, y_test, constraints, weights_train, clone(model)

def main(balanced_method='random'):
    ####################################种群的初始化###########################
    pop = toolbox.population(n=POPSIZE)  # 个体编码默认全为0
    pop = toolbox.init_population(pop, balanced_method=balanced_method)  # 初始化种群中的个体
    toolbox.evaluate(pop)  # 计算个体的适应度
    gmean_list = []
    mauc_list = []
    acc1_list = []
    acc2_list = []
    acc3_list = []
    for ind in pop:
        gmean_list.append(ind.gmean)
        mauc_list.append(ind.mauc)
        acc1_list.append(ind.fitness.values[0])
        acc2_list.append(ind.fitness.values[1])
        acc3_list.append(ind.fitness.values[2])
    # 求出list的中值
    median_gmean = statistics.median(gmean_list)
    median_mauc = statistics.median(mauc_list)
    median_acc1 = statistics.median(acc1_list)
    median_acc2 = statistics.median(acc2_list)
    median_acc3 = statistics.median(acc3_list)
    return median_gmean, median_mauc, median_acc1, median_acc2, median_acc3
def save_to_excel(data, save_path, filename='avg_results'):
    """
    将列表数据逐行写入Excel文件
    参数:
        data: 二维列表，每个子列表代表一行数据
        filename: 输出的Excel文件名(默认为output.xlsx)
    """
    # 创建一个新的工作簿
    wb = Workbook()
    # 获取活动的工作表
    ws = wb.active
    # 逐行写入数据
    for row in data:
        avg = row[1].tolist()
        avg.insert(0, row[0])
        std = row[2].tolist()
        std.insert(0, row[0])
        ws.append(avg)
        ws.append(std)
    # 创建 Excel 文件完整路径
    file_path = os.path.join(save_path, filename + ".xlsx")
    # 保存Excel文件
    wb.save(file_path)
    print(f"数据已成功写入到 {file_path}")

# %% [markdown]
# ## 运行

# %%
DATASETS = [Balance_Scale,Dermatology,Ecoli,Car,Pen_Digits,WallRobot,German,Wine,Nursery,Penbased,USPS,Satellite,Page_Blocks,Shuttle,Contraceptive,Automobile,Ovarian]  # 数据集名称（包含对应的参数配置）
# DATASETS = [USPS, Satellite, Page_Blocks, Shuttle, Contraceptive, Automobile, Ovarian]  # 数据集名称（包含对应的参数配置）
if __name__ == "__main__":
    save_path = 'C:/Users/zsc/Desktop/Random_Balanced/Balanced/'
    
    columns = ['Gmean', 'MAUC', 'Acc1', 'Acc2', 'Acc3']
    datasets_median_results = [[] for _ in range(len(DATASETS))]
    print("*****************算法开始执行：******************")
    for j, dataset in enumerate(DATASETS):
        x_train, x_test, y_train, y_test, constraints, weights_train, model = data_process(dataset=dataset,
                                                                                           distribution=False)
        toolbox = init_toolbox_eseic(model, x_train, y_train, weights_train, constraints, n_splits=N_SPLITS,
                                     random_seed=42)  # 初始化toolbox
        num_run = 40  # 运行次数
        median_results = [[] for _ in range(num_run)]
        for i in range(num_run):
            median_gmean, median_mauc, median_acc1, median_acc2, median_acc3 = main(balanced_method='balanced')
            median_results[i] = [median_gmean, median_mauc, median_acc1, median_acc2, median_acc3]
            print(f"第{i + 1}次执行：Gmean：{median_gmean}，mAUC：{median_gmean}")
        save_to_excel_2(save_path + dataset.DATASETNAME.split('.')[0] + '/', dataset.DATASETNAME.split('.')[0], columns,
                        median_results)
        median_result_mean = np.mean(median_results, axis=0)
        # 计算ensembles_resultsz中每一列的标准差
        median_result_std = np.std(median_results, axis=0)
        print(f'中位数（平均值）：{median_result_mean}')
        print(f'集成分类结果（标准差）：{median_result_std}')
        datasets_median_results[j] = [dataset.DATASETNAME.split('.')[0], median_result_mean, median_result_std]
    print("*****************算法执行结束！******************")
    # 写入到Excel     
    save_to_excel(datasets_median_results, save_path)
# Out:
# *****************算法开始执行：******************
# 第1次执行：Gmean：0.868912，mAUC：0.868912
# 第2次执行：Gmean：0.8707685000000001，mAUC：0.8707685000000001
# 第3次执行：Gmean：0.869557，mAUC：0.869557
# 第4次执行：Gmean：0.8813885，mAUC：0.8813885
# 第5次执行：Gmean：0.8588830000000001，mAUC：0.8588830000000001
# 第6次执行：Gmean：0.868816，mAUC：0.868816
# 第7次执行：Gmean：0.8809995，mAUC：0.8809995
# 第8次执行：Gmean：0.88159，mAUC：0.88159
# 第9次执行：Gmean：0.880638，mAUC：0.880638
# 第10次执行：Gmean：0.86417，mAUC：0.86417
# 第11次执行：Gmean：0.859474，mAUC：0.859474
# 第12次执行：Gmean：0.870569，mAUC：0.870569
# 第13次执行：Gmean：0.870569，mAUC：0.870569
# 第14次执行：Gmean：0.87511，mAUC：0.87511
# 第15次执行：Gmean：0.876279，mAUC：0.876279
# 第16次执行：Gmean：0.8707685000000001，mAUC：0.8707685000000001
# 第17次执行：Gmean：0.8695865，mAUC：0.8695865
# 第18次执行：Gmean：0.870569，mAUC：0.870569
# 第19次执行：Gmean：0.8697715，mAUC：0.8697715
# 第20次执行：Gmean：0.875272，mAUC：0.875272
# 第21次执行：Gmean：0.8697715，mAUC：0.8697715
# 第22次执行：Gmean：0.864726，mAUC：0.864726
# 第23次执行：Gmean：0.8791355，mAUC：0.8791355
# 第24次执行：Gmean：0.875272，mAUC：0.875272
# 第25次执行：Gmean：0.869001，mAUC：0.869001
# 第26次执行：Gmean：0.8748585，mAUC：0.8748585
# 第27次执行：Gmean：0.875272，mAUC：0.875272
# 第28次执行：Gmean：0.881187，mAUC：0.881187
# 第29次执行：Gmean：0.8756905，mAUC：0.8756905
# 第30次执行：Gmean：0.878744，mAUC：0.878744
# 第31次执行：Gmean：0.8744575，mAUC：0.8744575
# 第32次执行：Gmean：0.8630435，mAUC：0.8630435
# 第33次执行：Gmean：0.869557，mAUC：0.869557
# 第34次执行：Gmean：0.8809995，mAUC：0.8809995
# 第35次执行：Gmean：0.881201，mAUC：0.881201
# 第36次执行：Gmean：0.870569，mAUC：0.870569
# 第37次执行：Gmean：0.880812，mAUC：0.880812
# 第38次执行：Gmean：0.8582455，mAUC：0.8582455
# 第39次执行：Gmean：0.88159，mAUC：0.88159
# 第40次执行：Gmean：0.864081，mAUC：0.864081
# Excel 文件已保存至: C:/Users/zsc/Desktop/Random_Balanced/Balanced/Balance_Scale/Balance_Scale.xlsx
# 中位数（平均值）：[0.87254763 0.95915283 0.87365588 0.87365588 0.29464963]
# 集成分类结果（标准差）：[0.00665319 0.00361384 0.00647378 0.00647378 0.00273924]
# 第1次执行：Gmean：0.6955370000000001，mAUC：0.6955370000000001
# 第2次执行：Gmean：0.7047515，mAUC：0.7047515
# 第3次执行：Gmean：0.7198450000000001，mAUC：0.7198450000000001
# 第4次执行：Gmean：0.7096739999999999，mAUC：0.7096739999999999
# 第5次执行：Gmean：0.680318，mAUC：0.680318
# 第6次执行：Gmean：0.688635，mAUC：0.688635
# 第7次执行：Gmean：0.72385，mAUC：0.72385
# 第8次执行：Gmean：0.6986049999999999，mAUC：0.6986049999999999
# 第9次执行：Gmean：0.68682，mAUC：0.68682
# 第10次执行：Gmean：0.725691，mAUC：0.725691
# 第11次执行：Gmean：0.6885699999999999，mAUC：0.6885699999999999
# 第12次执行：Gmean：0.718329，mAUC：0.718329
# 第13次执行：Gmean：0.631699，mAUC：0.631699
# 第14次执行：Gmean：0.6904859999999999，mAUC：0.6904859999999999
# 第15次执行：Gmean：0.6897629999999999，mAUC：0.6897629999999999
# 第16次执行：Gmean：0.687766，mAUC：0.687766
# 第17次执行：Gmean：0.7050989999999999，mAUC：0.7050989999999999
# 第18次执行：Gmean：0.6968245，mAUC：0.6968245
# 第19次执行：Gmean：0.714975，mAUC：0.714975
# 第20次执行：Gmean：0.6949160000000001，mAUC：0.6949160000000001
# 第29次执行：Gmean：0.6943895，mAUC：0.6943895
# 第30次执行：Gmean：0.7004635，mAUC：0.7004635
# 第31次执行：Gmean：0.7077525，mAUC：0.7077525
# 第32次执行：Gmean：0.699057，mAUC：0.699057
# 第33次执行：Gmean：0.713395，mAUC：0.713395
# 第34次执行：Gmean：0.7028395000000001，mAUC：0.7028395000000001
# 第35次执行：Gmean：0.7088895，mAUC：0.7088895
# 第36次执行：Gmean：0.680609，mAUC：0.680609
# 第37次执行：Gmean：0.688365，mAUC：0.688365
# 第38次执行：Gmean：0.6858580000000001，mAUC：0.6858580000000001
# 第39次执行：Gmean：0.679639，mAUC：0.679639
# 第40次执行：Gmean：0.6924455，mAUC：0.6924455
# Excel 文件已保存至: C:/Users/zsc/Desktop/Random_Balanced/Balanced/Ecoli/Ecoli.xlsx
# 中位数（平均值）：[0.69725556 0.90131283 0.70711537 0.70711537 0.1424762 ]
# 集成分类结果（标准差）：[0.01429217 0.00673528 0.01268495 0.01268495 0.00249593]
# 第1次执行：Gmean：0.782551，mAUC：0.782551
# 第2次执行：Gmean：0.7875045，mAUC：0.7875045
# 第3次执行：Gmean：0.7901685，mAUC：0.7901685
# 第4次执行：Gmean：0.7723115，mAUC：0.7723115
# 第5次执行：Gmean：0.772417，mAUC：0.772417
# 第6次执行：Gmean：0.7825155，mAUC：0.7825155
# 第7次执行：Gmean：0.7907545，mAUC：0.7907545
# 第8次执行：Gmean：0.771863，mAUC：0.771863
# 第9次执行：Gmean：0.7974745，mAUC：0.7974745
# 第10次执行：Gmean：0.7958510000000001，mAUC：0.7958510000000001
# 第11次执行：Gmean：0.7838905，mAUC：0.7838905
# 第12次执行：Gmean：0.788262，mAUC：0.788262
# 第13次执行：Gmean：0.7900935，mAUC：0.7900935
# 第14次执行：Gmean：0.792862，mAUC：0.792862
# 第15次执行：Gmean：0.780643，mAUC：0.780643
# 第16次执行：Gmean：0.787142，mAUC：0.787142
# 第17次执行：Gmean：0.803372，mAUC：0.803372
# 第18次执行：Gmean：0.772533，mAUC：0.772533
# 第19次执行：Gmean：0.7890155000000001，mAUC：0.7890155000000001
# 第20次执行：Gmean：0.7738085，mAUC：0.7738085
# 第21次执行：Gmean：0.794197，mAUC：0.794197
# 第22次执行：Gmean：0.7925059999999999，mAUC：0.7925059999999999
# 第23次执行：Gmean：0.7957495，mAUC：0.7957495
# 第24次执行：Gmean：0.787033，mAUC：0.787033
# 第25次执行：Gmean：0.7917495000000001，mAUC：0.7917495000000001
# 第26次执行：Gmean：0.785428，mAUC：0.785428
# 第27次执行：Gmean：0.7740724999999999，mAUC：0.7740724999999999
# 第28次执行：Gmean：0.7955285，mAUC：0.7955285
# 第29次执行：Gmean：0.793865，mAUC：0.793865
# 第30次执行：Gmean：0.7864225，mAUC：0.7864225
# 第31次执行：Gmean：0.7969269999999999，mAUC：0.7969269999999999
# 第32次执行：Gmean：0.7973445，mAUC：0.7973445
# 第33次执行：Gmean：0.7741945，mAUC：0.7741945
# 第34次执行：Gmean：0.7797985，mAUC：0.7797985
# 第35次执行：Gmean：0.7879455，mAUC：0.7879455
# 第36次执行：Gmean：0.792991，mAUC：0.792991
# 第37次执行：Gmean：0.7805310000000001，mAUC：0.7805310000000001
# 第38次执行：Gmean：0.786143，mAUC：0.786143
# 第39次执行：Gmean：0.785404，mAUC：0.785404
# 第40次执行：Gmean：0.776246，mAUC：0.776246
# Excel 文件已保存至: C:/Users/zsc/Desktop/Random_Balanced/Balanced/
# 第10次执行：Gmean：0.6572875，mAUC：0.6572875
# 第11次执行：Gmean：0.6534125，mAUC：0.6534125
# 第12次执行：Gmean：0.6570860000000001，mAUC：0.6570860000000001
# 第13次执行：Gmean：0.641499，mAUC：0.641499
# 第14次执行：Gmean：0.6557219999999999，mAUC：0.6557219999999999
# 第15次执行：Gmean：0.6532195，mAUC：0.6532195
# 第16次执行：Gmean：0.6534125，mAUC：0.6534125
# 第17次执行：Gmean：0.6491665，mAUC：0.6491665
# 第18次执行：Gmean：0.6612695，mAUC：0.6612695
# 第19次执行：Gmean：0.656031，mAUC：0.656031
# 第20次执行：Gmean：0.645156，mAUC：0.645156
# 第21次执行：Gmean：0.652103，mAUC：0.652103
# 第22次执行：Gmean：0.6503095，mAUC：0.6503095
# 第23次执行：Gmean：0.6449389999999999，mAUC：0.6449389999999999
# 第24次执行：Gmean：0.6504065，mAUC：0.6504065
# 第25次执行：Gmean：0.6526544999999999，mAUC：0.6526544999999999
# 第26次执行：Gmean：0.654632，mAUC：0.654632
# 第27次执行：Gmean：0.661307，mAUC：0.661307
# 第28次执行：Gmean：0.6571815，mAUC：0.6571815
# 第29次执行：Gmean：0.6656475，mAUC：0.6656475
# 第30次执行：Gmean：0.64358，mAUC：0.64358
# 第31次执行：Gmean：0.6438405，mAUC：0.6438405
# 第32次执行：Gmean：0.650697，mAUC：0.650697
# 第33次执行：Gmean：0.655743，mAUC：0.655743
# 第34次执行：Gmean：0.654738，mAUC：0.654738
# 第35次执行：Gmean：0.6468455，mAUC：0.6468455
# 第36次执行：Gmean：0.656074，mAUC：0.656074
# 第37次执行：Gmean：0.658385，mAUC：0.658385
# 第38次执行：Gmean：0.6556575，mAUC：0.6556575
# 第39次执行：Gmean：0.649404，mAUC：0.649404
# 第40次执行：Gmean：0.6520385，mAUC：0.6520385
# Excel 文件已保存至: C:/Users/zsc/Desktop/Random_Balanced/Balanced/German/German.xlsx
# 中位数（平均值）：[0.65228751 0.70828699 0.65261255 0.65261255 0.32686837]
# 集成分类结果（标准差）：[0.00552335 0.00559177 0.0054993  0.0054993  0.00333827]
# 第1次执行：Gmean：0.9433095，mAUC：0.9433095
# 第2次执行：Gmean：0.95464，mAUC：0.95464
# 第3次执行：Gmean：0.944114，mAUC：0.944114
# 第4次执行：Gmean：0.9433095，mAUC：0.9433095
# 第5次执行：Gmean：0.944315，mAUC：0.944315
# 第6次执行：Gmean：0.943913，mAUC：0.943913
# 第7次执行：Gmean：0.95403，mAUC：0.95403
# 第8次执行：Gmean：0.943913，mAUC：0.943913
# 第9次执行：Gmean：0.944114，mAUC：0.944114
# 第10次执行：Gmean：0.95464，mAUC：0.95464
# 第11次执行：Gmean：0.95464，mAUC：0.95464
# 第12次执行：Gmean：0.9486665000000001，mAUC：0.9486665000000001
# 第13次执行：Gmean：0.9494775，mAUC：0.9494775
# 第14次执行：Gmean：0.955236，mAUC：0.955236
# 第15次执行：Gmean：0.9437260000000001，mAUC：0.9437260000000001
# 第16次执行：Gmean：0.9492765000000001，mAUC：0.9492765000000001
# 第17次执行：Gmean：0.95464，mAUC：0.95464
# 第18次执行：Gmean：0.95464，mAUC：0.95464
# 第19次执行：Gmean：0.95464，mAUC：0.95464
# 第20次执行：Gmean：0.95464，mAUC：0.95464
# 第21次执行：Gmean：0.95464，mAUC：0.95464
# 第22次执行：Gmean：0.9548435，mAUC：0.9548435
# 第23次执行：Gmean：0.943913，mAUC：0.943913
# 第24次执行：Gmean：0.95464，mAUC：0.95464
# 第25次执行：Gmean：0.95464，mAUC：0.95464
# 第26次执行：Gmean：0.944114，mAUC：0.944114
# 第27次执行：Gmean：0.95464，mAUC：0.95464
# 第28次执行：Gmean：0.95403，mAUC：0.95403
# 第29次执行：Gmean：0.95464，mAUC：0.95464
# 第30次执行：Gmean：0.9437260000000001，mAUC：0.9437260000000001
# 第31次执行：Gmean：0.95464，mAUC：0.95464
# 第32次执行：Gmean：0.9548435，mAUC：0.9548435
# 第33次执行：Gmean：0.955425，mAUC：0.955425
# 第34次执行：Gmean：0.9488675，mAUC：0.9488675
# 第35次执行：Gmean：0.95464，mAUC：0.95464
# 第36次执行：Gmean：0.944114，mAUC：0.944114
# 第37次执行：Gmean：0.95464，mAUC：0.95464
# 第38次执行：Gmean：0.955236，mAUC：0.955236
# 第39次执行：Gmean：0.9492765000000001，mAUC：0.9492765000000001
# 第40次执行：Gmean：0.95464，mAUC：0.95464
# Excel 文件已保存至: C:/Users/zsc/Desktop/Random_Balanced/Balanced/Wine/Wine.xlsx
# 中位数（平均值）：[0.95075074 0.99522921 0.9515279  0.9515279  0.31901487]
# 集成分类结果（标准差）：[0.0048484  0.00077576 0.0049675  0.0049675  0.00129346]
# 第1次执行：Gmean：0.912499，mAUC：0.912499
# 第2次执行：Gmean：0.9112979999999999，mAUC：0.9112979999999999
# 第3次执行：Gmean：0.913869，mAUC：0.913869
# 第4次执行：Gmean：0.9120225，mAUC：0.9120225
# 第5次执行：Gmean：0.911277，mAUC：0.911277
# 第6次执行：Gmean：0.9090605，mAUC：0.9090605
# 第7次执行：Gmean：0.9120495，mAUC：0.9120495
# 第8次执行：Gmean：0.915052，mAUC：0.915052
# 第9次执行：Gmean：0.9089295，mAUC：0.9089295
# 第10次执行：Gmean：0.9114965，mAUC：0.9114965
# 第11次执行：Gmean：0.912987，mAUC：0.912987
# 第12次执行：Gmean：0.918551，mAUC：0.918551
# 第13次执行：Gmean：0.906551，mAUC：0.906551
# 第14次执行：Gmean：0.91184，mAUC：0.91184
# 第15次执行：Gmean：0.91269，mAUC：0.91269
# 第16次执行：Gmean：0.9072715，mAUC：0.9072715
# 第17次执行：Gmean：0.9151385，mAUC：0.9151385
# 第18次执行：Gmean：0.9040360000000001，mAUC：0.9040360000000001
# 第19次执行：Gmean：0.913802，mAUC：0.913802
# 第20次执行：Gmean：0.9124615，mAUC：0.9124615
# 第21次执行：Gmean：0.9105995，mAUC：0.9105995
# 第22次执行：Gmean：0.9170195000000001，mAUC：0.9170195000000001
# 第23次执行：Gmean：0.9109535，mAUC：0.9109535
# 第24次执行：Gmean：0.9126805，mAUC：0.9126805
# 第25次执行：Gmean：0.90872，mAUC：0.90872
# 第26次执行：Gmean：0.913061，mAUC：0.913061
# 第27次执行：Gmean：0.9171905，mAUC：0.9171905
# 第28次执行：Gmean：0.912881，mAUC：0.912881
# 第29次执行：Gmean：0.9094800000000001，mAUC：0.9094800000000001
# Excel 文件已保存至: C:/Users/zsc/Desktop/Random_Balanced/Balanced/Penbased/Penbased.xlsx
# 中位数（平均值）：[0.94805719 0.99389055 0.94850394 0.94850394 0.09489325]
# 集成分类结果（标准差）：[0.00126218 0.00038317 0.00128426 0.00128426 0.00012359]
# 第1次执行：Gmean：0.9153290000000001，mAUC：0.9153290000000001
# 第2次执行：Gmean：0.9147055，mAUC：0.9147055
# 第3次执行：Gmean：0.913565，mAUC：0.913565
# 第4次执行：Gmean：0.9143055，mAUC：0.9143055
# 第5次执行：Gmean：0.9155985，mAUC：0.9155985
# 第6次执行：Gmean：0.9135185，mAUC：0.9135185
# 第7次执行：Gmean：0.9150705，mAUC：0.9150705
# 第8次执行：Gmean：0.914831，mAUC：0.914831
# 第9次执行：Gmean：0.9154925，mAUC：0.9154925
# 第10次执行：Gmean：0.91284，mAUC：0.91284
# 第11次执行：Gmean：0.9147565，mAUC：0.9147565
# 第12次执行：Gmean：0.914928，mAUC：0.914928
# 第13次执行：Gmean：0.913484，mAUC：0.913484
# 第14次执行：Gmean：0.9123235000000001，mAUC：0.9123235000000001
# 第15次执行：Gmean：0.9171320000000001，mAUC：0.9171320000000001
# 第16次执行：Gmean：0.9136569999999999，mAUC：0.9136569999999999
# 第17次执行：Gmean：0.9130320000000001，mAUC：0.9130320000000001
# 第18次执行：Gmean：0.914035，mAUC：0.914035
# 第19次执行：Gmean：0.9137595000000001，mAUC：0.9137595000000001
# 第20次执行：Gmean：0.9145525，mAUC：0.9145525
# 第21次执行：Gmean：0.9151279999999999，mAUC：0.9151279999999999
# 第22次执行：Gmean：0.9133695，mAUC：0.9133695
# 第23次执行：Gmean：0.9154495，mAUC：0.9154495
# 第24次执行：Gmean：0.9147529999999999，mAUC：0.9147529999999999
# 第25次执行：Gmean：0.912059，mAUC：0.912059
# 第26次执行：Gmean：0.9155825，mAUC：0.9155825
# 第27次执行：Gmean：0.9146075，mAUC：0.9146075
# 第28次执行：Gmean：0.9153560000000001，mAUC：0.9153560000000001
# 第29次执行：Gmean：0.914115，mAUC：0.914115
# 第30次执行：Gmean：0.9116695，mAUC：0.9116695
# 第31次执行：Gmean：0.914436，mAUC：0.914436
# 第32次执行：Gmean：0.914866，mAUC：0.914866
# 第33次执行：Gmean：0.9124570000000001，mAUC：0.9124570000000001
# 第34次执行：Gmean：0.9151849999999999，mAUC：0.9151849999999999
# 第35次执行：Gmean：0.915138，mAUC：0.915138
# 第36次执行：Gmean：0.9128375，mAUC：0.9128375
# 第37次执行：Gmean：0.9135025，mAUC：0.9135025
# 第38次执行：Gmean：0.913709，mAUC：0.913709
# 第39次执行：Gmean：0.9131294999999999，mAUC：0.9131294999999999
# 第40次执行：Gmean：0.915748，mAUC：0.915748
# Excel 文件已保存至: C:/Users/zsc/Desktop/Random_Balanced/Balanced/USPS/USPS.xlsx
# 中位数（平均值）：[0.91425035 0.99096114 0.91494409 0.91494409 0.09101817]
# 集成分类结果（标准差）：[0.00115925 0.00018998 0.00116073 0.00116073 0.00010302]
# 第1次执行：Gmean：0.846756，mAUC：0.846756
# 第2次执行：Gmean：0.844399，mAUC：0.844399
# 第3次执行：Gmean：0.848912，mAUC：0.848912
# 第4次执行：Gmean：0.8484805，mAUC：0.8484805
# 第5次执行：Gmean：0.8468815000000001，mAUC：0.8468815000000001
# 第6次执行：Gmean：0.8495955，mAUC：0.8495955
# 第7次执行：Gmean：0.847348，mAUC：0.847348
# 第8次执行：Gmean：0.8473900000000001，mAUC：0.8473900000000001
# 第9次执行：Gmean：0.846742，mAUC：0.846742
# 第10次执行：Gmean：0.8469745，mAUC：0.8469745
# 第11次执行：Gmean：0.851541，mAUC：0.851541
# 第12次执行：Gmean：0.847757，mAUC：0.847757
# 第13次执行：Gmean：0.847374，mAUC：0.847374
# 第14次执行：Gmean：0.8483890000000001，mAUC：0.8483890000000001
# 第15次执行：Gmean：0.846957，mAUC：0.846957
# 第16次执行：Gmean：0.8494934999999999，mAUC：0.8494934999999999
# 第17次执行：Gmean：0.851086，mAUC：0.851086
# 第18次执行：Gmean：0.8496325，mAUC：0.8496325
# 第19次执行：Gmean：0.847684，mAUC：0.847684
# 第20次执行：Gmean：0.847623，mAUC：0.847623
# 第21次执行：Gmean：0.8503959999999999，mAUC：0.8503959999999999
# 第22次执行：Gmean：0.849566，mAUC：0.849566
# 第23次执行：Gmean：0.8468964999999999，mAUC：0.8468964999999999
# 第24次执行：Gmean：0.8470445，mAUC：0.8470445
# 第25次执行：Gmean：0.84935，mAUC：0.84935
# 第26次执行：Gmean：0.847612，mAUC：0.847612
# 第27次执行：Gmean：0.8458425，mAUC：0.8458425
# 第28次执行：Gmean：0.849895，mAUC：0.849895
# 第29次执行：Gmean：0.8464370000000001，mAUC：0.8464370000000001
# 第30次执行：Gmean：0.8484125，mAUC：0.8484125
# 第31次执行：Gmean：0.851499，mAUC：0.851499
# 第32次执行：Gmean：0.8491394999999999，mAUC：0.8491394999999999
# 第33次执行：Gmean：0.8482745，mAUC：0.8482745
# 第34次执行：Gmean：0.848786，mAUC：0.848786
# 第35次执行：Gmean：0.848732，mAUC：0.848732
# 第36次执行：Gmean：0.850776，mAUC：0.850776
# 第37次执行：Gmean：0.850372，mAUC：0.850372
# 第38次执行：Gmean：0.8499645，mAUC：0.8499645
# 第39次执行：Gmean：0.849835，mAUC：0.849835
# 第40次执行：Gmean：0.8489964999999999，mAUC：0.8489964999999999
# Excel 文件已保存至: C:/Users/zsc/Desktop/Random_Balanced/Balanced/Satellite/Satellite.xlsx
# 中位数（平均值）：[0.84847107 0.97793125 0.85414548 0.85414548 0.14167889]
# 集成分类结果（标准差）：[0.0015992  0.00035603 0.00160837 0.00160837 0.00027449]
# 第1次执行：Gmean：0.8490725，mAUC：0.8490725
# 第2次执行：Gmean：0.8415665，mAUC：0.8415665
# 第3次执行：Gmean：0.847213，mAUC：0.847213
# 第4次执行：Gmean：0.839148，mAUC：0.839148
# 第5次执行：Gmean：0.8594695，mAUC：0.8594695
# 第6次执行：Gmean：0.862067，mAUC：0.862067
# 第7次执行：Gmean：0.861101，mAUC：0.861101
# 第8次执行：Gmean：0.8494055，mAUC：0.8494055
# 第9次执行：Gmean：0.8582620000000001，mAUC：0.8582620000000001
# 第10次执行：Gmean：0.845818，mAUC：0.845818
# 第11次执行：Gmean：0.863511，mAUC：0.863511
# 第12次执行：Gmean：0.8315245，mAUC：0.8315245
# 第13次执行：Gmean：0.8626480000000001，mAUC：0.8626480000000001
# 第14次执行：Gmean：0.8470305，mAUC：0.8470305
# 第15次执行：Gmean：0.850552，mAUC：0.850552
# 第16次执行：Gmean：0.8717715，mAUC：0.8717715
# 第17次执行：Gmean：0.8503445000000001，mAUC：0.8503445000000001
# 第18次执行：Gmean：0.8562415000000001，mAUC：0.8562415000000001
# 第19次执行：Gmean：0.851871，mAUC：0.851871
# 第20次执行：Gmean：0.880368，mAUC：0.880368
# 第21次执行：Gmean：0.8522514999999999，mAUC：0.8522514999999999
# 第22次执行：Gmean：0.8668899999999999，mAUC：0.8668899999999999
# 第23次执行：Gmean：0.864787，mAUC：0.864787
# 第24次执行：Gmean：0.836309，mAUC：0.836309
# 第25次执行：Gmean：0.8503445000000001，mAUC：0.8503445000000001
# 第26次执行：Gmean：0.860487，mAUC：0.860487
# 第27次执行：Gmean：0.8547915，mAUC：0.8547915
# 第28次执行：Gmean：0.857738，mAUC：0.857738
# 第29次执行：Gmean：0.837342，mAUC：0.837342
# 第30次执行：Gmean：0.852064，mAUC：0.852064
# 第31次执行：Gmean：0.8457905，mAUC：0.8457905
# 第32次执行：Gmean：0.8387374999999999，mAUC：0.8387374999999999
# 第33次执行：Gmean：0.854479，mAUC：0.854479
# 第34次执行：Gmean：0.8697515，mAUC：0.8697515
# 第35次执行：Gmean：0.856742，mAUC：0.856742
# 第36次执行：Gmean：0.841002，mAUC：0.841002
# 第37次执行：Gmean：0.844376，mAUC：0.844376
# 第38次执行：Gmean：0.8528800000000001，mAUC：0.8528800000000001
# 第39次执行：Gmean：0.846087，mAUC：0.846087
# 第40次执行：Gmean：0.852881，mAUC：0.852881
# Excel 文件已保存至: C:/Users/zsc/Desktop/Random_Balanced/Balanced/Page_Blocks/Page_Blocks.xlsx
# 中位数（平均值）：[0.85286791 0.95913191 0.85763907 0.85763907 0.1808607 ]
# 集成分类结果（标准差）：[0.01029984 0.00408469 0.01029579 0.01029579 0.00167336]
# 第1次执行：Gmean：0.991379，mAUC：0.991379
# 第2次执行：Gmean：0.9892515，mAUC：0.9892515
# 第3次执行：Gmean：0.991379，mAUC：0.991379
# 第4次执行：Gmean：0.987179，mAUC：0.987179
# 第5次执行：Gmean：0.991379，mAUC：0.991379
# 第6次执行：Gmean：0.991379，mAUC：0.991379
# 第7次执行：Gmean：0.991379，mAUC：0.991379
# 第8次执行：Gmean：0.9871515，mAUC：0.9871515
# 第9次执行：Gmean：0.991379，mAUC：0.991379
# 第10次执行：Gmean：0.991379，mAUC：0.991379
# 第11次执行：Gmean：0.991379，mAUC：0.991379
# 第12次执行：Gmean：0.991379，mAUC：0.991379
# 第13次执行：Gmean：0.991379，mAUC：0.991379
# 第14次执行：Gmean：0.987124，mAUC：0.987124
# 第15次执行：Gmean：0.989279，mAUC：0.989279
# 第16次执行：Gmean：0.987124，mAUC：0.987124
# 第17次执行：Gmean：0.991379，mAUC：0.991379
# 第18次执行：Gmean：0.9871515，mAUC：0.9871515
# 第19次执行：Gmean：0.991379，mAUC：0.991379
# 第20次执行：Gmean：0.991379，mAUC：0.991379
# 第21次执行：Gmean：0.991379，mAUC：0.991379
# 第22次执行：Gmean：0.987124，mAUC：0.987124
# 第23次执行：Gmean：0.991379，mAUC：0.991379
# 第24次执行：Gmean：0.991379，mAUC：0.991379
# 第25次执行：Gmean：0.991379，mAUC：0.991379
# 第26次执行：Gmean：0.991379，mAUC：0.991379
# 第27次执行：Gmean：0.991379，mAUC：0.991379
# 第28次执行：Gmean：0.987124，mAUC：0.987124
# 第29次执行：Gmean：0.991379，mAUC：0.991379
# 第30次执行：Gmean：0.991379，mAUC：0.991379
# 第31次执行：Gmean：0.991379，mAUC：0.991379
# 第32次执行：Gmean：0.991379，mAUC：0.991379
# 第33次执行：Gmean：0.987124，mAUC：0.987124
# 第34次执行：Gmean：0.991379，mAUC：0.991379
# 第35次执行：Gmean：0.991379，mAUC：0.991379
# 第36次执行：Gmean：0.991379，mAUC：0.991379
# 第37次执行：Gmean：0.9914069999999999，mAUC：0.9914069999999999
# 第38次执行：Gmean：0.991379，mAUC：0.991379
# 第39次执行：Gmean：0.987124，mAUC：0.987124
# 第40次执行：Gmean：0.991379，mAUC：0.991379
# Excel 文件已保存至: C:/Users/zsc/Desktop/Random_Balanced/Balanced/Shuttle/Shuttle.xlsx
# 中位数（平均值）：[0.99031939 0.98873944 0.9903845  0.9903845  0.32743758]
# 集成分类结果（标准差）：[0.0017751  0.00158162 0.00178794 0.00178794 0.00044871]
# 第1次执行：Gmean：0.5026505，mAUC：0.5026505
# 第2次执行：Gmean：0.504683，mAUC：0.504683
# 第3次执行：Gmean：0.5109345000000001，mAUC：0.5109345000000001
# 第4次执行：Gmean：0.4993345，mAUC：0.4993345
# 第5次执行：Gmean：0.5085305，mAUC：0.5085305
# 第6次执行：Gmean：0.5025204999999999，mAUC：0.5025204999999999
# 第7次执行：Gmean：0.4965005，mAUC：0.4965005
# 第8次执行：Gmean：0.5082295，mAUC：0.5082295
# 第9次执行：Gmean：0.5088835，mAUC：0.5088835
# 第10次执行：Gmean：0.508609，mAUC：0.508609
# 第11次执行：Gmean：0.5017605，mAUC：0.5017605
# 第12次执行：Gmean：0.5069565，mAUC：0.5069565
# 第13次执行：Gmean：0.4999445，mAUC：0.4999445
# 第14次执行：Gmean：0.497709，mAUC：0.497709
# 第15次执行：Gmean：0.503115，mAUC：0.503115
# 第16次执行：Gmean：0.49938249999999995，mAUC：0.49938249999999995
# 第17次执行：Gmean：0.501768，mAUC：0.501768
# 第18次执行：Gmean：0.5109815，mAUC：0.5109815
# 第19次执行：Gmean：0.5089735，mAUC：0.5089735
# 第20次执行：Gmean：0.499947，mAUC：0.499947
# 第21次执行：Gmean：0.49876299999999996，mAUC：0.49876299999999996
# 第22次执行：Gmean：0.5076290000000001，mAUC：0.5076290000000001
# 第23次执行：Gmean：0.502861，mAUC：0.502861
# 第24次执行：Gmean：0.5035719999999999，mAUC：0.5035719999999999
# 第25次执行：Gmean：0.5027219999999999，mAUC：0.5027219999999999
# 第26次执行：Gmean：0.499152，mAUC：0.499152
# 第27次执行：Gmean：0.5021145，mAUC：0.5021145
# 第28次执行：Gmean：0.5046765，mAUC：0.5046765
# 第29次执行：Gmean：0.50832，mAUC：0.50832
# 第30次执行：Gmean：0.5038015，mAUC：0.5038015
# 第31次执行：Gmean：0.508379，mAUC：0.508379
# 第32次执行：Gmean：0.501226，mAUC：0.501226
# 第33次执行：Gmean：0.5054765，mAUC：0.5054765
# 第34次执行：Gmean：0.500538，mAUC：0.500538
# 第35次执行：Gmean：0.5138315，mAUC：0.5138315
# 第36次执行：Gmean：0.503587，mAUC：0.503587
# 第37次执行：Gmean：0.504105，mAUC：0.504105
# 第38次执行：Gmean：0.50413，mAUC：0.50413
# 第39次执行：Gmean：0.5013965，mAUC：0.5013965
# 第40次执行：Gmean：0.508711，mAUC：0.508711
# Excel 文件已保存至: C:/Users/zsc/Desktop/Random_Balanced/Balanced/Contraceptive/Contraceptive.xlsx
# 中位数（平均值）：[0.50416015 0.67811972 0.50648822 0.50648822 0.17120384]
# 集成分类结果（标准差）：[0.00405159 0.00352674 0.00371784 0.00371784 0.00121676]
# 第1次执行：Gmean：0.5178815，mAUC：0.5178815
# 第2次执行：Gmean：0.5295704999999999，mAUC：0.5295704999999999
# 第3次执行：Gmean：0.5458700000000001，mAUC：0.5458700000000001
# 第4次执行：Gmean：0.517957，mAUC：0.517957
# 第5次执行：Gmean：0.526799，mAUC：0.526799
# 第6次执行：Gmean：0.48877550000000003，mAUC：0.48877550000000003
# 第7次执行：Gmean：0.5206985，mAUC：0.5206985
# 第8次执行：Gmean：0.4863455，mAUC：0.4863455
# 第9次执行：Gmean：0.5378205，mAUC：0.5378205
# 第10次执行：Gmean：0.507083，mAUC：0.507083
# 第11次执行：Gmean：0.553579，mAUC：0.553579
# 第12次执行：Gmean：0.5329935，mAUC：0.5329935
# 第13次执行：Gmean：0.526987，mAUC：0.526987
# 第14次执行：Gmean：0.5415175000000001，mAUC：0.5415175000000001
# 第15次执行：Gmean：0.527773，mAUC：0.527773
# 第16次执行：Gmean：0.5450225，mAUC：0.5450225
# 第17次执行：Gmean：0.5236075，mAUC：0.5236075
# 第18次执行：Gmean：0.532154，mAUC：0.532154
# 第19次执行：Gmean：0.5031924999999999，mAUC：0.5031924999999999
# 第20次执行：Gmean：0.542813，mAUC：0.542813
# 第21次执行：Gmean：0.509154，mAUC：0.509154
# 第22次执行：Gmean：0.5056535，mAUC：0.5056535
# 第23次执行：Gmean：0.546558，mAUC：0.546558
# 第24次执行：Gmean：0.5099914999999999，mAUC：0.5099914999999999
# 第25次执行：Gmean：0.5214924999999999，mAUC：0.5214924999999999
# 第26次执行：Gmean：0.55374，mAUC：0.55374
# 第27次执行：Gmean：0.520043，mAUC：0.520043
# 第28次执行：Gmean：0.5492375，mAUC：0.5492375
# 第29次执行：Gmean：0.49981549999999997，mAUC：0.49981549999999997
# 第30次执行：Gmean：0.5012015000000001，mAUC：0.5012015000000001
# 第31次执行：Gmean：0.520251，mAUC：0.520251
# 第32次执行：Gmean：0.5166634999999999，mAUC：0.5166634999999999
# 第33次执行：Gmean：0.5233760000000001，mAUC：0.5233760000000001
# 第34次执行：Gmean：0.542813，mAUC：0.542813
# 第35次执行：Gmean：0.5226265，mAUC：0.5226265
# 第36次执行：Gmean：0.5343355000000001，mAUC：0.5343355000000001
# 第37次执行：Gmean：0.500377，mAUC：0.500377
# 第38次执行：Gmean：0.484641，mAUC：0.484641
# 第39次执行：Gmean：0.5306595000000001，mAUC：0.5306595000000001
# 第40次执行：Gmean：0.532154，mAUC：0.532154
# Excel 文件已保存至: C:/Users/zsc/Desktop/Random_Balanced/Balanced/Automobile/Automobile.xlsx
# 中位数（平均值）：[0.52333061 0.80990746 0.5605558  0.5605558  0.11627993]
# 集成分类结果（标准差）：[0.01800016 0.00847349 0.01647114 0.01647114 0.00284025]
# 第1次执行：Gmean：0.948119，mAUC：0.948119
# 第2次执行：Gmean：0.956858，mAUC：0.956858
# 第3次执行：Gmean：0.948276，mAUC：0.948276
# 第4次执行：Gmean：0.939299，mAUC：0.939299
# 第5次执行：Gmean：0.948119，mAUC：0.948119
# 第6次执行：Gmean：0.9432400000000001，mAUC：0.9432400000000001
# 第7次执行：Gmean：0.955925，mAUC：0.955925
# 第8次执行：Gmean：0.9432400000000001，mAUC：0.9432400000000001
# 第9次执行：Gmean：0.9523330000000001，mAUC：0.9523330000000001
# 第10次执行：Gmean：0.947649，mAUC：0.947649
# 第11次执行：Gmean：0.948276，mAUC：0.948276
# 第12次执行：Gmean：0.9472565，mAUC：0.9472565
# 第13次执行：Gmean：0.939616，mAUC：0.939616
# 第14次执行：Gmean：0.947884，mAUC：0.947884
# 第15次执行：Gmean：0.947884，mAUC：0.947884
# 第16次执行：Gmean：0.9481975，mAUC：0.9481975
# 第17次执行：Gmean：0.947649，mAUC：0.947649
# 第18次执行：Gmean：0.9481975，mAUC：0.9481975
# 第19次执行：Gmean：0.9436325，mAUC：0.9436325
# 第20次执行：Gmean：0.948119，mAUC：0.948119
# 第21次执行：Gmean：0.9436325，mAUC：0.9436325
# 第22次执行：Gmean：0.947649，mAUC：0.947649
# 第23次执行：Gmean：0.948276，mAUC：0.948276
# 第24次执行：Gmean：0.948119，mAUC：0.948119
# 第25次执行：Gmean：0.939616，mAUC：0.939616
# 第26次执行：Gmean：0.947649，mAUC：0.947649
# 第27次执行：Gmean：0.946864，mAUC：0.946864
# 第28次执行：Gmean：0.948119，mAUC：0.948119
# 第29次执行：Gmean：0.948119，mAUC：0.948119
# 第30次执行：Gmean：0.939616，mAUC：0.939616
# 第31次执行：Gmean：0.948119，mAUC：0.948119
# 第32次执行：Gmean：0.948119，mAUC：0.948119
# 第33次执行：Gmean：0.947884，mAUC：0.947884
# 第34次执行：Gmean：0.9394575000000001，mAUC：0.9394575000000001
# 第35次执行：Gmean：0.948119，mAUC：0.948119
# 第36次执行：Gmean：0.939616，mAUC：0.939616
# 第37次执行：Gmean：0.939616，mAUC：0.939616
# 第38次执行：Gmean：0.9562360000000001，mAUC：0.9562360000000001
# 第39次执行：Gmean：0.939616，mAUC：0.939616
# 第40次执行：Gmean：0.947649，mAUC：0.947649
# Excel 文件已保存至: C:/Users/zsc/Desktop/Random_Balanced/Balanced/Ovarian/Ovarian.xlsx
# 中位数（平均值）：[0.94654652 0.96640161 0.94687509 0.94687509 0.4755015 ]
# 集成分类结果（标准差）：[0.0044727  0.00339648 0.00456053 0.00456053 0.00186347]
# *****************算法执行结束！******************
# 数据已成功写入到 C:/Users/zsc/Desktop/Random_Balanced/Balanced/avg_results.xlsx
