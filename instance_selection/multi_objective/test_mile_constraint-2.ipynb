# %% [markdown]
# # E-SEIC
# Selection of evolutionary instances with constraints for unbalanced datasets

# %%
from utils.dataset_utils import get_distribution, k_fold_cross_validation
from instance_selection.parameter.parameter import *  # 导入参数的设定
from instance_selection.operator.init_toolbox import init_toolbox_eseic
from instance_selection.operator.metrics import calculate_gmean_mauc, calculate_average_accuracy, calculate_accuracy
from instance_selection.operator.genetic_operator import selTournamentNDCD
from instance_selection.operator.ensemble import vote_result_ensembles, ensemble_individuals
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.base import clone
import scipy.io as sio  # 从.mat文件中读取数据集
import random
import warnings
import numpy as np
import os
from openpyxl import Workbook

warnings.filterwarnings("ignore")  # 忽略警告
from utils.excel_utils import save_to_excel_2


# 数据的预处理
def data_process(dataset=None, distribution=False):
    datasetname = dataset.DATASETNAME.split('.')[0]
    mat_data = sio.loadmat(IMBALANCED_DATASET_PATH + dataset.DATASETNAME)  # 加载、划分数据集
    x = mat_data['X']
    y = mat_data['Y'][:, 0]  # mat_data['Y']得到的形状为[n,1]，通过[:,0]，得到形状[n,]
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y,
                                                        random_state=RANDOM_SEED)  # 划分数据集
    scaler = StandardScaler()  # 数据的标准化
    x_train = scaler.fit_transform(x_train)
    x_test = scaler.transform(x_test)
    unique_elements_all, classes_all, counts_all = get_distribution(y)  # 获取原始数据集分布
    unique_elements_train, classes_train, counts_train = get_distribution(y_train)  # 获取训练集分布
    unique_elements_test, classes_test, counts_test = get_distribution(y_test)  # 获取测试集分布
    weights_train = (1 / counts_train.astype(float)) / np.sum(1 / counts_train.astype(float))  # 计算每个类的权重，用于计算每个类别的权重
    if distribution:
        print(datasetname + f' distribution: {counts_all}')
        print(f'trainset distribution: {counts_train}')
        print(f'testset distribution: {counts_test}')
    model = MLPClassifier(hidden_layer_sizes=(dataset.HIDDEN_SIZE,), max_iter=dataset.MAX_ITER,
                          random_state=RANDOM_SEED, learning_rate_init=dataset.LEARNING_RATE)
    y_train_pred_proba = k_fold_cross_validation(model=clone(model), X=x_train, y=y_train, n_splits=N_SPLITS,
                                                 method='soft',
                                                 random_state=RANDOM_SEED)  # 交叉验证得到软标签
    # 将概率转化为预测结果
    y_train_pred = np.argmax(y_train_pred_proba, axis=1)

    Acc1, Acc2, Acc3 = calculate_accuracy(y_train_pred, y_train, weights_train)
    constraints = [Acc1, Acc2, Acc3]

    return x_train, x_test, y_train, y_test, constraints, weights_train, clone(model)


def main(x_train, y_train, model, balanced_method='random'):
    list_of_sfe = []
    ####################################种群的初始化###########################
    pop = toolbox.population(n=POPSIZE)  # 个体编码默认全为0
    pop = toolbox.init_population(pop, balanced_method=balanced_method)  # 初始化种群中的个体
    toolbox.evaluate(pop)  # 计算个体的适应度
    feasible_pop, infeasible_pop = toolbox.get_feasible_infeasible(pop)  # 得到可行解与不可行解
    # 输出可行解的数量
    print(f'第{0}代，可行解的数量为{len(feasible_pop)}')
    list_of_sfe.append(len(feasible_pop))
    ####################################种群的迭代#################################################
    for gen in range(1, NGEN + 11):
        offspring = selTournamentNDCD(pop, POPSIZE, tournsize=3)  # 锦标赛选择（1、先根据非支配排序的等级2、再根据拥挤距离）
        offspring = [toolbox.clone(ind) for ind in offspring]
        for i in range(0, len(offspring) - 1, 2):
            if random.random() <= CXPB:
                offspring[i], offspring[i + 1] = toolbox.mate(offspring[i], offspring[i + 1])  # 单点交叉
            offspring[i] = toolbox.mutate(offspring[i], MR)[0]  # 二进制反转突变
            offspring[i + 1] = toolbox.mutate(offspring[i + 1], MR)[0]  # 二进制反转突变
            del offspring[i].fitness.values, offspring[i + 1].fitness.values
        #############################################################合并、去重#####################################################
        offspring = toolbox.individuals_constraints(offspring)  # 限制每个类至少有一个实例被选择
        pop = pop + offspring  # 种群的合并
        pop, _ = toolbox.remove_duplicates(pop)  # 去重
        while len(pop) < POPSIZE:  # 保证种群大小为POPSIZE
            add_individual = []
            num_add = POPSIZE - len(pop)
            for i in range(0, num_add):
                index = random.randint(0, len(offspring) - 1)  # 在0-len(offspring)范围内随机产生一个索引
                offspring[index] = toolbox.mutate(offspring[index], MR)[0]  # 选择index对应的个体进行突变
                del offspring[index].fitness.values
                add_individual.append(offspring[index])
            add_individual = toolbox.individuals_constraints(add_individual)  # 限制每个类至少有一个实例被选择
            pop = pop + add_individual  # 种群的合并
            pop, _ = toolbox.remove_duplicates(pop)  # 去重
        pop = toolbox.individuals_constraints(pop)  # 限制每个类至少有5个实例被选择
        toolbox.evaluate(pop)  # 计算新种群适应度
        ###############################################得到pareto_fronts############################################
        feasible_pop, infeasible_pop = toolbox.get_feasible_infeasible(pop)  # 得到可行解与不可行解
        # 输出可行解的数量
        print(f'第{gen}代，可行解的数量为{len(feasible_pop)}')
        list_of_sfe.append(len(feasible_pop))
        if len(feasible_pop) >= POPSIZE:
            pop, pareto_fronts = toolbox.select(feasible_pop, POPSIZE)
            ensembles = pop  # pop均为可行解，则集成pop中所有个体
        elif len(feasible_pop) > 0:
            pop = feasible_pop + infeasible_pop[:POPSIZE - len(feasible_pop)]  # 在不可行解中选取违约程度小的个体，保证pop数量为POPSIZE
            ensembles = feasible_pop  # 只集成可行解
        else:
            pop = feasible_pop + infeasible_pop[:POPSIZE - len(feasible_pop)]  # 加入不可行解中违约程度小的个体，保证pop数量为POPSIZE
            ensembles = [infeasible_pop[0]]  # 没有可行解，集成不可行解中第一个个体
        _, avg_acc2, _ = calculate_average_accuracy(ensembles)  # 计算acc1、acc2、acc3的平均值
    ensemble_classifiers = ensemble_individuals(ensembles, model, x_train, y_train)
    return ensemble_classifiers, list_of_sfe
def save_to_excel(data, save_path, filename='avg_results'):
    """
    将列表数据逐行写入Excel文件
    参数:
        data: 二维列表，每个子列表代表一行数据
        filename: 输出的Excel文件名(默认为output.xlsx)
    """
    # 创建一个新的工作簿
    wb = Workbook()
    # 获取活动的工作表
    ws = wb.active
    # 逐行写入数据
    for row in data:
        avg = row[1].tolist()
        avg.insert(0, row[0])
        std = row[2].tolist()
        std.insert(0, row[0])
        ws.append(avg)
        ws.append(std)
    # 创建 Excel 文件完整路径
    file_path = os.path.join(save_path, filename + ".xlsx")
    # 保存Excel文件
    wb.save(file_path)
    print(f"数据已成功写入到 {file_path}")

# %% [markdown]
# ## 运行

# %%
# DATASETS = [Balance_Scale,Dermatology,Ecoli,Car,Pen_Digits,WallRobot,German,Wine,Nursery,Penbased,USPS,Satellite,Page_Blocks,Shuttle,Contraceptive,Automobile,Ovarian]  # 数据集名称（包含对应的参数配置）

# DATASETS = [Balance_Scale,Dermatology,Ecoli,Car,Pen_Digits,WallRobot,Wine,Satellite,Shuttle]  # 数据集名称（包含对应的参数配置）
DATASETS = [German,Nursery,Penbased,Contraceptive,USPS]  # 数据集名称（包含对应的参数配置）
#DATASETS = [Balance_Scale]  # 数据集名称（包含对应的参数配置）
if __name__ == "__main__":
    save_path = 'C:/Users/zsc/Desktop/MILE/'
    datasets_sfe_results = []
    print("*****************算法开始执行：******************")
    for j, dataset in enumerate(DATASETS):
        x_train, x_test, y_train, y_test, constraints, weights_train, model = data_process(dataset=dataset,
                                                                                           distribution=False)
        toolbox = init_toolbox_eseic(model, x_train, y_train, weights_train, constraints, n_splits=N_SPLITS,
                                     random_seed=42)  # 初始化toolbox
        num_run = 4  # 运行次数
        for i in range(num_run):
            _, list_of_sfe = main(x_train, y_train, model=model, balanced_method='random')
            datasets_sfe_results.append([dataset.DATASETNAME.split('.')[0], list_of_sfe])
    print("*****************算法执行结束！******************")
    for k, list in enumerate(datasets_sfe_results):
        print(f'{list[0]}的第{(k + 1) % (num_run+1)}次运行的结果为：{list[1]}')
# Out:
# *****************算法开始执行：******************
# 第0代，可行解的数量为7
# 第1代，可行解的数量为13
# 第2代，可行解的数量为25
# 第3代，可行解的数量为45
# 第4代，可行解的数量为47
# 第5代，可行解的数量为48
# 第6代，可行解的数量为51
# 第7代，可行解的数量为53
# 第8代，可行解的数量为55
# 第9代，可行解的数量为54
# 第10代，可行解的数量为53
# 第11代，可行解的数量为55
# 第12代，可行解的数量为53
# 第13代，可行解的数量为54
# 第14代，可行解的数量为59
# 第15代，可行解的数量为59
# 第16代，可行解的数量为59
# 第17代，可行解的数量为58
# 第18代，可行解的数量为60
# 第19代，可行解的数量为60
# 第20代，可行解的数量为60
# 第21代，可行解的数量为59
# 第22代，可行解的数量为60
# 第23代，可行解的数量为56
# 第24代，可行解的数量为59
# 第25代，可行解的数量为58
# 第26代，可行解的数量为59
# 第27代，可行解的数量为59
# 第28代，可行解的数量为59
# 第29代，可行解的数量为59
# 第30代，可行解的数量为58
# 第31代，可行解的数量为60
# 第32代，可行解的数量为57
# 第33代，可行解的数量为59
# 第34代，可行解的数量为60
# 第35代，可行解的数量为60
# 第36代，可行解的数量为58
# 第37代，可行解的数量为60
# 第38代，可行解的数量为58
# 第39代，可行解的数量为59
# 第40代，可行解的数量为59
# 第0代，可行解的数量为12
# 第1代，可行解的数量为23
# 第2代，可行解的数量为40
# 第3代，可行解的数量为48
# 第4代，可行解的数量为48
# 第5代，可行解的数量为52
# 第6代，可行解的数量为52
# 第7代，可行解的数量为56
# 第8代，可行解的数量为54
# 第9代，可行解的数量为52
# 第10代，可行解的数量为56
# 第11代，可行解的数量为54
# 第12代，可行解的数量为57
# 第13代，可行解的数量为56
# 第14代，可行解的数量为56
# 第15代，可行解的数量为57
# 第16代，可行解的数量为57
# 第17代，可行解的数量为55
# 第18代，可行解的数量为57
# 第19代，可行解的数量为56
# 第20代，可行解的数量为60
# 第21代，可行解的数量为60
# 第22代，可行解的数量为58
# 第23代，可行解的数量为58
# 第24代，可行解的数量为60
# 第25代，可行解的数量为58
# 第26代，可行解的数量为58
# 第27代，可行解的数量为60
# 第28代，可行解的数量为59
# 第29代，可行解的数量为59
# 第30代，可行解的数量为59
# 第31代，可行解的数量为60
# 第32代，可行解的数量为58
# 第33代，可行解的数量为59
# 第34代，可行解的数量为60
# 第35代，可行解的数量为58
# 第36代，可行解的数量为60
# 第37代，可行解的数量为58
# 第38代，可行解的数量为60
# 第39代，可行解的数量为60
# 第40代，可行解的数量为58
# 第0代，可行解的数量为9
# 第1代，可行解的数量为15
# 第2代，可行解的数量为27
# 第3代，可行解的数量为43
# 第4代，可行解的数量为43
# 第5代，可行解的数量为42
# 第6代，可行解的数量为51
# 第7代，可行解的数量为50
# 第8代，可行解的数量为50
# 第9代，可行解的数量为48
# 第10代，可行解的数量为56
# 第11代，可行解的数量为51
# 第12代，可行解的数量为52
# 第13代，可行解的数量为51
# 第14代，可行解的数量为56
# 第15代，可行解的数量为54
# 第16代，可行解的数量为59
# 第17代，可行解的数量为55
# 第18代，可行解的数量为58
# 第19代，可行解的数量为57
# 第20代，可行解的数量为59
# 第21代，可行解的数量为56
# 第22代，可行解的数量为57
# 第23代，可行解的数量为58
# 第24代，可行解的数量为57
# 第25代，可行解的数量为58
# 第26代，可行解的数量为56
# 第27代，可行解的数量为60
# 第28代，可行解的数量为59
# 第29代，可行解的数量为56
# 第30代，可行解的数量为58
# 第31代，可行解的数量为59
# 第32代，可行解的数量为60
# 第33代，可行解的数量为59
# 第34代，可行解的数量为60
# 第35代，可行解的数量为59
# 第36代，可行解的数量为58
# 第37代，可行解的数量为60
# 第38代，可行解的数量为59
# 第39代，可行解的数量为59
# 第40代，可行解的数量为60
# 第0代，可行解的数量为10
# 第1代，可行解的数量为19
# 第2代，可行解的数量为22
# 第3代，可行解的数量为35
# 第4代，可行解的数量为45
# 第5代，可行解的数量为44
# 第6代，可行解的数量为50
# 第7代，可行解的数量为44
# 第8代，可行解的数量为56
# 第9代，可行解的数量为51
# 第10代，可行解的数量为50
# 第11代，可行解的数量为50
# 第12代，可行解的数量为55
# 第13代，可行解的数量为54
# 第14代，可行解的数量为54
# 第15代，可行解的数量为54
# 第16代，可行解的数量为57
# 第17代，可行解的数量为53
# 第18代，可行解的数量为56
# 第19代，可行解的数量为57
# 第20代，可行解的数量为56
# 第21代，可行解的数量为60
# 第22代，可行解的数量为59
# 第23代，可行解的数量为57
# 第24代，可行解的数量为56
# 第25代，可行解的数量为60
# 第26代，可行解的数量为57
# 第27代，可行解的数量为59
# 第28代，可行解的数量为59
# 第29代，可行解的数量为60
# 第30代，可行解的数量为59
# 第31代，可行解的数量为60
# 第32代，可行解的数量为59
# 第33代，可行解的数量为59
# 第34代，可行解的数量为60
# 第35代，可行解的数量为60
# 第36代，可行解的数量为60
# 第37代，可行解的数量为59
# 第38代，可行解的数量为60
# 第39代，可行解的数量为60
# 第40代，可行解的数量为60
# 第0代，可行解的数量为7
# 第1代，可行解的数量为11
# 第2代，可行解的数量为16
# 第3代，可行解的数量为24
# 第4代，可行解的数量为30
# 第5代，可行解的数量为41
# 第6代，可行解的数量为40
# 第7代，可行解的数量为48
# 第8代，可行解的数量为44
# 第9代，可行解的数量为43
# 第10代，可行解的数量为40
# 第11代，可行解的数量为41
# 第12代，可行解的数量为38
# 第13代，可行解的数量为42
# 第14代，可行解的数量为39
# 第15代，可行解的数量为40
# 第16代，可行解的数量为42
# 第17代，可行解的数量为44
# 第18代，可行解的数量为37
# 第19代，可行解的数量为37
# 第20代，可行解的数量为39
# 第21代，可行解的数量为46
# 第22代，可行解的数量为43
# 第23代，可行解的数量为43
# 第24代，可行解的数量为48
# 第25代，可行解的数量为43
# 第26代，可行解的数量为46
# 第27代，可行解的数量为40
# 第28代，可行解的数量为42
# 第29代，可行解的数量为43
# 第30代，可行解的数量为41
# 第31代，可行解的数量为44
# 第32代，可行解的数量为44
# 第33代，可行解的数量为47
# 第34代，可行解的数量为47
# 第35代，可行解的数量为45
# 第36代，可行解的数量为45
# 第37代，可行解的数量为43
# 第38代，可行解的数量为43
# 第39代，可行解的数量为40
# 第40代，可行解的数量为40
# 第0代，可行解的数量为6
# 第1代，可行解的数量为14
# 第2代，可行解的数量为25
# 第3代，可行解的数量为37
# 第4代，可行解的数量为40
# 第5代，可行解的数量为40
# 第6代，可行解的数量为46
# 第7代，可行解的数量为41
# 第8代，可行解的数量为35
# 第9代，可行解的数量为40
# 第10代，可行解的数量为37
# 第11代，可行解的数量为40
# 第12代，可行解的数量为41
# 第13代，可行解的数量为36
# 第14代，可行解的数量为41
# 第15代，可行解的数量为42
# 第16代，可行解的数量为37
# 第17代，可行解的数量为41
# 第18代，可行解的数量为41
# 第19代，可行解的数量为40
# 第20代，可行解的数量为39
# 第21代，可行解的数量为43
# 第22代，可行解的数量为40
# 第23代，可行解的数量为42
# 第24代，可行解的数量为41
# 第25代，可行解的数量为39
# 第26代，可行解的数量为39
# 第27代，可行解的数量为42
# 第28代，可行解的数量为41
# 第29代，可行解的数量为32
# 第30代，可行解的数量为39
# 第31代，可行解的数量为41
# 第32代，可行解的数量为39
# 第33代，可行解的数量为41
# 第34代，可行解的数量为41
# 第35代，可行解的数量为39
# 第36代，可行解的数量为36
# 第37代，可行解的数量为38
# 第38代，可行解的数量为41
# 第39代，可行解的数量为35
# 第40代，可行解的数量为44
# 第0代，可行解的数量为6
# 第1代，可行解的数量为13
# 第2代，可行解的数量为23
# 第3代，可行解的数量为30
# 第4代，可行解的数量为39
# 第5代，可行解的数量为38
# 第6代，可行解的数量为41
# 第7代，可行解的数量为41
# 第8代，可行解的数量为43
# 第9代，可行解的数量为43
# 第10代，可行解的数量为44
# 第11代，可行解的数量为40
# 第12代，可行解的数量为38
# 第13代，可行解的数量为40
# 第14代，可行解的数量为44
# 第15代，可行解的数量为44
# 第16代，可行解的数量为45
# 第17代，可行解的数量为39
# 第18代，可行解的数量为40
# 第19代，可行解的数量为42
# 第20代，可行解的数量为46
# 第21代，可行解的数量为42
# 第22代，可行解的数量为45
# 第23代，可行解的数量为44
# 第24代，可行解的数量为38
# 第25代，可行解的数量为41
# 第26代，可行解的数量为43
# 第27代，可行解的数量为43
# 第28代，可行解的数量为40
# 第29代，可行解的数量为42
# 第30代，可行解的数量为41
# 第31代，可行解的数量为42
# 第32代，可行解的数量为42
# 第33代，可行解的数量为36
# 第34代，可行解的数量为45
# 第35代，可行解的数量为43
# 第36代，可行解的数量为42
# 第37代，可行解的数量为43
# 第38代，可行解的数量为40
# 第39代，可行解的数量为40
# 第40代，可行解的数量为43
# 第0代，可行解的数量为8
# 第1代，可行解的数量为13
# 第2代，可行解的数量为21
# 第3代，可行解的数量为30
# 第4代，可行解的数量为39
# 第5代，可行解的数量为39
# 第6代，可行解的数量为36
# 第7代，可行解的数量为38
# 第8代，可行解的数量为40
# 第9代，可行解的数量为35
# 第10代，可行解的数量为39
# 第11代，可行解的数量为36
# 第12代，可行解的数量为35
# 第13代，可行解的数量为38
# 第14代，可行解的数量为43
# 第15代，可行解的数量为35
# 第16代，可行解的数量为38
# 第17代，可行解的数量为37
# 第18代，可行解的数量为37
# 第19代，可行解的数量为37
# 第20代，可行解的数量为37
# 第21代，可行解的数量为37
# 第22代，可行解的数量为40
# 第23代，可行解的数量为40
# 第24代，可行解的数量为38
# 第25代，可行解的数量为39
# 第26代，可行解的数量为36
# 第27代，可行解的数量为36
# 第28代，可行解的数量为41
# 第29代，可行解的数量为38
# 第30代，可行解的数量为35
# 第31代，可行解的数量为37
# 第32代，可行解的数量为37
# 第33代，可行解的数量为39
# 第34代，可行解的数量为37
# 第35代，可行解的数量为38
# 第36代，可行解的数量为36
# 第37代，可行解的数量为40
# 第38代，可行解的数量为39
# 第39代，可行解的数量为42
# 第40代，可行解的数量为39
# 第0代，可行解的数量为17
# 第1代，可行解的数量为27
# 第2代，可行解的数量为36
# 第3代，可行解的数量为36
# 第4代，可行解的数量为39
# 第5代，可行解的数量为39
# 第6代，可行解的数量为40
# 第7代，可行解的数量为42
# 第8代，可行解的数量为42
# 第9代，可行解的数量为39
# 第10代，可行解的数量为42
# 第11代，可行解的数量为47
# 第12代，可行解的数量为39
# 第13代，可行解的数量为43
# 第14代，可行解的数量为42
# 第15代，可行解的数量为41
# 第16代，可行解的数量为47
# 第17代，可行解的数量为48
# 第18代，可行解的数量为48
# 第19代，可行解的数量为39
# 第20代，可行解的数量为46
# 第21代，可行解的数量为45
# 第22代，可行解的数量为43
# 第23代，可行解的数量为48
# 第24代，可行解的数量为48
# 第25代，可行解的数量为49
# 第26代，可行解的数量为44
# 第27代，可行解的数量为51
# 第28代，可行解的数量为54
# 第29代，可行解的数量为49
# 第30代，可行解的数量为48
# 第31代，可行解的数量为49
# 第32代，可行解的数量为51
# 第33代，可行解的数量为47
# 第34代，可行解的数量为45
# 第35代，可行解的数量为53
# 第36代，可行解的数量为48
# 第37代，可行解的数量为45
# 第38代，可行解的数量为49
# 第39代，可行解的数量为53
# 第40代，可行解的数量为51
# 第0代，可行解的数量为17
# 第1代，可行解的数量为25
# 第2代，可行解的数量为36
# 第3代，可行解的数量为45
# 第4代，可行解的数量为46
# 第5代，可行解的数量为44
# 第6代，可行解的数量为45
# 第7代，可行解的数量为43
# 第8代，可行解的数量为39
# 第9代，可行解的数量为43
# 第10代，可行解的数量为43
# 第11代，可行解的数量为41
# 第12代，可行解的数量为48
# 第13代，可行解的数量为42
# 第14代，可行解的数量为44
# 第15代，可行解的数量为45
# 第16代，可行解的数量为48
# 第17代，可行解的数量为41
# 第18代，可行解的数量为48
# 第19代，可行解的数量为39
# 第20代，可行解的数量为38
# 第21代，可行解的数量为47
# 第22代，可行解的数量为46
# 第23代，可行解的数量为40
# 第24代，可行解的数量为46
# 第25代，可行解的数量为38
# 第26代，可行解的数量为40
# 第27代，可行解的数量为48
# 第28代，可行解的数量为43
# 第29代，可行解的数量为41
# 第30代，可行解的数量为45
# 第31代，可行解的数量为43
# 第32代，可行解的数量为45
# 第33代，可行解的数量为44
# 第34代，可行解的数量为39
# 第35代，可行解的数量为44
# 第36代，可行解的数量为42
# 第37代，可行解的数量为40
# 第38代，可行解的数量为47
# 第39代，可行解的数量为44
# 第40代，可行解的数量为39
# 第0代，可行解的数量为18
# 第1代，可行解的数量为27
# 第2代，可行解的数量为39
# 第3代，可行解的数量为36
# 第4代，可行解的数量为36
# 第5代，可行解的数量为45
# 第6代，可行解的数量为38
# 第7代，可行解的数量为44
# 第8代，可行解的数量为42
# 第9代，可行解的数量为43
# 第10代，可行解的数量为37
# 第11代，可行解的数量为43
# 第12代，可行解的数量为36
# 第13代，可行解的数量为41
# 第14代，可行解的数量为46
# 第15代，可行解的数量为38
# 第16代，可行解的数量为37
# 第17代，可行解的数量为40
# 第18代，可行解的数量为39
# 第19代，可行解的数量为40
# 第20代，可行解的数量为46
# 第21代，可行解的数量为41
# 第22代，可行解的数量为38
# 第23代，可行解的数量为44
# 第24代，可行解的数量为38
# 第25代，可行解的数量为43
# 第26代，可行解的数量为45
# 第27代，可行解的数量为46
# 第28代，可行解的数量为42
# 第29代，可行解的数量为47
# 第30代，可行解的数量为45
# 第31代，可行解的数量为45
# 第32代，可行解的数量为45
# 第33代，可行解的数量为46
# 第34代，可行解的数量为50
# 第35代，可行解的数量为46
# 第36代，可行解的数量为43
# 第37代，可行解的数量为46
# 第38代，可行解的数量为44
# 第39代，可行解的数量为49
# 第40代，可行解的数量为50
# 第0代，可行解的数量为17
# 第1代，可行解的数量为26
# 第2代，可行解的数量为41
# 第3代，可行解的数量为39
# 第4代，可行解的数量为38
# 第5代，可行解的数量为39
# 第6代，可行解的数量为37
# 第7代，可行解的数量为41
# 第8代，可行解的数量为37
# 第9代，可行解的数量为39
# 第10代，可行解的数量为41
# 第11代，可行解的数量为37
# 第12代，可行解的数量为37
# 第13代，可行解的数量为40
# 第14代，可行解的数量为39
# 第15代，可行解的数量为42
# 第16代，可行解的数量为43
# 第17代，可行解的数量为40
# 第18代，可行解的数量为43
# 第19代，可行解的数量为43
# 第20代，可行解的数量为44
# 第21代，可行解的数量为47
# 第22代，可行解的数量为35
# 第23代，可行解的数量为38
# 第24代，可行解的数量为43
# 第25代，可行解的数量为40
# 第26代，可行解的数量为41
# 第27代，可行解的数量为43
# 第28代，可行解的数量为41
# 第29代，可行解的数量为41
# 第30代，可行解的数量为41
# 第31代，可行解的数量为43
# 第32代，可行解的数量为40
# 第33代，可行解的数量为44
# 第34代，可行解的数量为45
# 第35代，可行解的数量为41
# 第36代，可行解的数量为46
# 第37代，可行解的数量为46
# 第38代，可行解的数量为50
# 第39代，可行解的数量为44
# 第40代，可行解的数量为42
# 第0代，可行解的数量为6
# 第1代，可行解的数量为8
# 第2代，可行解的数量为10
# 第3代，可行解的数量为16
# 第4代，可行解的数量为21
# 第5代，可行解的数量为29
# 第6代，可行解的数量为38
# 第7代，可行解的数量为43
# 第8代，可行解的数量为45
# 第9代，可行解的数量为42
# 第10代，可行解的数量为35
# 第11代，可行解的数量为41
# 第12代，可行解的数量为38
# 第13代，可行解的数量为41
# 第14代，可行解的数量为47
# 第15代，可行解的数量为43
# 第16代，可行解的数量为42
# 第17代，可行解的数量为45
# 第18代，可行解的数量为41
# 第19代，可行解的数量为40
# 第20代，可行解的数量为46
# 第21代，可行解的数量为41
# 第22代，可行解的数量为43
# 第23代，可行解的数量为49
# 第24代，可行解的数量为48
# 第25代，可行解的数量为38
# 第26代，可行解的数量为42
# 第27代，可行解的数量为44
# 第28代，可行解的数量为45
# 第29代，可行解的数量为44
# 第30代，可行解的数量为41
# 第31代，可行解的数量为47
# 第32代，可行解的数量为39
# 第33代，可行解的数量为46
# 第34代，可行解的数量为41
# 第35代，可行解的数量为41
# 第36代，可行解的数量为51
# 第37代，可行解的数量为42
# 第38代，可行解的数量为45
# 第39代，可行解的数量为38
# 第40代，可行解的数量为48
# 第0代，可行解的数量为2
# 第1代，可行解的数量为7
# 第2代，可行解的数量为16
# 第3代，可行解的数量为22
# 第4代，可行解的数量为26
# 第5代，可行解的数量为34
# 第6代，可行解的数量为34
# 第7代，可行解的数量为35
# 第8代，可行解的数量为39
# 第9代，可行解的数量为40
# 第10代，可行解的数量为40
# 第11代，可行解的数量为36
# 第12代，可行解的数量为40
# 第13代，可行解的数量为39
# 第14代，可行解的数量为37
# 第15代，可行解的数量为46
# 第16代，可行解的数量为40
# 第17代，可行解的数量为48
# 第18代，可行解的数量为44
# 第19代，可行解的数量为42
# 第20代，可行解的数量为47
# 第21代，可行解的数量为47
# 第22代，可行解的数量为46
# 第23代，可行解的数量为48
# 第24代，可行解的数量为47
# 第25代，可行解的数量为49
# 第26代，可行解的数量为46
# 第27代，可行解的数量为44
# 第28代，可行解的数量为52
# 第29代，可行解的数量为48
# 第30代，可行解的数量为48
# 第31代，可行解的数量为53
# 第32代，可行解的数量为45
# 第33代，可行解的数量为47
# 第34代，可行解的数量为49
# 第35代，可行解的数量为51
# 第36代，可行解的数量为53
# 第37代，可行解的数量为49
# 第38代，可行解的数量为46
# 第39代，可行解的数量为47
# 第40代，可行解的数量为50
# 第0代，可行解的数量为5
# 第1代，可行解的数量为9
# 第2代，可行解的数量为12
# 第3代，可行解的数量为17
# 第4代，可行解的数量为20
# 第5代，可行解的数量为25
# 第6代，可行解的数量为33
# 第7代，可行解的数量为37
# 第8代，可行解的数量为44
# 第9代，可行解的数量为42
# 第10代，可行解的数量为42
# 第11代，可行解的数量为44
# 第12代，可行解的数量为38
# 第13代，可行解的数量为40
# 第14代，可行解的数量为43
# 第15代，可行解的数量为42
# 第16代，可行解的数量为45
# 第17代，可行解的数量为40
# 第18代，可行解的数量为42
# 第19代，可行解的数量为41
# 第20代，可行解的数量为46
# 第21代，可行解的数量为47
# 第22代，可行解的数量为48
# 第23代，可行解的数量为51
# 第24代，可行解的数量为50
# 第25代，可行解的数量为50
# 第26代，可行解的数量为47
# 第27代，可行解的数量为53
# 第28代，可行解的数量为47
# 第29代，可行解的数量为48
# 第30代，可行解的数量为46
# 第31代，可行解的数量为49
# 第32代，可行解的数量为49
# 第33代，可行解的数量为50
# 第34代，可行解的数量为49
# 第35代，可行解的数量为49
# 第36代，可行解的数量为48
# 第37代，可行解的数量为51
# 第38代，可行解的数量为50
# 第39代，可行解的数量为50
# 第40代，可行解的数量为51
# 第0代，可行解的数量为4
# 第1代，可行解的数量为5
# 第2代，可行解的数量为6
# 第3代，可行解的数量为13
# 第4代，可行解的数量为15
# 第5代，可行解的数量为17
# 第6代，可行解的数量为26
# 第7代，可行解的数量为32
# 第8代，可行解的数量为38
# 第9代，可行解的数量为35
# 第10代，可行解的数量为35
# 第11代，可行解的数量为39
# 第12代，可行解的数量为42
# 第13代，可行解的数量为39
# 第14代，可行解的数量为40
# 第15代，可行解的数量为38
# 第16代，可行解的数量为40
# 第17代，可行解的数量为40
# 第18代，可行解的数量为40
# 第19代，可行解的数量为41
# 第20代，可行解的数量为42
# 第21代，可行解的数量为46
# 第22代，可行解的数量为44
# 第23代，可行解的数量为44
# 第24代，可行解的数量为46
# 第25代，可行解的数量为42
# 第26代，可行解的数量为42
# 第27代，可行解的数量为45
# 第28代，可行解的数量为46
# 第29代，可行解的数量为43
# 第30代，可行解的数量为42
# 第31代，可行解的数量为42
# 第32代，可行解的数量为46
# 第33代，可行解的数量为45
# 第34代，可行解的数量为44
# 第35代，可行解的数量为43
# 第36代，可行解的数量为49
# 第37代，可行解的数量为48
# 第38代，可行解的数量为46
# 第39代，可行解的数量为46
# 第40代，可行解的数量为51
# 第0代，可行解的数量为16
# 第1代，可行解的数量为30
# 第2代，可行解的数量为50
# 第3代，可行解的数量为47
# 第4代，可行解的数量为48
# 第5代，可行解的数量为38
# 第6代，可行解的数量为51
# 第7代，可行解的数量为48
# 第8代，可行解的数量为54
# 第9代，可行解的数量为48
# 第10代，可行解的数量为49
# 第11代，可行解的数量为48
# 第12代，可行解的数量为49
# 第13代，可行解的数量为49
# 第14代，可行解的数量为54
# 第15代，可行解的数量为48
# 第16代，可行解的数量为47
# 第17代，可行解的数量为47
# 第18代，可行解的数量为46
# 第19代，可行解的数量为52
# 第20代，可行解的数量为53
# 第21代，可行解的数量为54
# 第22代，可行解的数量为50
# 第23代，可行解的数量为52
# 第24代，可行解的数量为50
# 第25代，可行解的数量为49
# 第26代，可行解的数量为45
# 第27代，可行解的数量为49
# 第28代，可行解的数量为50
# 第29代，可行解的数量为54
# 第30代，可行解的数量为56
# 第31代，可行解的数量为49
# 第32代，可行解的数量为47
# 第33代，可行解的数量为48
# 第34代，可行解的数量为53
# 第35代，可行解的数量为49
# 第36代，可行解的数量为49
# 第37代，可行解的数量为52
# 第38代，可行解的数量为53
# 第39代，可行解的数量为53
# 第40代，可行解的数量为49
# 第0代，可行解的数量为12
# 第1代，可行解的数量为27
# 第2代，可行解的数量为43
# 第3代，可行解的数量为50
# 第4代，可行解的数量为49
# 第5代，可行解的数量为46
# 第6代，可行解的数量为48
# 第7代，可行解的数量为53
# 第8代，可行解的数量为51
# 第9代，可行解的数量为47
# 第10代，可行解的数量为52
# 第11代，可行解的数量为51
# 第12代，可行解的数量为52
# 第13代，可行解的数量为51
# 第14代，可行解的数量为44
# 第15代，可行解的数量为53
# 第16代，可行解的数量为49
# 第17代，可行解的数量为53
# 第18代，可行解的数量为51
# 第19代，可行解的数量为48
# 第20代，可行解的数量为54
# 第21代，可行解的数量为51
# 第22代，可行解的数量为48
# 第23代，可行解的数量为51
# 第24代，可行解的数量为51
# 第25代，可行解的数量为51
# 第26代，可行解的数量为54
# 第27代，可行解的数量为52
# 第28代，可行解的数量为51
# 第29代，可行解的数量为48
# 第30代，可行解的数量为50
# 第31代，可行解的数量为52
# 第32代，可行解的数量为55
# 第33代，可行解的数量为53
# 第34代，可行解的数量为54
# 第35代，可行解的数量为51
# 第36代，可行解的数量为53
# 第37代，可行解的数量为51
# 第38代，可行解的数量为53
# 第39代，可行解的数量为54
# 第40代，可行解的数量为57
# 第0代，可行解的数量为15
# 第1代，可行解的数量为32
# 第2代，可行解的数量为45
# 第3代，可行解的数量为43
# 第4代，可行解的数量为49
# 第5代，可行解的数量为45
# 第6代，可行解的数量为47
# 第7代，可行解的数量为46
# 第8代，可行解的数量为47
# 第9代，可行解的数量为49
# 第10代，可行解的数量为51
# 第11代，可行解的数量为44
# 第12代，可行解的数量为47
# 第13代，可行解的数量为50
# 第14代，可行解的数量为45
# 第15代，可行解的数量为49
# 第16代，可行解的数量为47
# 第17代，可行解的数量为53
# 第18代，可行解的数量为54
# 第19代，可行解的数量为51
# 第20代，可行解的数量为47
# 第21代，可行解的数量为49
# 第22代，可行解的数量为47
# 第23代，可行解的数量为50
# 第24代，可行解的数量为51
# 第25代，可行解的数量为53
# 第26代，可行解的数量为51
# 第27代，可行解的数量为48
# 第28代，可行解的数量为51
# 第29代，可行解的数量为47
# 第30代，可行解的数量为51
# 第31代，可行解的数量为47
# 第32代，可行解的数量为46
# 第33代，可行解的数量为52
# 第34代，可行解的数量为52
# 第35代，可行解的数量为52
# 第36代，可行解的数量为49
# 第37代，可行解的数量为52
# 第38代，可行解的数量为51
# 第39代，可行解的数量为53
# 第40代，可行解的数量为49
# 第0代，可行解的数量为11
# 第1代，可行解的数量为25
# 第2代，可行解的数量为37
# 第3代，可行解的数量为46
# 第4代，可行解的数量为46
# 第5代，可行解的数量为43
# 第6代，可行解的数量为47
# 第7代，可行解的数量为44
# 第8代，可行解的数量为50
# 第9代，可行解的数量为46
# 第10代，可行解的数量为49
# 第11代，可行解的数量为45
# 第12代，可行解的数量为49
# 第13代，可行解的数量为46
# 第14代，可行解的数量为50
# 第15代，可行解的数量为52
# 第16代，可行解的数量为48
# 第17代，可行解的数量为48
# 第18代，可行解的数量为49
# 第19代，可行解的数量为50
# 第20代，可行解的数量为53
# 第21代，可行解的数量为49
# 第22代，可行解的数量为50
# 第23代，可行解的数量为49
# 第24代，可行解的数量为52
# 第25代，可行解的数量为54
# 第26代，可行解的数量为49
# 第27代，可行解的数量为57
# 第28代，可行解的数量为53
# 第29代，可行解的数量为54
# 第30代，可行解的数量为56
# 第31代，可行解的数量为52
# 第32代，可行解的数量为50
# 第33代，可行解的数量为55
# 第34代，可行解的数量为58
# 第35代，可行解的数量为56
# 第36代，可行解的数量为57
# 第37代，可行解的数量为54
# 第38代，可行解的数量为57
# 第39代，可行解的数量为52
# 第40代，可行解的数量为53
# *****************算法执行结束！******************
# German的第1次运行的结果为：[7, 13, 25, 45, 47, 48, 51, 53, 55, 54, 53, 55, 53, 54, 59, 59, 59, 58, 60, 60, 60, 59, 60, 56, 59, 58, 59, 59, 59, 59, 58, 60, 57, 59, 60, 60, 58, 60, 58, 59, 59]
# German的第2次运行的结果为：[12, 23, 40, 48, 48, 52, 52, 56, 54, 52, 56, 54, 57, 56, 56, 57, 57, 55, 57, 56, 60, 60, 58, 58, 60, 58, 58, 60, 59, 59, 59, 60, 58, 59, 60, 58, 60, 58, 60, 60, 58]
# German的第3次运行的结果为：[9, 15, 27, 43, 43, 42, 51, 50, 50, 48, 56, 51, 52, 51, 56, 54, 59, 55, 58, 57, 59, 56, 57, 58, 57, 58, 56, 60, 59, 56, 58, 59, 60, 59, 60, 59, 58, 60, 59, 59, 60]
# German的第4次运行的结果为：[10, 19, 22, 35, 45, 44, 50, 44, 56, 51, 50, 50, 55, 54, 54, 54, 57, 53, 56, 57, 56, 60, 59, 57, 56, 60, 57, 59, 59, 60, 59, 60, 59, 59, 60, 60, 60, 59, 60, 60, 60]
# Nursery的第0次运行的结果为：[7, 11, 16, 24, 30, 41, 40, 48, 44, 43, 40, 41, 38, 42, 39, 40, 42, 44, 37, 37, 39, 46, 43, 43, 48, 43, 46, 40, 42, 43, 41, 44, 44, 47, 47, 45, 45, 43, 43, 40, 40]
# Nursery的第1次运行的结果为：[6, 14, 25, 37, 40, 40, 46, 41, 35, 40, 37, 40, 41, 36, 41, 42, 37, 41, 41, 40, 39, 43, 40, 42, 41, 39, 39, 42, 41, 32, 39, 41, 39, 41, 41, 39, 36, 38, 41, 35, 44]
# Nursery的第2次运行的结果为：[6, 13, 23, 30, 39, 38, 41, 41, 43, 43, 44, 40, 38, 40, 44, 44, 45, 39, 40, 42, 46, 42, 45, 44, 38, 41, 43, 43, 40, 42, 41, 42, 42, 36, 45, 43, 42, 43, 40, 40, 43]
# Nursery的第3次运行的结果为：[8, 13, 21, 30, 39, 39, 36, 38, 40, 35, 39, 36, 35, 38, 43, 35, 38, 37, 37, 37, 37, 37, 40, 40, 38, 39, 36, 36, 41, 38, 35, 37, 37, 39, 37, 38, 36, 40, 39, 42, 39]
# Penbased的第4次运行的结果为：[17, 27, 36, 36, 39, 39, 40, 42, 42, 39, 42, 47, 39, 43, 42, 41, 47, 48, 48, 39, 46, 45, 43, 48, 48, 49, 44, 51, 54, 49, 48, 49, 51, 47, 45, 53, 48, 45, 49, 53, 51]
# Penbased的第0次运行的结果为：[17, 25, 36, 45, 46, 44, 45, 43, 39, 43, 43, 41, 48, 42, 44, 45, 48, 41, 48, 39, 38, 47, 46, 40, 46, 38, 40, 48, 43, 41, 45, 43, 45, 44, 39, 44, 42, 40, 47, 44, 39]
# Penbased的第1次运行的结果为：[18, 27, 39, 36, 36, 45, 38, 44, 42, 43, 37, 43, 36, 41, 46, 38, 37, 40, 39, 40, 46, 41, 38, 44, 38, 43, 45, 46, 42, 47, 45, 45, 45, 46, 50, 46, 43, 46, 44, 49, 50]
# Penbased的第2次运行的结果为：[17, 26, 41, 39, 38, 39, 37, 41, 37, 39, 41, 37, 37, 40, 39, 42, 43, 40, 43, 43, 44, 47, 35, 38, 43, 40, 41, 43, 41, 41, 41, 43, 40, 44, 45, 41, 46, 46, 50, 44, 42]
# Contraceptive的第3次运行的结果为：[6, 8, 10, 16, 21, 29, 38, 43, 45, 42, 35, 41, 38, 41, 47, 43, 42, 45, 41, 40, 46, 41, 43, 49, 48, 38, 42, 44, 45, 44, 41, 47, 39, 46, 41, 41, 51, 42, 45, 38, 48]
# Contraceptive的第4次运行的结果为：[2, 7, 16, 22, 26, 34, 34, 35, 39, 40, 40, 36, 40, 39, 37, 46, 40, 48, 44, 42, 47, 47, 46, 48, 47, 49, 46, 44, 52, 48, 48, 53, 45, 47, 49, 51, 53, 49, 46, 47, 50]
# Contraceptive的第0次运行的结果为：[5, 9, 12, 17, 20, 25, 33, 37, 44, 42, 42, 44, 38, 40, 43, 42, 45, 40, 42, 41, 46, 47, 48, 51, 50, 50, 47, 53, 47, 48, 46, 49, 49, 50, 49, 49, 48, 51, 50, 50, 51]
# Contraceptive的第1次运行的结果为：[4, 5, 6, 13, 15, 17, 26, 32, 38, 35, 35, 39, 42, 39, 40, 38, 40, 40, 40, 41, 42, 46, 44, 44, 46, 42, 42, 45, 46, 43, 42, 42, 46, 45, 44, 43, 49, 48, 46, 46, 51]
# USPS的第2次运行的结果为：[16, 30, 50, 47, 48, 38, 51, 48, 54, 48, 49, 48, 49, 49, 54, 48, 47, 47, 46, 52, 53, 54, 50, 52, 50, 49, 45, 49, 50, 54, 56, 49, 47, 48, 53, 49, 49, 52, 53, 53, 49]
# USPS的第3次运行的结果为：[12, 27, 43, 50, 49, 46, 48, 53, 51, 47, 52, 51, 52, 51, 44, 53, 49, 53, 51, 48, 54, 51, 48, 51, 51, 51, 54, 52, 51, 48, 50, 52, 55, 53, 54, 51, 53, 51, 53, 54, 57]
# USPS的第4次运行的结果为：[15, 32, 45, 43, 49, 45, 47, 46, 47, 49, 51, 44, 47, 50, 45, 49, 47, 53, 54, 51, 47, 49, 47, 50, 51, 53, 51, 48, 51, 47, 51, 47, 46, 52, 52, 52, 49, 52, 51, 53, 49]
# USPS的第0次运行的结果为：[11, 25, 37, 46, 46, 43, 47, 44, 50, 46, 49, 45, 49, 46, 50, 52, 48, 48, 49, 50, 53, 49, 50, 49, 52, 54, 49, 57, 53, 54, 56, 52, 50, 55, 58, 56, 57, 54, 57, 52, 53]

# %%
a=np.array(datasets_sfe_results)
