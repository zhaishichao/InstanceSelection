# %% [markdown]
# # E-SEIC
# Selection of evolutionary instances with constraints for unbalanced datasets

# %%
from utils.dataset_utils import get_distribution, k_fold_cross_validation
from instance_selection.parameter.parameter import *  # 导入参数的设定
from instance_selection_encapsulation.operator.init_toolbox import init_toolbox_eseic
from instance_selection_encapsulation.operator.metrics import calculate_gmean_mauc, calculate_average_accuracy, \
    calculate_average_gmean_mauc, calculate_accuracy
from instance_selection_encapsulation.operator.genetic_operator import selTournamentNDCD
from instance_selection_encapsulation.operator.ensemble import vote_result_ensembles, ensemble_individuals
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.base import clone
import scipy.io as sio  # 从.mat文件中读取数据集
import random
from deap import tools
import warnings
import numpy as np

warnings.filterwarnings("ignore")  # 忽略警告

DATASET = Pen_Digits  # 数据集名称（包含对应的参数配置）

datasetname = DATASET.DATASETNAME.split('.')[0]
mat_data = sio.loadmat(IMBALANCED_DATASET_PATH + DATASET.DATASETNAME)  # 加载、划分数据集
x = mat_data['X']
y = mat_data['Y'][:, 0]  # mat_data['Y']得到的形状为[n,1]，通过[:,0]，得到形状[n,]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y,
                                                    random_state=RANDOM_SEED)  # 划分数据集
scaler = StandardScaler()  # 数据的标准化
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

unique_elements_all, classes_all, counts_all = get_distribution(y)  # 获取原始数据集分布
unique_elements_train, classes_train, counts_train = get_distribution(y_train)  # 获取训练集分布
unique_elements_test, classes_test, counts_test = get_distribution(y_test)  # 获取测试集分布
print(datasetname + f' distribution: {counts_all}')
print(f'trainset distribution: {counts_train}')
print(f'testset distribution: {counts_test}')

model = MLPClassifier(hidden_layer_sizes=(DATASET.HIDDEN_SIZE,), max_iter=DATASET.MAX_ITER,
                      random_state=RANDOM_SEED, learning_rate_init=DATASET.LEARNING_RATE)

weights_train = (1 / counts_train.astype(float)) / np.sum(1 / counts_train.astype(float))  # 计算每个类的权重，用于计算每个类别的权重
weights_test = (1 / counts_test.astype(float)) / np.sum(1 / counts_test.astype(float))  # 计算每个类的权重，用于计算每个类别的权重

num_instances = int(np.ceil(counts_train.min() * 0.9))  # 取最小数量的类的0.9（向下取整）
print("最小数量:", num_instances)

y_train_pred_proba = k_fold_cross_validation(model=clone(model), X=x_train, y=y_train, n_splits=N_SPLITS - 2,
                                             method='soft',
                                             random_state=RANDOM_SEED)  # 交叉验证得到软标签
# 将概率转化为预测结果
y_train_pred = np.argmax(y_train_pred_proba, axis=1)

Acc1, Acc2, Acc3 = calculate_accuracy(y_train_pred, y_train, weights_train)
constraints = [Acc1, Acc2, Acc3]
# Out:
# Pen_Digits distribution: [9937 1055]
# trainset distribution: [6956  738]
# testset distribution: [2981  317]
# 最小数量: 665

# %% [markdown]
# ## E-SEIC

# %%
toolbox = init_toolbox_eseic(model, x_train, y_train, weights_train, constraints, n_splits=N_SPLITS - 2,
                             random_seed=RANDOM_SEED)  # 初始化toolbox


def main(x_train, y_train, model, balanced_method='balanced'):
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    logbook = tools.Logbook()
    logbook.header = "gen", "feasible", "ensembles_size", "avg_gmean", "avg_mauc", "avg_acc2"
    ####################################种群的初始化###########################
    pop = toolbox.population(n=POPSIZE)  # 个体编码默认全为0
    pop = toolbox.init_population(pop, balanced_method=balanced_method)  # 初始化种群中的个体
    toolbox.evaluate(pop)  # 计算个体的适应度
    ####################################种群的迭代#################################################
    for gen in range(1, NGEN + 1):
        offspring = selTournamentNDCD(pop, POPSIZE, tournsize=3)  # 锦标赛选择（1、先根据非支配排序的等级2、再根据拥挤距离）
        offspring = [toolbox.clone(ind) for ind in offspring]
        for i in range(0, len(offspring) - 1, 2):
            if random.random() <= CXPB:
                offspring[i], offspring[i + 1] = toolbox.mate(offspring[i], offspring[i + 1])  # 单点交叉
            offspring[i] = toolbox.mutate(offspring[i], MR)[0]  # 二进制反转突变
            offspring[i + 1] = toolbox.mutate(offspring[i + 1], MR)[0]  # 二进制反转突变
            del offspring[i].fitness.values, offspring[i + 1].fitness.values
        #############################################################合并、去重#####################################################
        offspring = toolbox.individuals_constraints(offspring)  # 限制每个类至少有一个实例被选择
        pop = pop + offspring  # 种群的合并
        pop, _ = toolbox.remove_duplicates(pop)  # 去重
        while len(pop) < POPSIZE:  # 保证种群大小为POPSIZE
            add_individual = []
            num_add = POPSIZE - len(pop)
            for i in range(0, num_add):
                index = random.randint(0, len(offspring) - 1)  # 在0-len(offspring)范围内随机产生一个索引
                offspring[index] = toolbox.mutate(offspring[index], MR)[0]  # 选择index对应的个体进行突变
                del offspring[index].fitness.values
                add_individual.append(offspring[index])
            add_individual = toolbox.individuals_constraints(add_individual)  # 限制每个类至少有一个实例被选择
            pop = pop + add_individual  # 种群的合并
            pop, _ = toolbox.remove_duplicates(pop)  # 去重
        pop = toolbox.individuals_constraints(pop)  # 限制每个类至少有5个实例被选择
        toolbox.evaluate(pop)  # 计算新种群适应度
        ###############################################得到pareto_fronts############################################
        feasible_pop, infeasible_pop = toolbox.get_feasible_infeasible(pop)  # 得到可行解与不可行解
        if len(feasible_pop) >= POPSIZE:
            pop, pareto_fronts = toolbox.select(feasible_pop, POPSIZE)
            # ensembles = pareto_fronts[0]  # pareto_first_front
            ensembles = pop  # pop均为可行解，则集成pop中所有个体
        elif len(feasible_pop) > 0:
            pop = feasible_pop + infeasible_pop[:POPSIZE - len(feasible_pop)]  # 在不可行解中选取违约程度小的个体，保证pop数量为POPSIZE
            # ensembles = tools.sortNondominated(feasible_pop, len(feasible_pop))[0]  # pareto_first_front
            ensembles = feasible_pop  # 只集成可行解
            # ensembles = pop  # 集成种群
        else:
            pop = feasible_pop + infeasible_pop[:POPSIZE - len(feasible_pop)]  # 加入不可行解中违约程度小的个体，保证pop数量为POPSIZE
            ensembles = [infeasible_pop[0]]  # 没有可行解，集成不可行解中第一个个体
            # ensembles = pop  # 集成种群
        avg_gmean, avg_mauc = calculate_average_gmean_mauc(ensembles)  # 计算gmean、mauc的平均值
        _, avg_acc2, _ = calculate_average_accuracy(ensembles)  # 计算acc1、acc2、acc3的平均值

        record = stats.compile(pop)
        logbook.record(gen=gen, feasible=len(feasible_pop), ensembles_size=len(ensembles), avg_gmean=avg_gmean,
                       avg_mauc=avg_mauc, avg_acc2=avg_acc2, **record)
        # print(logbook.stream)
    ensemble_classifiers = ensemble_individuals(ensembles, model, x_train, y_train)
    return ensemble_classifiers


if __name__ == "__main__":
    print("*****************算法开始执行：******************")
    num_run = 40  # 运行次数
    ensembles_results = [[] for _ in range(num_run)]
    for i in range(num_run):
        ensemble_classifiers = main(x_train, y_train, model=model, balanced_method='random')
        for i,classifier in enumerate(ensemble_classifiers):
            ind_pred = classifier.predict(x_test)  # 计算accuracy、PPV
            ind_proba = classifier.predict_proba(x_test)
            gmean, mauc, recall_per_class = calculate_gmean_mauc(ind_proba, y_test)
            # 输出gmean mauc recall_per_class
            print(f"\t第{i+1}个分类器分类结果：Recall{recall_per_class}，Gmean：{gmean}，mAUC：{mauc}")
        vote_pred_prob = vote_result_ensembles(ensemble_classifiers, x_test)  # 默认预测结果是软标签
        vote_pred = np.argmax(vote_pred_prob, axis=1)
        gmean, mauc, recall_per_class = calculate_gmean_mauc(vote_pred_prob, y_test)
        acc1, acc2, acc3 = calculate_accuracy(vote_pred, y_test, weights_test)
        ensembles_results[i] = [gmean, mauc, acc1, acc2, acc3, len(ensemble_classifiers)]
        print(
            f"第{i + 1}次执行：Gmean：{gmean}，mAUC：{mauc}，Acc1：{acc1}，Acc2：{acc2}，Acc3：{acc3}，集成的数量：{len(ensemble_classifiers)}")
    print("*****************算法执行结束！******************")
    ensembles_result_mean = np.mean(ensembles_results, axis=0)
    print(f'集成分类结果（平均值）：{ensembles_result_mean}')
# Out:
# *****************算法开始执行：******************
# 	第1个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999946
# 	第2个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999978
# 	第3个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999932
# 	第4个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999958
# 	第5个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.999969
# 	第6个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999944
# 	第7个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999953
# 	第8个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999957
# 	第9个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999972
# 	第10个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999983
# 	第11个分类器分类结果：Recall[0.99899363 1.        ]，Gmean：0.999497，mAUC：0.999997
# 	第12个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999952
# 	第13个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.99999
# 	第14个分类器分类结果：Recall[0.99832271 0.98107256]，Gmean：0.98966，mAUC：0.999919
# 	第15个分类器分类结果：Recall[0.99664542 0.98107256]，Gmean：0.988828，mAUC：0.999818
# 	第16个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999982
# 	第17个分类器分类结果：Recall[0.99765179 0.99684543]，Gmean：0.997249，mAUC：0.999946
# 	第18个分类器分类结果：Recall[0.99698088 0.98422713]，Gmean：0.990583，mAUC：0.999678
# 	第19个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999941
# 	第20个分类器分类结果：Recall[0.99932908 0.97476341]，Gmean：0.98697，mAUC：0.999881
# 	第21个分类器分类结果：Recall[1.         0.95899054]，Gmean：0.979281，mAUC：0.999951
# 	第22个分类器分类结果：Recall[0.99832271 0.97791798]，Gmean：0.988068，mAUC：0.999944
# 	第23个分类器分类结果：Recall[0.99563905 0.95583596]，Gmean：0.975535，mAUC：0.998932
# 	第24个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.99997
# 	第25个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999932
# 	第26个分类器分类结果：Recall[0.99932908 0.99684543]，Gmean：0.998086，mAUC：0.999947
# 	第27个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999971
# 	第28个分类器分类结果：Recall[0.99865817 0.99369085]，Gmean：0.996171，mAUC：0.999968
# 	第29个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999992
# 	第30个分类器分类结果：Recall[1.         0.97476341]，Gmean：0.987301，mAUC：0.999959
# 第30次执行：Gmean：0.996506，mAUC：0.99999，Acc1：0.998787，Acc2：0.99651，Acc3：0.497116，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99966454 0.95268139]，Gmean：0.97589，mAUC：0.999744
# 	第2个分类器分类结果：Recall[0.99899363 0.98107256]，Gmean：0.989993，mAUC：0.999888
# 	第3个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999898
# 	第4个分类器分类结果：Recall[0.99865817 0.99053628]，Gmean：0.994589，mAUC：0.999967
# 	第5个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999954
# 	第6个分类器分类结果：Recall[0.99899363 0.98107256]，Gmean：0.989993，mAUC：0.99995
# 	第7个分类器分类结果：Recall[0.99865817 0.98422713]，Gmean：0.991416，mAUC：0.999962
# 	第8个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999974
# 	第9个分类器分类结果：Recall[0.99832271 0.99684543]，Gmean：0.997584，mAUC：0.999978
# 	第10个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999943
# 	第11个分类器分类结果：Recall[0.99329084 0.97791798]，Gmean：0.985574，mAUC：0.998663
# 	第12个分类器分类结果：Recall[0.99664542 1.        ]，Gmean：0.998321，mAUC：0.999964
# 	第13个分类器分类结果：Recall[0.99966454 0.97791798]，Gmean：0.988731，mAUC：0.99996
# 	第14个分类器分类结果：Recall[0.99932908 0.97476341]，Gmean：0.98697，mAUC：0.999951
# 	第15个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999965
# 	第16个分类器分类结果：Recall[0.99899363 0.98107256]，Gmean：0.989993，mAUC：0.999972
# 	第17个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999951
# 	第18个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999962
# 	第19个分类器分类结果：Recall[0.99832271 0.98422713]，Gmean：0.99125，mAUC：0.999845
# 	第20个分类器分类结果：Recall[0.99798725 0.98107256]，Gmean：0.989494，mAUC：0.999914
# 	第21个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999957
# 	第22个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999874
# 	第23个分类器分类结果：Recall[0.99832271 0.99684543]，Gmean：0.997584，mAUC：0.999983
# 	第24个分类器分类结果：Recall[0.99899363 0.97791798]，Gmean：0.9884，mAUC：0.999774
# 	第25个分类器分类结果：Recall[0.99832271 0.97476341]，Gmean：0.986473，mAUC：0.999888
# 	第26个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999732
# 	第27个分类器分类结果：Recall[0.99966454 0.97791798]，Gmean：0.988731，mAUC：0.999872
# 	第28个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999971
# 	第29个分类器分类结果：Recall[0.99698088 0.97476341]，Gmean：0.98581，mAUC：0.999749
# 	第30个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.99996
# 第30次执行：Gmean：0.993337，mAUC：0.999979，Acc1：0.998181，Acc2：0.993355，Acc3：0.494265，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999985
# 	第2个分类器分类结果：Recall[0.99865817 0.97476341]，Gmean：0.986638，mAUC：0.999946
# 	第3个分类器分类结果：Recall[0.99966454 0.97160883]，Gmean：0.985537，mAUC：0.999891
# 	第4个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.999977
# 	第5个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999952
# 	第6个分类器分类结果：Recall[0.99966454 0.97160883]，Gmean：0.985537，mAUC：0.999917
# 	第7个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999975
# 	第8个分类器分类结果：Recall[0.99932908 0.97476341]，Gmean：0.98697，mAUC：0.99997
# 	第9个分类器分类结果：Recall[0.99832271 0.98107256]，Gmean：0.98966，mAUC：0.999598
# 	第10个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999978
# 	第11个分类器分类结果：Recall[0.99698088 0.99053628]，Gmean：0.993753，mAUC：0.999768
# 	第12个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999978
# 	第13个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.999972
# 	第14个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999944
# 	第15个分类器分类结果：Recall[0.99932908 0.95268139]，Gmean：0.975727，mAUC：0.999534
# 	第16个分类器分类结果：Recall[0.99932908 0.97791798]，Gmean：0.988566，mAUC：0.999821
# 	第17个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.99998
# 	第18个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999976
# 	第19个分类器分类结果：Recall[0.99899363 0.97791798]，Gmean：0.9884，mAUC：0.999935
# 	第20个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999959
# 	第21个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999969
# 	第22个分类器分类结果：Recall[0.99932908 0.97791798]，Gmean：0.988566，mAUC：0.999945
# 	第23个分类器分类结果：Recall[0.99832271 0.98422713]，Gmean：0.99125，mAUC：0.999875
# 	第24个分类器分类结果：Recall[0.99966454 0.97791798]，Gmean：0.988731，mAUC：0.999967
# 	第25个分类器分类结果：Recall[0.99798725 0.95583596]，Gmean：0.976684，mAUC：0.999444
# 	第26个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999979
# 	第27个分类器分类结果：Recall[0.99832271 0.99053628]，Gmean：0.994422，mAUC：0.999943
# 	第28个分类器分类结果：Recall[0.99966454 0.97791798]，Gmean：0.988731，mAUC：0.999721
# 	第29个分类器分类结果：Recall[0.99966454 0.97791798]，Gmean：0.988731，mAUC：0.999971
# 	第30个分类器分类结果：Recall[0.99966454 0.92744479]，Gmean：0.962878，mAUC：0.999684
# 第30次执行：Gmean：0.990159，mAUC：0.999983，Acc1：0.997574，Acc2：0.990201，Acc3：0.491414，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999981
# 	第2个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.999949
# 	第3个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999932
# 	第4个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999904
# 	第5个分类器分类结果：Recall[0.99865817 0.95899054]，Gmean：0.978623，mAUC：0.999656
# 	第6个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999944
# 	第7个分类器分类结果：Recall[0.99899363 0.99684543]，Gmean：0.997919，mAUC：0.999963
# 	第8个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999962
# 	第9个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.999928
# 	第10个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999976
# 	第11个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.999987
# 	第12个分类器分类结果：Recall[1.         0.98422713]，Gmean：0.992082，mAUC：0.99994
# 	第13个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999986
# 	第14个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.999981
# 	第15个分类器分类结果：Recall[0.99865817 0.99684543]，Gmean：0.997751，mAUC：0.999981
# 	第16个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999967
# 	第17个分类器分类结果：Recall[1.         0.96845426]，Gmean：0.984101，mAUC：0.999937
# 	第18个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999964
# 	第19个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999948
# 	第20个分类器分类结果：Recall[0.99932908 0.96214511]，Gmean：0.980561，mAUC：0.999828
# 	第21个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.99998
# 	第22个分类器分类结果：Recall[0.99932908 0.97791798]，Gmean：0.988566，mAUC：0.999925
# 	第23个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999937
# 	第24个分类器分类结果：Recall[0.99765179 0.99053628]，Gmean：0.994088，mAUC：0.999563
# 	第25个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.99994
# 	第26个分类器分类结果：Recall[0.99832271 0.97476341]，Gmean：0.986473，mAUC：0.999845
# 	第27个分类器分类结果：Recall[0.99865817 0.99053628]，Gmean：0.994589，mAUC：0.999937
# 	第28个分类器分类结果：Recall[1.         0.99369085]，Gmean：0.99684，mAUC：0.999998
# 	第29个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.99994
# 	第30个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999931
# 第30次执行：Gmean：0.99509，mAUC：0.99999，Acc1：0.998787，Acc2：0.9951，Acc3：0.495707，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999931
# 	第2个分类器分类结果：Recall[0.99899363 0.97160883]，Gmean：0.985206，mAUC：0.999903
# 	第3个分类器分类结果：Recall[0.99832271 0.97791798]，Gmean：0.988068，mAUC：0.999733
# 	第4个分类器分类结果：Recall[0.99698088 0.99369085]，Gmean：0.995335，mAUC：0.999957
# 	第5个分类器分类结果：Recall[0.99966454 0.97791798]，Gmean：0.988731，mAUC：0.999805
# 	第6个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999968
# 	第7个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.99992
# 	第8个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999992
# 	第9个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.99998
# 	第10个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999942
# 	第11个分类器分类结果：Recall[0.99765179 0.98422713]，Gmean：0.990917，mAUC：0.999869
# 	第12个分类器分类结果：Recall[1.         0.96845426]，Gmean：0.984101，mAUC：0.999986
# 	第13个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999924
# 	第14个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999979
# 	第15个分类器分类结果：Recall[0.99966454 0.99684543]，Gmean：0.998254，mAUC：0.99998
# 	第16个分类器分类结果：Recall[0.99798725 0.9873817 ]，Gmean：0.99267，mAUC：0.999922
# 	第17个分类器分类结果：Recall[0.99899363 0.97791798]，Gmean：0.9884，mAUC：0.999849
# 	第18个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999962
# 	第19个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999977
# 	第20个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999982
# 	第21个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.999982
# 	第22个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999977
# 	第23个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999976
# 	第24个分类器分类结果：Recall[1.         0.94321767]，Gmean：0.971194，mAUC：0.999952
# 	第25个分类器分类结果：Recall[0.99798725 0.99053628]，Gmean：0.994255，mAUC：0.999872
# 	第26个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999965
# 	第27个分类器分类结果：Recall[0.99765179 0.99369085]，Gmean：0.995669，mAUC：0.999908
# 	第28个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999964
# 	第29个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999968
# 	第30个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999961
# 第30次执行：Gmean：0.994923，mAUC：0.99999，Acc1：0.998484，Acc2：0.994933，Acc3：0.495691，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999972
# 	第2个分类器分类结果：Recall[0.99865817 0.98422713]，Gmean：0.991416，mAUC：0.999908
# 	第3个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.999986
# 	第4个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999961
# 	第5个分类器分类结果：Recall[0.99865817 0.98422713]，Gmean：0.991416，mAUC：0.999808
# 	第6个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999992
# 	第7个分类器分类结果：Recall[1.         0.99053628]，Gmean：0.995257，mAUC：0.999989
# 	第8个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999947
# 	第9个分类器分类结果：Recall[0.99865817 0.99053628]，Gmean：0.994589，mAUC：0.999969
# 	第10个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999937
# 	第11个分类器分类结果：Recall[0.99966454 0.97791798]，Gmean：0.988731，mAUC：0.999892
# 	第12个分类器分类结果：Recall[0.99966454 0.99684543]，Gmean：0.998254，mAUC：0.999993
# 	第13个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999835
# 	第14个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999943
# 	第15个分类器分类结果：Recall[0.99899363 0.97791798]，Gmean：0.9884，mAUC：0.999954
# 	第16个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999966
# 	第17个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999952
# 	第18个分类器分类结果：Recall[0.99865817 0.99053628]，Gmean：0.994589，mAUC：0.999963
# 	第19个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999949
# 	第20个分类器分类结果：Recall[0.99832271 0.99053628]，Gmean：0.994422，mAUC：0.999956
# 	第21个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999954
# 	第22个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999987
# 	第23个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999957
# 	第24个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999926
# 	第25个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999933
# 	第26个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.99997
# 	第27个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.999972
# 	第28个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999967
# 	第29个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999985
# 	第30个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999961
# 第30次执行：Gmean：0.993337，mAUC：0.999983，Acc1：0.998181，Acc2：0.993355，Acc3：0.494265，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999953
# 	第2个分类器分类结果：Recall[0.99865817 0.99053628]，Gmean：0.994589，mAUC：0.999961
# 	第3个分类器分类结果：Recall[0.99832271 0.9873817 ]，Gmean：0.992837，mAUC：0.999968
# 	第4个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999948
# 	第5个分类器分类结果：Recall[0.99932908 0.95268139]，Gmean：0.975727，mAUC：0.999685
# 	第6个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999966
# 	第7个分类器分类结果：Recall[0.99932908 0.97476341]，Gmean：0.98697，mAUC：0.999908
# 	第8个分类器分类结果：Recall[0.99932908 0.99684543]，Gmean：0.998086，mAUC：0.99996
# 	第9个分类器分类结果：Recall[0.99832271 0.9873817 ]，Gmean：0.992837，mAUC：0.999965
# 	第10个分类器分类结果：Recall[0.99865817 0.99053628]，Gmean：0.994589，mAUC：0.999962
# 	第11个分类器分类结果：Recall[0.99832271 0.99684543]，Gmean：0.997584，mAUC：0.999992
# 	第12个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999945
# 	第13个分类器分类结果：Recall[0.99865817 0.99053628]，Gmean：0.994589，mAUC：0.999943
# 	第14个分类器分类结果：Recall[0.99865817 0.99053628]，Gmean：0.994589，mAUC：0.999961
# 	第15个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999965
# 	第16个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999975
# 	第17个分类器分类结果：Recall[0.99865817 0.99053628]，Gmean：0.994589，mAUC：0.99995
# 	第18个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999931
# 	第19个分类器分类结果：Recall[0.99865817 0.99684543]，Gmean：0.997751，mAUC：0.999961
# 	第20个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999957
# 	第21个分类器分类结果：Recall[0.99698088 0.98422713]，Gmean：0.990583，mAUC：0.999855
# 	第22个分类器分类结果：Recall[0.99698088 0.99369085]，Gmean：0.995335，mAUC：0.999961
# 	第23个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999965
# 	第24个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999963
# 	第25个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999961
# 	第26个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999975
# 	第27个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999948
# 	第28个分类器分类结果：Recall[1.         0.99053628]，Gmean：0.995257，mAUC：0.999995
# 	第29个分类器分类结果：Recall[0.99966454 1.        ]，Gmean：0.999832，mAUC：0.999984
# 	第30个分类器分类结果：Recall[0.99865817 0.97791798]，Gmean：0.988234，mAUC：0.999855
# 第30次执行：Gmean：0.993337，mAUC：0.999986，Acc1：0.998181，Acc2：0.993355，Acc3：0.494265，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999982
# 	第2个分类器分类结果：Recall[0.99899363 0.98107256]，Gmean：0.989993，mAUC：0.999962
# 	第3个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999962
# 	第4个分类器分类结果：Recall[0.99932908 0.97791798]，Gmean：0.988566，mAUC：0.99994
# 	第5个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.99996
# 	第6个分类器分类结果：Recall[0.99865817 0.96845426]，Gmean：0.98344，mAUC：0.999894
# 	第7个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999961
# 	第8个分类器分类结果：Recall[0.99865817 0.98107256]，Gmean：0.989826，mAUC：0.999938
# 	第9个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.99998
# 	第10个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999978
# 	第11个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999939
# 	第12个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999971
# 	第13个分类器分类结果：Recall[0.99899363 0.96845426]，Gmean：0.983605，mAUC：0.999909
# 	第14个分类器分类结果：Recall[0.99731634 0.98422713]，Gmean：0.99075，mAUC：0.999728
# 	第15个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999891
# 	第16个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.99999
# 	第17个分类器分类结果：Recall[0.99932908 0.97476341]，Gmean：0.98697，mAUC：0.999865
# 	第18个分类器分类结果：Recall[1.         0.82649842]，Gmean：0.90912，mAUC：0.999324
# 	第19个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999954
# 	第20个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.999963
# 	第21个分类器分类结果：Recall[0.99966454 0.99684543]，Gmean：0.998254，mAUC：0.999984
# 	第22个分类器分类结果：Recall[0.99865817 0.94006309]，Gmean：0.968918，mAUC：0.99958
# 	第23个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.999981
# 	第24个分类器分类结果：Recall[0.99899363 0.97476341]，Gmean：0.986804，mAUC：0.999919
# 	第25个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999967
# 	第26个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999961
# 	第27个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.999975
# 	第28个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.99996
# 	第29个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999813
# 	第30个分类器分类结果：Recall[0.99966454 0.97791798]，Gmean：0.988731，mAUC：0.999961
# 第30次执行：Gmean：0.993504，mAUC：0.999986，Acc1：0.998484，Acc2：0.993523，Acc3：0.494281，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999874
# 	第2个分类器分类结果：Recall[0.99865817 0.9873817 ]，Gmean：0.993004，mAUC：0.999971
# 	第3个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999956
# 	第4个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999964
# 	第5个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.99998
# 	第6个分类器分类结果：Recall[0.99832271 0.9873817 ]，Gmean：0.992837，mAUC：0.999868
# 	第7个分类器分类结果：Recall[0.99832271 0.98107256]，Gmean：0.98966，mAUC：0.999875
# 	第8个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999933
# 	第9个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999976
# 	第10个分类器分类结果：Recall[0.99865817 0.9873817 ]，Gmean：0.993004，mAUC：0.999929
# 	第11个分类器分类结果：Recall[1.         0.97476341]，Gmean：0.987301，mAUC：0.999906
# 	第12个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999859
# 	第13个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.99998
# 	第14个分类器分类结果：Recall[0.99832271 0.99053628]，Gmean：0.994422，mAUC：0.999953
# 	第15个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999894
# 	第16个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999946
# 	第17个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999987
# 	第18个分类器分类结果：Recall[0.99832271 0.97476341]，Gmean：0.986473，mAUC：0.999771
# 	第19个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999974
# 	第20个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999993
# 	第21个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999916
# 	第22个分类器分类结果：Recall[1.         0.98422713]，Gmean：0.992082，mAUC：0.999977
# 	第23个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999969
# 	第24个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999959
# 	第25个分类器分类结果：Recall[0.99832271 0.98422713]，Gmean：0.99125，mAUC：0.999912
# 	第26个分类器分类结果：Recall[0.99329084 0.98422713]，Gmean：0.988749，mAUC：0.999101
# 	第27个分类器分类结果：Recall[0.99966454 0.97160883]，Gmean：0.985537，mAUC：0.999941
# 	第28个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999961
# 	第29个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999814
# 	第30个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999935
# 第30次执行：Gmean：0.994923，mAUC：0.99999，Acc1：0.998484，Acc2：0.994933，Acc3：0.495691，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.999987
# 	第2个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.999979
# 	第3个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999962
# 	第4个分类器分类结果：Recall[1.         0.96529968]，Gmean：0.982497，mAUC：0.999924
# 	第5个分类器分类结果：Recall[0.99865817 0.9873817 ]，Gmean：0.993004，mAUC：0.999946
# 	第6个分类器分类结果：Recall[0.99932908 0.97791798]，Gmean：0.988566，mAUC：0.999966
# 	第7个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999969
# 	第8个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999945
# 	第9个分类器分类结果：Recall[0.99865817 0.97791798]，Gmean：0.988234，mAUC：0.999937
# 	第10个分类器分类结果：Recall[1.         0.93059937]，Gmean：0.964676，mAUC：0.999412
# 	第11个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999957
# 	第12个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999954
# 	第13个分类器分类结果：Recall[0.99966454 0.95583596]，Gmean：0.977505，mAUC：0.99984
# 	第14个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999962
# 	第15个分类器分类结果：Recall[0.99832271 0.98422713]，Gmean：0.99125，mAUC：0.99995
# 	第16个分类器分类结果：Recall[0.99966454 0.99684543]，Gmean：0.998254，mAUC：0.999993
# 	第17个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999976
# 	第18个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.99997
# 	第19个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999979
# 	第20个分类器分类结果：Recall[0.99899363 0.97791798]，Gmean：0.9884，mAUC：0.999953
# 	第21个分类器分类结果：Recall[0.99563905 0.99369085]，Gmean：0.994664，mAUC：0.999879
# 	第22个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999966
# 	第23个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999963
# 	第24个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999776
# 	第25个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999966
# 	第26个分类器分类结果：Recall[0.99798725 0.97160883]，Gmean：0.98471，mAUC：0.999735
# 	第27个分类器分类结果：Recall[0.99798725 0.99369085]，Gmean：0.995837，mAUC：0.999956
# 	第28个分类器分类结果：Recall[0.99698088 0.99053628]，Gmean：0.993753，mAUC：0.999906
# 	第29个分类器分类结果：Recall[0.99899363 0.96214511]，Gmean：0.980396，mAUC：0.999583
# 	第30个分类器分类结果：Recall[1.         0.95899054]，Gmean：0.979281，mAUC：0.999948
# 第30次执行：Gmean：0.990325，mAUC：0.999985，Acc1：0.997878，Acc2：0.990369，Acc3：0.49143，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999972
# 	第2个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999978
# 	第3个分类器分类结果：Recall[0.99832271 0.95899054]，Gmean：0.978459，mAUC：0.999565
# 	第4个分类器分类结果：Recall[0.99865817 0.99053628]，Gmean：0.994589，mAUC：0.9998
# 	第5个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999949
# 	第6个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.99998
# 	第7个分类器分类结果：Recall[0.99865817 0.99684543]，Gmean：0.997751，mAUC：0.999986
# 	第8个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999983
# 	第9个分类器分类结果：Recall[0.99329084 1.        ]，Gmean：0.99664，mAUC：0.999958
# 	第10个分类器分类结果：Recall[0.99932908 0.97476341]，Gmean：0.98697，mAUC：0.99993
# 	第11个分类器分类结果：Recall[0.99832271 0.99369085]，Gmean：0.996004，mAUC：0.999961
# 	第12个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.999993
# 	第13个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999857
# 	第14个分类器分类结果：Recall[0.9936263  0.99684543]，Gmean：0.995235，mAUC：0.999891
# 	第15个分类器分类结果：Recall[0.99865817 0.99369085]，Gmean：0.996171，mAUC：0.999894
# 	第16个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999964
# 	第17个分类器分类结果：Recall[0.99932908 0.99684543]，Gmean：0.998086，mAUC：0.999989
# 	第18个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999965
# 	第19个分类器分类结果：Recall[0.99932908 0.99684543]，Gmean：0.998086，mAUC：0.999981
# 	第20个分类器分类结果：Recall[0.99161355 0.99684543]，Gmean：0.994226，mAUC：0.999881
# 	第21个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999872
# 	第22个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.999992
# 	第23个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999962
# 	第24个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.99994
# 	第25个分类器分类结果：Recall[0.99932908 0.96529968]，Gmean：0.982167，mAUC：0.999631
# 	第26个分类器分类结果：Recall[0.99865817 0.99369085]，Gmean：0.996171，mAUC：0.999836
# 	第27个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.999978
# 	第28个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999975
# 	第29个分类器分类结果：Recall[0.99832271 0.98422713]，Gmean：0.99125，mAUC：0.999899
# 	第30个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999908
# 第30次执行：Gmean：0.999664，mAUC：0.999988，Acc1：0.999394，Acc2：0.999665，Acc3：0.499968，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999968
# 	第2个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999719
# 	第3个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999958
# 	第4个分类器分类结果：Recall[0.99630996 0.9873817 ]，Gmean：0.991836，mAUC：0.999613
# 	第5个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999982
# 	第6个分类器分类结果：Recall[0.99161355 0.96529968]，Gmean：0.978368，mAUC：0.997754
# 	第7个分类器分类结果：Recall[0.99832271 0.99053628]，Gmean：0.994422，mAUC：0.999896
# 	第8个分类器分类结果：Recall[0.99865817 0.98422713]，Gmean：0.991416，mAUC：0.999922
# 	第9个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999914
# 	第10个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999893
# 	第11个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.99997
# 	第12个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999915
# 	第13个分类器分类结果：Recall[0.99865817 0.97476341]，Gmean：0.986638，mAUC：0.999849
# 	第14个分类器分类结果：Recall[0.99966454 0.99684543]，Gmean：0.998254，mAUC：0.999994
# 	第15个分类器分类结果：Recall[0.99865817 0.99053628]，Gmean：0.994589，mAUC：0.999974
# 	第16个分类器分类结果：Recall[0.99899363 0.97476341]，Gmean：0.986804，mAUC：0.99991
# 	第17个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.999956
# 	第18个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999945
# 	第19个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999943
# 	第20个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999989
# 	第21个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999968
# 	第22个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999976
# 	第23个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999978
# 	第24个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.99997
# 	第25个分类器分类结果：Recall[0.99329084 0.99684543]，Gmean：0.995067，mAUC：0.99988
# 	第26个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999974
# 	第27个分类器分类结果：Recall[0.99966454 0.97791798]，Gmean：0.988731，mAUC：0.999942
# 	第28个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.99995
# 	第29个分类器分类结果：Recall[0.99731634 0.98107256]，Gmean：0.989161，mAUC：0.999867
# 	第30个分类器分类结果：Recall[0.99932908 0.97160883]，Gmean：0.985371，mAUC：0.999695
# 第30次执行：Gmean：0.993337，mAUC：0.999987，Acc1：0.998181，Acc2：0.993355，Acc3：0.494265，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999925
# 	第2个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999987
# 	第3个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.999989
# 	第4个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999928
# 	第5个分类器分类结果：Recall[0.99865817 0.9873817 ]，Gmean：0.993004，mAUC：0.999813
# 	第6个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999978
# 	第7个分类器分类结果：Recall[0.99865817 0.99369085]，Gmean：0.996171，mAUC：0.999985
# 	第8个分类器分类结果：Recall[0.99899363 0.94637224]，Gmean：0.972327，mAUC：0.999434
# 	第9个分类器分类结果：Recall[0.99899363 0.94637224]，Gmean：0.972327，mAUC：0.999799
# 	第10个分类器分类结果：Recall[0.99899363 0.99684543]，Gmean：0.997919，mAUC：0.999994
# 	第11个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.99998
# 	第12个分类器分类结果：Recall[0.99798725 0.99369085]，Gmean：0.995837，mAUC：0.999895
# 	第13个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999984
# 	第14个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999957
# 	第15个分类器分类结果：Recall[0.99932908 0.99684543]，Gmean：0.998086，mAUC：0.999967
# 	第16个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.99998
# 	第17个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999986
# 	第18个分类器分类结果：Recall[0.99832271 0.99369085]，Gmean：0.996004，mAUC：0.999974
# 	第19个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999938
# 	第20个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999988
# 	第21个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999982
# 	第22个分类器分类结果：Recall[0.99798725 1.        ]，Gmean：0.998993，mAUC：0.999982
# 	第23个分类器分类结果：Recall[0.99429722 0.98107256]，Gmean：0.987663，mAUC：0.999501
# 	第24个分类器分类结果：Recall[0.99899363 0.95583596]，Gmean：0.977177，mAUC：0.999674
# 	第25个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.99995
# 	第26个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999984
# 	第27个分类器分类结果：Recall[0.99832271 0.96214511]，Gmean：0.980067，mAUC：0.999669
# 	第28个分类器分类结果：Recall[0.99966454 0.99684543]，Gmean：0.998254，mAUC：0.999995
# 	第29个分类器分类结果：Recall[0.99865817 0.99369085]，Gmean：0.996171，mAUC：0.999968
# 	第30个分类器分类结果：Recall[0.99899363 0.98107256]，Gmean：0.989993，mAUC：0.999906
# 第30次执行：Gmean：0.996506，mAUC：0.999989，Acc1：0.998787，Acc2：0.99651，Acc3：0.497116，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99765179 0.94637224]，Gmean：0.971674，mAUC：0.998669
# 	第2个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999959
# 	第3个分类器分类结果：Recall[0.97651795 0.99369085]，Gmean：0.985067，mAUC：0.995964
# 	第4个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.99998
# 	第5个分类器分类结果：Recall[0.99731634 0.9873817 ]，Gmean：0.992337，mAUC：0.999734
# 	第6个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999972
# 	第7个分类器分类结果：Recall[0.99899363 0.98107256]，Gmean：0.989993，mAUC：0.999953
# 	第8个分类器分类结果：Recall[0.99899363 0.98107256]，Gmean：0.989993，mAUC：0.999945
# 	第9个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999925
# 	第10个分类器分类结果：Recall[0.99899363 0.98107256]，Gmean：0.989993，mAUC：0.999961
# 	第11个分类器分类结果：Recall[0.99932908 0.94006309]，Gmean：0.969243，mAUC：0.999742
# 	第12个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999969
# 	第13个分类器分类结果：Recall[0.99597451 0.96214511]，Gmean：0.978914，mAUC：0.998909
# 	第14个分类器分类结果：Recall[1.         0.99053628]，Gmean：0.995257，mAUC：0.999984
# 	第15个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999976
# 	第16个分类器分类结果：Recall[1.         0.97791798]，Gmean：0.988897，mAUC：0.999993
# 	第17个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999986
# 	第18个分类器分类结果：Recall[0.99798725 0.99369085]，Gmean：0.995837，mAUC：0.999938
# 	第19个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999948
# 	第20个分类器分类结果：Recall[0.99899363 0.97476341]，Gmean：0.986804，mAUC：0.999967
# 	第21个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999968
# 	第22个分类器分类结果：Recall[0.99966454 0.97791798]，Gmean：0.988731，mAUC：0.999917
# 	第23个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999975
# 	第24个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999956
# 	第25个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999958
# 	第26个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999976
# 	第27个分类器分类结果：Recall[0.99966454 0.97791798]，Gmean：0.988731，mAUC：0.999837
# 	第28个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999978
# 	第29个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999986
# 	第30个分类器分类结果：Recall[0.98859443 0.99053628]，Gmean：0.989565，mAUC：0.999493
# 第30次执行：Gmean：0.994923，mAUC：0.999985，Acc1：0.998484，Acc2：0.994933，Acc3：0.495691，集成的数量：30
# 	第1个分类器分类结果：Recall[1.         0.96845426]，Gmean：0.984101，mAUC：0.999906
# 	第2个分类器分类结果：Recall[0.99966454 0.94952681]，Gmean：0.974273，mAUC：0.999286
# 	第3个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.999989
# 	第4个分类器分类结果：Recall[0.99899363 0.98107256]，Gmean：0.989993，mAUC：0.99974
# 	第5个分类器分类结果：Recall[0.99865817 0.99369085]，Gmean：0.996171，mAUC：0.999971
# 	第6个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999967
# 	第7个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.99999
# 	第8个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999979
# 	第9个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999974
# 	第10个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999977
# 	第11个分类器分类结果：Recall[1.         0.92113565]，Gmean：0.959758，mAUC：0.999814
# 	第12个分类器分类结果：Recall[0.99899363 0.98107256]，Gmean：0.989993，mAUC：0.999932
# 	第13个分类器分类结果：Recall[0.99865817 0.99684543]，Gmean：0.997751，mAUC：0.999992
# 	第14个分类器分类结果：Recall[0.99865817 0.99053628]，Gmean：0.994589，mAUC：0.99994
# 	第15个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999976
# 	第16个分类器分类结果：Recall[0.99865817 0.99369085]，Gmean：0.996171，mAUC：0.999977
# 	第17个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999957
# 	第18个分类器分类结果：Recall[0.99698088 0.9873817 ]，Gmean：0.99217，mAUC：0.999734
# 	第19个分类器分类结果：Recall[0.99832271 0.97791798]，Gmean：0.988068，mAUC：0.999843
# 	第20个分类器分类结果：Recall[1.        0.9873817]，Gmean：0.993671，mAUC：0.999987
# 	第21个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999992
# 	第22个分类器分类结果：Recall[0.99899363 0.99684543]，Gmean：0.997919，mAUC：0.99999
# 	第23个分类器分类结果：Recall[0.99932908 0.99684543]，Gmean：0.998086，mAUC：0.999982
# 	第24个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999939
# 	第25个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999971
# 	第26个分类器分类结果：Recall[0.99932908 0.99684543]，Gmean：0.998086，mAUC：0.999977
# 	第27个分类器分类结果：Recall[0.99798725 0.99369085]，Gmean：0.995837，mAUC：0.999931
# 	第28个分类器分类结果：Recall[0.99932908 0.99684543]，Gmean：0.998086，mAUC：0.999988
# 	第29个分类器分类结果：Recall[0.99765179 0.9873817 ]，Gmean：0.992503，mAUC：0.999746
# 	第30个分类器分类结果：Recall[0.99932908 0.99684543]，Gmean：0.998086，mAUC：0.999994
# 第30次执行：Gmean：0.998086，mAUC：0.999996，Acc1：0.99909，Acc2：0.998087，Acc3：0.498542，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999987
# 	第2个分类器分类结果：Recall[0.99966454 0.97476341]，Gmean：0.987135，mAUC：0.999843
# 	第3个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999978
# 	第4个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999965
# 	第5个分类器分类结果：Recall[1.        0.9873817]，Gmean：0.993671，mAUC：0.999982
# 	第6个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999952
# 	第7个分类器分类结果：Recall[0.99966454 0.97791798]，Gmean：0.988731，mAUC：0.999903
# 	第8个分类器分类结果：Recall[0.99865817 0.98107256]，Gmean：0.989826，mAUC：0.999932
# 	第9个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999989
# 	第10个分类器分类结果：Recall[0.99832271 0.99053628]，Gmean：0.994422，mAUC：0.999961
# 	第11个分类器分类结果：Recall[0.99765179 0.99369085]，Gmean：0.995669，mAUC：0.999903
# 	第12个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999964
# 	第13个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999951
# 	第14个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999937
# 	第15个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999959
# 	第16个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999952
# 	第17个分类器分类结果：Recall[1.         0.96529968]，Gmean：0.982497，mAUC：0.999865
# 	第18个分类器分类结果：Recall[0.99530359 0.97160883]，Gmean：0.983385，mAUC：0.999517
# 	第19个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999983
# 	第20个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999964
# 	第21个分类器分类结果：Recall[0.99932908 0.93059937]，Gmean：0.964352，mAUC：0.999818
# 	第22个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999976
# 	第23个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999976
# 	第24个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999943
# 	第25个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.999949
# 	第26个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999966
# 	第27个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999969
# 	第28个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.999912
# 	第29个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999951
# 	第30个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999948
# 第30次执行：Gmean：0.993504，mAUC：0.999992，Acc1：0.998484，Acc2：0.993523，Acc3：0.494281，集成的数量：30
# 	第1个分类器分类结果：Recall[1.         0.98107256]，Gmean：0.990491，mAUC：0.999983
# 	第2个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999963
# 	第3个分类器分类结果：Recall[0.99664542 0.9873817 ]，Gmean：0.992003，mAUC：0.999496
# 	第4个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999975
# 	第5个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999976
# 	第6个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.999964
# 	第7个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999928
# 	第8个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999964
# 	第9个分类器分类结果：Recall[0.99865817 0.9873817 ]，Gmean：0.993004，mAUC：0.999956
# 	第10个分类器分类结果：Recall[0.99865817 0.99369085]，Gmean：0.996171，mAUC：0.999964
# 	第11个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999979
# 	第12个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999977
# 	第13个分类器分类结果：Recall[0.99832271 0.99369085]，Gmean：0.996004，mAUC：0.999958
# 	第14个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999939
# 	第15个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999944
# 	第16个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999987
# 	第17个分类器分类结果：Recall[0.99865817 0.99053628]，Gmean：0.994589，mAUC：0.999972
# 	第18个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999968
# 	第19个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.999949
# 	第20个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999947
# 	第21个分类器分类结果：Recall[0.99765179 0.99053628]，Gmean：0.994088，mAUC：0.999921
# 	第22个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999948
# 	第23个分类器分类结果：Recall[0.99832271 0.9873817 ]，Gmean：0.992837，mAUC：0.999959
# 	第24个分类器分类结果：Recall[1.         0.98422713]，Gmean：0.992082，mAUC：0.999985
# 	第25个分类器分类结果：Recall[1.         0.98107256]，Gmean：0.990491，mAUC：0.999984
# 	第26个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999978
# 	第27个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999969
# 	第28个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999949
# 	第29个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999894
# 	第30个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999972
# 第30次执行：Gmean：0.993337，mAUC：0.999992，Acc1：0.998181，Acc2：0.993355，Acc3：0.494265，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99798725 0.99053628]，Gmean：0.994255，mAUC：0.999943
# 	第2个分类器分类结果：Recall[0.99865817 0.9873817 ]，Gmean：0.993004，mAUC：0.999944
# 	第3个分类器分类结果：Recall[0.99798725 0.9873817 ]，Gmean：0.99267，mAUC：0.99994
# 	第4个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.99997
# 	第5个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999958
# 	第6个分类器分类结果：Recall[0.99563905 0.97791798]，Gmean：0.986739，mAUC：0.999611
# 	第7个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999983
# 	第8个分类器分类结果：Recall[0.99832271 0.97476341]，Gmean：0.986473，mAUC：0.999913
# 	第9个分类器分类结果：Recall[0.99932908 0.97791798]，Gmean：0.988566，mAUC：0.999897
# 	第10个分类器分类结果：Recall[0.99798725 0.98107256]，Gmean：0.989494，mAUC：0.999741
# 	第11个分类器分类结果：Recall[0.99865817 0.99053628]，Gmean：0.994589，mAUC：0.999935
# 	第12个分类器分类结果：Recall[1.         0.91167192]，Gmean：0.954815，mAUC：0.999715
# 	第13个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999963
# 	第14个分类器分类结果：Recall[0.99899363 0.98107256]，Gmean：0.989993，mAUC：0.999824
# 	第15个分类器分类结果：Recall[0.99832271 0.97476341]，Gmean：0.986473，mAUC：0.999865
# 	第16个分类器分类结果：Recall[0.99865817 0.99053628]，Gmean：0.994589，mAUC：0.999875
# 	第17个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999971
# 	第18个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999952
# 	第19个分类器分类结果：Recall[0.99865817 0.97476341]，Gmean：0.986638，mAUC：0.999951
# 	第20个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999975
# 	第21个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999978
# 	第22个分类器分类结果：Recall[0.99731634 0.9873817 ]，Gmean：0.992337，mAUC：0.999828
# 	第23个分类器分类结果：Recall[0.99630996 0.99053628]，Gmean：0.993419，mAUC：0.999856
# 	第24个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999911
# 	第25个分类器分类结果：Recall[0.99832271 0.99053628]，Gmean：0.994422，mAUC：0.999923
# 	第26个分类器分类结果：Recall[0.99966454 0.97160883]，Gmean：0.985537，mAUC：0.999883
# 	第27个分类器分类结果：Recall[1.         0.98107256]，Gmean：0.990491，mAUC：0.999974
# 	第28个分类器分类结果：Recall[0.99798725 0.98107256]，Gmean：0.989494，mAUC：0.999897
# 	第29个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999901
# 	第30个分类器分类结果：Recall[0.99865817 0.9873817 ]，Gmean：0.993004，mAUC：0.999863
# 第30次执行：Gmean：0.991749，mAUC：0.999989，Acc1：0.997878，Acc2：0.991778，Acc3：0.492839，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.99999
# 	第2个分类器分类结果：Recall[0.99765179 0.98422713]，Gmean：0.990917，mAUC：0.999869
# 	第3个分类器分类结果：Recall[0.99966454 0.97476341]，Gmean：0.987135，mAUC：0.999956
# 	第4个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999902
# 	第5个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999971
# 	第6个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999794
# 	第7个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999943
# 	第8个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999992
# 	第9个分类器分类结果：Recall[0.99798725 0.95899054]，Gmean：0.978295，mAUC：0.999672
# 	第10个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999894
# 	第11个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999957
# 	第12个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999861
# 	第13个分类器分类结果：Recall[0.99899363 0.99684543]，Gmean：0.997919，mAUC：0.999984
# 	第14个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999985
# 	第15个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999986
# 	第16个分类器分类结果：Recall[1.         0.97160883]，Gmean：0.985702，mAUC：0.999899
# 	第17个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999976
# 	第18个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.99998
# 	第19个分类器分类结果：Recall[0.99932908 0.99684543]，Gmean：0.998086，mAUC：0.99997
# 	第20个分类器分类结果：Recall[1.         0.97160883]，Gmean：0.985702，mAUC：0.999977
# 	第21个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999982
# 	第22个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.999981
# 	第23个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.999958
# 	第24个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.99997
# 	第25个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999987
# 	第26个分类器分类结果：Recall[0.99865817 0.9873817 ]，Gmean：0.993004，mAUC：0.999889
# 	第27个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999982
# 	第28个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999965
# 	第29个分类器分类结果：Recall[1.        0.9873817]，Gmean：0.993671，mAUC：0.999996
# 	第30个分类器分类结果：Recall[0.99865817 0.97791798]，Gmean：0.988234，mAUC：0.999903
# 第30次执行：Gmean：0.994923，mAUC：0.999993，Acc1：0.998484，Acc2：0.994933，Acc3：0.495691，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99966454 1.        ]，Gmean：0.999832，mAUC：0.999994
# 	第2个分类器分类结果：Recall[0.99832271 0.98422713]，Gmean：0.99125，mAUC：0.999892
# 	第3个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999868
# 	第4个分类器分类结果：Recall[0.99630996 0.99053628]，Gmean：0.993419，mAUC：0.999758
# 	第5个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999898
# 	第6个分类器分类结果：Recall[0.99932908 0.97791798]，Gmean：0.988566，mAUC：0.999958
# 	第7个分类器分类结果：Recall[1.         0.98422713]，Gmean：0.992082，mAUC：0.999981
# 	第8个分类器分类结果：Recall[0.99865817 0.9873817 ]，Gmean：0.993004，mAUC：0.99995
# 	第9个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999963
# 	第10个分类器分类结果：Recall[0.99865817 0.96845426]，Gmean：0.98344，mAUC：0.999843
# 	第11个分类器分类结果：Recall[0.99966454 0.97791798]，Gmean：0.988731，mAUC：0.999728
# 	第12个分类器分类结果：Recall[0.99496813 1.        ]，Gmean：0.997481，mAUC：0.999969
# 	第13个分类器分类结果：Recall[0.99932908 0.95268139]，Gmean：0.975727，mAUC：0.999683
# 	第14个分类器分类结果：Recall[0.99932908 0.97791798]，Gmean：0.988566，mAUC：0.999938
# 	第15个分类器分类结果：Recall[0.99865817 0.9873817 ]，Gmean：0.993004，mAUC：0.999945
# 	第16个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.99988
# 	第17个分类器分类结果：Recall[1.        0.9873817]，Gmean：0.993671，mAUC：0.999941
# 	第18个分类器分类结果：Recall[0.99899363 0.98107256]，Gmean：0.989993，mAUC：0.999898
# 	第19个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999956
# 	第20个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999916
# 	第21个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999969
# 	第22个分类器分类结果：Recall[0.99798725 0.99053628]，Gmean：0.994255，mAUC：0.999933
# 	第23个分类器分类结果：Recall[0.99765179 0.99053628]，Gmean：0.994088，mAUC：0.999966
# 	第24个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999913
# 	第25个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999956
# 	第26个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999948
# 	第27个分类器分类结果：Recall[1.        0.9873817]，Gmean：0.993671，mAUC：0.999838
# 	第28个分类器分类结果：Recall[0.99899363 0.97476341]，Gmean：0.986804，mAUC：0.999877
# 	第29个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999921
# 	第30个分类器分类结果：Recall[0.99865817 0.9873817 ]，Gmean：0.993004，mAUC：0.999921
# 第30次执行：Gmean：0.991749，mAUC：0.999987，Acc1：0.997878，Acc2：0.991778，Acc3：0.492839，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99865817 0.98422713]，Gmean：0.991416，mAUC：0.999925
# 	第2个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999872
# 	第3个分类器分类结果：Recall[0.99563905 0.98107256]，Gmean：0.988329，mAUC：0.999714
# 	第4个分类器分类结果：Recall[0.99798725 0.9873817 ]，Gmean：0.99267，mAUC：0.999912
# 	第5个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999965
# 	第6个分类器分类结果：Recall[0.99899363 0.96845426]，Gmean：0.983605，mAUC：0.999742
# 	第7个分类器分类结果：Recall[0.99865817 0.98107256]，Gmean：0.989826，mAUC：0.999934
# 	第8个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999989
# 	第9个分类器分类结果：Recall[0.99865817 0.99053628]，Gmean：0.994589，mAUC：0.999972
# 	第10个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999949
# 	第11个分类器分类结果：Recall[0.99932908 0.99684543]，Gmean：0.998086，mAUC：0.999968
# 	第12个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999922
# 	第13个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999974
# 	第14个分类器分类结果：Recall[0.99932908 0.97791798]，Gmean：0.988566，mAUC：0.999926
# 	第15个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999962
# 	第16个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999968
# 	第17个分类器分类结果：Recall[0.99698088 0.98422713]，Gmean：0.990583，mAUC：0.999735
# 	第18个分类器分类结果：Recall[1.         0.98107256]，Gmean：0.990491，mAUC：0.999987
# 	第19个分类器分类结果：Recall[1.         0.95899054]，Gmean：0.979281，mAUC：0.999957
# 	第20个分类器分类结果：Recall[0.99865817 0.9873817 ]，Gmean：0.993004，mAUC：0.999964
# 	第21个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999873
# 	第22个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999929
# 	第23个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999939
# 	第24个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.999979
# 	第25个分类器分类结果：Recall[0.99832271 1.        ]，Gmean：0.999161，mAUC：0.999925
# 	第26个分类器分类结果：Recall[0.99832271 0.97791798]，Gmean：0.988068，mAUC：0.99993
# 	第27个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999954
# 	第28个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999979
# 	第29个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999954
# 	第30个分类器分类结果：Recall[0.99429722 0.99369085]，Gmean：0.993994，mAUC：0.999676
# 第30次执行：Gmean：0.993337，mAUC：0.999984，Acc1：0.998181，Acc2：0.993355，Acc3：0.494265，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999952
# 	第2个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.999981
# 	第3个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999581
# 	第4个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999947
# 	第5个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999751
# 	第6个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999942
# 	第7个分类器分类结果：Recall[0.99865817 0.99053628]，Gmean：0.994589，mAUC：0.999885
# 	第8个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999917
# 	第9个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999958
# 	第10个分类器分类结果：Recall[0.99932908 0.99684543]，Gmean：0.998086，mAUC：0.999974
# 	第11个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999984
# 	第12个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999957
# 	第13个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999944
# 	第14个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999978
# 	第15个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999976
# ...
# 	第29个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999922
# 	第30个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999848
# 第30次执行：Gmean：0.994923，mAUC：0.99999，Acc1：0.998484，Acc2：0.994933，Acc3：0.495691，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99966454 0.97476341]，Gmean：0.987135，mAUC：0.999963
# 	第2个分类器分类结果：Recall[0.99865817 0.98422713]，Gmean：0.991416，mAUC：0.999964
# 	第3个分类器分类结果：Recall[0.99731634 1.        ]，Gmean：0.998657，mAUC：0.999959
# 	第4个分类器分类结果：Recall[0.99932908 1.        ]，Gmean：0.999664，mAUC：0.999987
# 	第5个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999982
# 	第6个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.999993
# 	第7个分类器分类结果：Recall[0.99765179 0.92744479]，Gmean：0.961908，mAUC：0.998986
# 	第8个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999969
# 	第9个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.99998
# 	第10个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999984
# 	第11个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999968
# 	第12个分类器分类结果：Recall[0.99228447 0.99053628]，Gmean：0.99141，mAUC：0.9992
# 	第13个分类器分类结果：Recall[0.99798725 0.97476341]，Gmean：0.986307，mAUC：0.999764
# 	第14个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999984
# 	第15个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999962
# 	第16个分类器分类结果：Recall[1.         0.98107256]，Gmean：0.990491，mAUC：0.99995
# 	第17个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999971
# 	第18个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999981
# 	第19个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999897
# 	第20个分类器分类结果：Recall[0.99832271 0.9873817 ]，Gmean：0.992837，mAUC：0.999744
# 	第21个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.999971
# 	第22个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999968
# 	第23个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.999995
# 	第24个分类器分类结果：Recall[0.99865817 0.99369085]，Gmean：0.996171，mAUC：0.999958
# 	第25个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.999992
# 	第26个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999946
# 	第27个分类器分类结果：Recall[0.99865817 0.9873817 ]，Gmean：0.993004，mAUC：0.999981
# 	第28个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999975
# 	第29个分类器分类结果：Recall[0.99731634 0.98107256]，Gmean：0.989161，mAUC：0.999823
# 	第30个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999894
# 第30次执行：Gmean：0.996506，mAUC：0.999995，Acc1：0.998787，Acc2：0.99651，Acc3：0.497116，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999925
# 	第2个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999978
# 	第3个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999972
# 	第4个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.99995
# 	第5个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999986
# 	第6个分类器分类结果：Recall[0.99966454 0.97791798]，Gmean：0.988731，mAUC：0.999905
# 	第7个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999921
# 	第8个分类器分类结果：Recall[0.99563905 0.99369085]，Gmean：0.994664，mAUC：0.99974
# 	第9个分类器分类结果：Recall[0.99932908 0.99684543]，Gmean：0.998086，mAUC：0.999992
# 	第10个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999994
# 	第11个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999961
# 	第12个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999962
# 	第13个分类器分类结果：Recall[1.         0.99053628]，Gmean：0.995257，mAUC：0.99999
# 	第14个分类器分类结果：Recall[0.99932908 1.        ]，Gmean：0.999664，mAUC：0.999986
# 	第15个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999979
# 	第16个分类器分类结果：Recall[0.99161355 0.99369085]，Gmean：0.992652，mAUC：0.99975
# 	第17个分类器分类结果：Recall[0.99966454 0.97791798]，Gmean：0.988731，mAUC：0.999896
# 	第18个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999925
# 	第19个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999925
# 	第20个分类器分类结果：Recall[1.         0.99053628]，Gmean：0.995257，mAUC：0.999987
# 	第21个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999969
# 	第22个分类器分类结果：Recall[0.99966454 0.97791798]，Gmean：0.988731，mAUC：0.999952
# 	第23个分类器分类结果：Recall[0.99932908 0.97791798]，Gmean：0.988566，mAUC：0.999801
# 	第24个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999984
# 	第25个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999989
# 	第26个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999981
# 	第27个分类器分类结果：Recall[0.99932908 0.97791798]，Gmean：0.988566，mAUC：0.999953
# 	第28个分类器分类结果：Recall[0.99932908 0.99684543]，Gmean：0.998086，mAUC：0.999987
# 	第29个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999972
# 	第30个分类器分类结果：Recall[0.99966454 1.        ]，Gmean：0.999832，mAUC：1.0
# 第30次执行：Gmean：0.996506，mAUC：0.99999，Acc1：0.998787，Acc2：0.99651，Acc3：0.497116，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999967
# 	第2个分类器分类结果：Recall[0.99832271 0.99053628]，Gmean：0.994422，mAUC：0.999906
# 	第3个分类器分类结果：Recall[0.99966454 0.97476341]，Gmean：0.987135，mAUC：0.999967
# 	第4个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999829
# 	第5个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999925
# 	第6个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999956
# 	第7个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999948
# 	第8个分类器分类结果：Recall[0.99865817 0.99684543]，Gmean：0.997751，mAUC：0.999896
# 	第9个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.999959
# 	第10个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999949
# 	第11个分类器分类结果：Recall[0.99731634 0.97791798]，Gmean：0.98757，mAUC：0.999761
# 	第12个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999979
# 	第13个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999956
# 	第14个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999961
# 	第15个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999958
# 	第16个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.999968
# 	第17个分类器分类结果：Recall[0.99899363 0.94321767]，Gmean：0.970705，mAUC：0.999334
# 	第18个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999865
# 	第19个分类器分类结果：Recall[0.99295538 0.99684543]，Gmean：0.994899，mAUC：0.999877
# 	第20个分类器分类结果：Recall[0.99865817 0.99053628]，Gmean：0.994589，mAUC：0.999953
# 	第21个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999949
# 	第22个分类器分类结果：Recall[0.99966454 0.99684543]，Gmean：0.998254，mAUC：0.999996
# 	第23个分类器分类结果：Recall[0.99731634 0.97160883]，Gmean：0.984379，mAUC：0.99968
# 	第24个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999971
# 	第25个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.99998
# 	第26个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999958
# 	第27个分类器分类结果：Recall[0.99798725 0.97791798]，Gmean：0.987902，mAUC：0.999753
# 	第28个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999977
# 	第29个分类器分类结果：Recall[0.99832271 0.9873817 ]，Gmean：0.992837，mAUC：0.999907
# 	第30个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999996
# 第30次执行：Gmean：0.996506，mAUC：0.999989，Acc1：0.998787，Acc2：0.99651，Acc3：0.497116，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99865817 0.98422713]，Gmean：0.991416，mAUC：0.99994
# 	第2个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999968
# 	第3个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999953
# 	第4个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999932
# 	第5个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999932
# 	第6个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999976
# 	第7个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999966
# 	第8个分类器分类结果：Recall[0.99765179 0.99053628]，Gmean：0.994088，mAUC：0.999889
# 	第9个分类器分类结果：Recall[0.98658168 0.99369085]，Gmean：0.99013，mAUC：0.999423
# 	第10个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999954
# 	第11个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999958
# 	第12个分类器分类结果：Recall[0.99966454 0.99684543]，Gmean：0.998254，mAUC：0.999997
# 	第13个分类器分类结果：Recall[0.99630996 0.99053628]，Gmean：0.993419，mAUC：0.999929
# 	第14个分类器分类结果：Recall[0.99765179 0.98422713]，Gmean：0.990917，mAUC：0.999656
# 	第15个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999951
# 	第16个分类器分类结果：Recall[0.99865817 0.98107256]，Gmean：0.989826，mAUC：0.999939
# 	第17个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.999917
# 	第18个分类器分类结果：Recall[0.99932908 0.97160883]，Gmean：0.985371，mAUC：0.999932
# 	第19个分类器分类结果：Recall[0.99899363 0.99684543]，Gmean：0.997919，mAUC：0.999997
# 	第20个分类器分类结果：Recall[0.99865817 0.99684543]，Gmean：0.997751，mAUC：0.999984
# 	第21个分类器分类结果：Recall[0.99865817 0.97476341]，Gmean：0.986638，mAUC：0.999898
# 	第22个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999948
# 	第23个分类器分类结果：Recall[0.99932908 0.93059937]，Gmean：0.964352，mAUC：0.999238
# 	第24个分类器分类结果：Recall[0.99899363 0.96845426]，Gmean：0.983605，mAUC：0.999613
# 	第25个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999974
# 	第26个分类器分类结果：Recall[0.99832271 0.97791798]，Gmean：0.988068，mAUC：0.999873
# 	第27个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999968
# 	第28个分类器分类结果：Recall[0.99731634 0.9873817 ]，Gmean：0.992337，mAUC：0.999838
# 	第29个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999925
# 	第30个分类器分类结果：Recall[0.99932908 0.97476341]，Gmean：0.98697，mAUC：0.999739
# 第30次执行：Gmean：0.994923，mAUC：0.999983，Acc1：0.998484，Acc2：0.994933，Acc3：0.495691，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99865817 0.99369085]，Gmean：0.996171，mAUC：0.999965
# 	第2个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.999994
# 	第3个分类器分类结果：Recall[1.         0.99053628]，Gmean：0.995257，mAUC：0.999987
# 	第4个分类器分类结果：Recall[0.99932908 0.97791798]，Gmean：0.988566，mAUC：0.999952
# 	第5个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.99996
# 	第6个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999967
# 	第7个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999935
# 	第8个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999972
# 	第9个分类器分类结果：Recall[0.99932908 0.99684543]，Gmean：0.998086，mAUC：0.999983
# 	第10个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999928
# 	第11个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999903
# 	第12个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999982
# 	第13个分类器分类结果：Recall[0.99899363 0.98107256]，Gmean：0.989993，mAUC：0.999944
# 	第14个分类器分类结果：Recall[0.99865817 0.96214511]，Gmean：0.980232，mAUC：0.999666
# 	第15个分类器分类结果：Recall[0.99630996 0.99053628]，Gmean：0.993419，mAUC：0.999312
# 	第16个分类器分类结果：Recall[0.99865817 0.98422713]，Gmean：0.991416，mAUC：0.999945
# 	第17个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999951
# 	第18个分类器分类结果：Recall[0.99966454 0.98107256]，Gmean：0.990325，mAUC：0.999971
# 	第19个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999912
# 	第20个分类器分类结果：Recall[0.99865817 0.9873817 ]，Gmean：0.993004，mAUC：0.99992
# 	第21个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999984
# 	第22个分类器分类结果：Recall[0.99966454 0.99684543]，Gmean：0.998254，mAUC：0.999989
# 	第23个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999957
# 	第24个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999965
# 	第25个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999947
# 	第26个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999925
# 	第27个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999984
# 	第28个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999975
# 	第29个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.99995
# 	第30个分类器分类结果：Recall[0.99932908 0.96845426]，Gmean：0.983771，mAUC：0.999771
# 第30次执行：Gmean：0.993337，mAUC：0.999989，Acc1：0.998181，Acc2：0.993355，Acc3：0.494265，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99899363 1.        ]，Gmean：0.999497，mAUC：0.999992
# 	第2个分类器分类结果：Recall[0.99865817 0.98422713]，Gmean：0.991416，mAUC：0.99996
# 	第3个分类器分类结果：Recall[0.99865817 0.97476341]，Gmean：0.986638，mAUC：0.999913
# 	第4个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.99997
# 	第5个分类器分类结果：Recall[0.99530359 0.98422713]，Gmean：0.98975，mAUC：0.999715
# 	第6个分类器分类结果：Recall[0.99865817 0.97791798]，Gmean：0.988234，mAUC：0.999615
# 	第7个分类器分类结果：Recall[0.99932908 0.97791798]，Gmean：0.988566，mAUC：0.999941
# 	第8个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.99991
# 	第9个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.99998
# 	第10个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999989
# 	第11个分类器分类结果：Recall[0.99798725 0.99053628]，Gmean：0.994255，mAUC：0.999964
# 	第12个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.99994
# 	第13个分类器分类结果：Recall[0.99966454 0.95583596]，Gmean：0.977505，mAUC：0.999584
# 	第14个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999962
# 	第15个分类器分类结果：Recall[0.99932908 0.97476341]，Gmean：0.98697，mAUC：0.999964
# 	第16个分类器分类结果：Recall[0.99899363 0.98422713]，Gmean：0.991583，mAUC：0.999956
# 	第17个分类器分类结果：Recall[0.99932908 0.97160883]，Gmean：0.985371，mAUC：0.999926
# 	第18个分类器分类结果：Recall[0.99765179 0.99684543]，Gmean：0.997249，mAUC：0.99984
# 	第19个分类器分类结果：Recall[0.99932908 0.99053628]，Gmean：0.994923，mAUC：0.999962
# 	第20个分类器分类结果：Recall[0.99798725 0.98422713]，Gmean：0.991083，mAUC：0.999662
# 	第21个分类器分类结果：Recall[0.99798725 0.99369085]，Gmean：0.995837，mAUC：0.999966
# 	第22个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999961
# 	第23个分类器分类结果：Recall[0.99798725 1.        ]，Gmean：0.998993，mAUC：0.999992
# 	第24个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999929
# 	第25个分类器分类结果：Recall[0.99966454 0.99684543]，Gmean：0.998254，mAUC：0.999987
# 	第26个分类器分类结果：Recall[0.99865817 0.99369085]，Gmean：0.996171，mAUC：0.99997
# 	第27个分类器分类结果：Recall[0.99396176 0.93375394]，Gmean：0.963388，mAUC：0.997429
# 	第28个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999993
# 	第29个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999938
# 	第30个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.99993
# 第30次执行：Gmean：0.996506，mAUC：0.999988，Acc1：0.998787，Acc2：0.99651，Acc3：0.497116，集成的数量：30
# 	第1个分类器分类结果：Recall[0.99496813 0.90536278]，Gmean：0.949109，mAUC：0.997455
# 	第2个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999988
# 	第3个分类器分类结果：Recall[0.99731634 0.97160883]，Gmean：0.984379，mAUC：0.999701
# 	第4个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.99997
# 	第5个分类器分类结果：Recall[0.99899363 0.99369085]，Gmean：0.996339，mAUC：0.999901
# 	第6个分类器分类结果：Recall[0.99463267 0.99369085]，Gmean：0.994162，mAUC：0.999887
# 	第7个分类器分类结果：Recall[0.99865817 0.98422713]，Gmean：0.991416，mAUC：0.999826
# 	第8个分类器分类结果：Recall[0.99865817 0.99053628]，Gmean：0.994589，mAUC：0.999945
# 	第9个分类器分类结果：Recall[0.99798725 0.99053628]，Gmean：0.994255，mAUC：0.999912
# 	第10个分类器分类结果：Recall[0.99932908 0.99369085]，Gmean：0.996506，mAUC：0.999986
# 	第11个分类器分类结果：Recall[0.99966454 0.99369085]，Gmean：0.996673，mAUC：0.999967
# 	第12个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999983
# 	第13个分类器分类结果：Recall[0.99765179 0.99684543]，Gmean：0.997249，mAUC：0.999959
# 	第14个分类器分类结果：Recall[0.99899363 0.99053628]，Gmean：0.994756，mAUC：0.999969
# 	第15个分类器分类结果：Recall[0.99731634 0.99369085]，Gmean：0.995502，mAUC：0.999873
# 	第16个分类器分类结果：Recall[0.99966454 0.99053628]，Gmean：0.99509，mAUC：0.999984
# 	第17个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999891
# 	第18个分类器分类结果：Recall[0.99563905 0.9873817 ]，Gmean：0.991502，mAUC：0.999803
# 	第19个分类器分类结果：Recall[0.99932908 0.98107256]，Gmean：0.990159，mAUC：0.999905
# 	第20个分类器分类结果：Recall[0.99932908 0.9873817 ]，Gmean：0.993337，mAUC：0.999966
# 	第21个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.99997
# 	第22个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.99997
# 	第23个分类器分类结果：Recall[0.99966454 0.98422713]，Gmean：0.991916，mAUC：0.999979
# 	第24个分类器分类结果：Recall[0.99865817 0.9873817 ]，Gmean：0.993004，mAUC：0.999946
# 	第25个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999983
# 	第26个分类器分类结果：Recall[0.99932908 0.98422713]，Gmean：0.991749，mAUC：0.999749
# 	第27个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999929
# 	第28个分类器分类结果：Recall[0.99966454 0.93690852]，Gmean：0.967778，mAUC：0.999543
# 	第29个分类器分类结果：Recall[0.99966454 0.9873817 ]，Gmean：0.993504，mAUC：0.999963
# 	第30个分类器分类结果：Recall[0.99899363 0.9873817 ]，Gmean：0.993171，mAUC：0.999965
# 第30次执行：Gmean：0.994923，mAUC：0.999989，Acc1：0.998484，Acc2：0.994933，Acc3：0.495691，集成的数量：30
# *****************算法执行结束！******************
# 集成分类结果（平均值）：[0.02487308 0.02499973 0.0249621  0.02487332 0.01239227 0.75      ]

# %% [markdown]
# ## 写入到Excel

# %%
from utils.excel_utils import save_to_excel_2

columns = ['Gmean', 'MAUC', 'Acc1', 'Acc2', 'Acc3', 'num_ensemble']

save_path = 'C:/Users/Lenovo/Desktop/Stratified/7-3/MILE/' + datasetname + '/'
filename = datasetname
save_to_excel_2(save_path, filename, columns, ensembles_results)
# Out:
# Excel 文件已保存至: C:/Users/Lenovo/Desktop/Stratified/7-3/MILE/Pen_Digits/Pen_Digits.xlsx
# 'C:/Users/Lenovo/Desktop/Stratified/7-3/MILE/Pen_Digits/Pen_Digits.xlsx'
