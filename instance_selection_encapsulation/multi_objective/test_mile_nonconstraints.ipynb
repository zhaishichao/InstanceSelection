# %% [markdown]
# # E-SEIC
# Selection of evolutionary instances with constraints for unbalanced datasets

# %%
from utils.dataset_utils import get_distribution, k_fold_cross_validation
from instance_selection.parameter.parameter import *  # 导入参数的设定
from instance_selection_encapsulation.operator.init_toolbox import init_toolbox_eseic
from instance_selection_encapsulation.operator.metrics import calculate_gmean_mauc, calculate_average_accuracy, calculate_accuracy
from instance_selection_encapsulation.operator.genetic_operator import selTournamentNDCD
from instance_selection_encapsulation.operator.ensemble import vote_result_ensembles, ensemble_individuals
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.base import clone
import scipy.io as sio  # 从.mat文件中读取数据集
import random
import warnings
import numpy as np
import os
from openpyxl import Workbook

warnings.filterwarnings("ignore")  # 忽略警告
from utils.excel_utils import save_to_excel_2

# 数据的预处理
def data_process(dataset=None, distribution=False):
    datasetname = dataset.DATASETNAME.split('.')[0]
    mat_data = sio.loadmat(IMBALANCED_DATASET_PATH + dataset.DATASETNAME)  # 加载、划分数据集
    x = mat_data['X']
    y = mat_data['Y'][:, 0]  # mat_data['Y']得到的形状为[n,1]，通过[:,0]，得到形状[n,]
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y,
                                                        random_state=RANDOM_SEED)  # 划分数据集
    scaler = StandardScaler()  # 数据的标准化
    x_train = scaler.fit_transform(x_train)
    x_test = scaler.transform(x_test)
    unique_elements_all, classes_all, counts_all = get_distribution(y)  # 获取原始数据集分布
    unique_elements_train, classes_train, counts_train = get_distribution(y_train)  # 获取训练集分布
    unique_elements_test, classes_test, counts_test = get_distribution(y_test)  # 获取测试集分布
    weights_train = (1 / counts_train.astype(float)) / np.sum(1 / counts_train.astype(float))  # 计算每个类的权重，用于计算每个类别的权重
    if distribution:
        print(datasetname + f' distribution: {counts_all}')
        print(f'trainset distribution: {counts_train}')
        print(f'testset distribution: {counts_test}')
    model = MLPClassifier(hidden_layer_sizes=(dataset.HIDDEN_SIZE,), max_iter=dataset.MAX_ITER,
                          random_state=RANDOM_SEED, learning_rate_init=dataset.LEARNING_RATE)

    return x_train, x_test, y_train, y_test, weights_train, clone(model)

def main(x_train, y_train, model, balanced_method='random'):
    ####################################种群的初始化###########################
    pop = toolbox.population(n=POPSIZE)  # 个体编码默认全为0
    pop = toolbox.init_population(pop, balanced_method=balanced_method)  # 初始化种群中的个体
    toolbox.evaluate(pop)  # 计算个体的适应度
    ####################################种群的迭代#################################################
    for gen in range(1, NGEN + 1):
        offspring = selTournamentNDCD(pop, POPSIZE, tournsize=3)  # 锦标赛选择（1、先根据非支配排序的等级2、再根据拥挤距离）
        offspring = [toolbox.clone(ind) for ind in offspring]
        for i in range(0, len(offspring) - 1, 2):
            if random.random() <= CXPB:
                offspring[i], offspring[i + 1] = toolbox.mate(offspring[i], offspring[i + 1])  # 单点交叉
            offspring[i] = toolbox.mutate(offspring[i], MR)[0]  # 二进制反转突变
            offspring[i + 1] = toolbox.mutate(offspring[i + 1], MR)[0]  # 二进制反转突变
            del offspring[i].fitness.values, offspring[i + 1].fitness.values
        #############################################################合并、去重#####################################################
        offspring = toolbox.individuals_constraints(offspring)  # 限制每个类至少有一个实例被选择
        pop = pop + offspring  # 种群的合并
        pop, _ = toolbox.remove_duplicates(pop)  # 去重
        while len(pop) < POPSIZE:  # 保证种群大小为POPSIZE
            add_individual = []
            num_add = POPSIZE - len(pop)
            for i in range(0, num_add):
                index = random.randint(0, len(offspring) - 1)  # 在0-len(offspring)范围内随机产生一个索引
                offspring[index] = toolbox.mutate(offspring[index], MR)[0]  # 选择index对应的个体进行突变
                del offspring[index].fitness.values
                add_individual.append(offspring[index])
            add_individual = toolbox.individuals_constraints(add_individual)  # 限制每个类至少有一个实例被选择
            pop = pop + add_individual  # 种群的合并
            pop, _ = toolbox.remove_duplicates(pop)  # 去重
        pop = toolbox.individuals_constraints(pop)  # 限制每个类至少有5个实例被选择
        toolbox.evaluate(pop)  # 计算新种群适应度
        # 非支配排序
        pop, pareto_fronts = toolbox.select(pop, POPSIZE)
    ensemble_classifiers = ensemble_individuals(pop, model, x_train, y_train)
    return ensemble_classifiers

def save_to_excel(data, save_path, filename='avg_results'):
    """
    将列表数据逐行写入Excel文件
    参数:
        data: 二维列表，每个子列表代表一行数据
        filename: 输出的Excel文件名(默认为output.xlsx)
    """
    # 创建一个新的工作簿
    wb = Workbook()
    # 获取活动的工作表
    ws = wb.active
    # 逐行写入数据
    for row in data:
        avg=row[1].tolist()
        avg.insert(0, row[0])
        std=row[2].tolist()     
        std.insert(0, row[0])
        ws.append(avg)
        ws.append(std)
    # 创建 Excel 文件完整路径
    file_path = os.path.join(save_path, filename + ".xlsx")
    # 保存Excel文件
    wb.save(file_path)
    print(f"数据已成功写入到 {file_path}")

# %% [markdown]
# ## 运行

# %%
# DATASETS = [Balance_Scale,Dermatology,Ecoli,Car,Pen_Digits,WallRobot,German,Wine,Nursery,Penbased,USPS,Satellite,Page_Blocks,Shuttle,Contraceptive,Automobile,Ovarian]  # 数据集名称（包含对应的参数配置）
DATASETS = [Penbased,USPS,Satellite,Page_Blocks,Shuttle,Contraceptive,Automobile,Ovarian]  # 数据集名称（包含对应的参数配置）
if __name__ == "__main__":
    save_path = 'C:/Users/Lenovo/Desktop/Non-constraints/'
    columns = ['Gmean', 'MAUC', 'Acc1', 'Acc2', 'Acc3', 'num_ensemble']
    datasets_ensembles_results = [[] for _ in range(len(DATASETS))]
    print("*****************算法开始执行：******************")
    for j, dataset in enumerate(DATASETS):
        x_train, x_test, y_train, y_test, weights_train, model = data_process(dataset=dataset, distribution=False)
        toolbox = init_toolbox_eseic(model, x_train, y_train, weights_train, None, n_splits=N_SPLITS - 2,
                                     random_seed=42)  # 初始化toolbox
        num_run = 40  # 运行次数
        ensembles_results = [[] for _ in range(num_run)]
        for i in range(num_run):
            ensemble_classifiers = main(x_train, y_train, model=model, balanced_method='random')
            vote_pred_prob = vote_result_ensembles(ensemble_classifiers, x_test)  # 默认预测结果是软标签
            vote_pred = np.argmax(vote_pred_prob, axis=1)
            gmean, mauc, recall_per_class = calculate_gmean_mauc(vote_pred_prob, y_test)
            acc1, acc2, acc3 = calculate_accuracy(vote_pred, y_test, weights_train)
            ensembles_results[i] = [gmean, mauc, acc1, acc2, acc3, len(ensemble_classifiers)]
            print(f"第{i + 1}次执行：Gmean：{gmean}，mAUC：{mauc}")
        save_to_excel_2(save_path + dataset.DATASETNAME.split('.')[0] + '/', dataset.DATASETNAME.split('.')[0], columns, ensembles_results)
        ensembles_result_mean = np.mean(ensembles_results, axis=0)
        # 计算ensembles_resultsz中每一列的标准差
        ensembles_result_std = np.std(ensembles_results, axis=0)
        print(f'集成分类结果（平均值）：{ensembles_result_mean}')
        print(f'集成分类结果（标准差）：{ensembles_result_std}')
        datasets_ensembles_results[j] = [dataset.DATASETNAME.split('.')[0], ensembles_result_mean, ensembles_result_std]
    print("*****************算法执行结束！******************")
    # 写入到Excel     
    save_to_excel(datasets_ensembles_results,save_path)
# Out:
# *****************算法开始执行：******************
# 第1次执行：Gmean：0.981858，mAUC：0.999026
# 第2次执行：Gmean：0.962979，mAUC：0.998905
# 第3次执行：Gmean：0.964934，mAUC：0.998893
# 第4次执行：Gmean：0.978931，mAUC：0.998088
# 第5次执行：Gmean：0.978023，mAUC：0.998481
# 第6次执行：Gmean：0.964119，mAUC：0.99912
# 第7次执行：Gmean：0.964119，mAUC：0.998936
# 第8次执行：Gmean：0.954037，mAUC：0.998022
# 第9次执行：Gmean：0.959813，mAUC：0.998773
# 第10次执行：Gmean：0.978535，mAUC：0.998841
# 第11次执行：Gmean：0.972621，mAUC：0.998586
# 第12次执行：Gmean：0.972621，mAUC：0.999025
# 第13次执行：Gmean：0.969214，mAUC：0.999403
# 第14次执行：Gmean：0.975618，mAUC：0.998083
# 第15次执行：Gmean：0.978644，mAUC：0.998538
# 第16次执行：Gmean：0.966559，mAUC：0.998506
# 第17次执行：Gmean：0.964934，mAUC：0.998947
# 第18次执行：Gmean：0.978841，mAUC：0.9985
# 第19次执行：Gmean：0.955663，mAUC：0.998557
# 第20次执行：Gmean：0.975618，mAUC：0.9988
# 第21次执行：Gmean：0.981858，mAUC：0.998016
# 第22次执行：Gmean：0.966041，mAUC：0.99858
# 第23次执行：Gmean：0.981858，mAUC：0.999002
# 第24次执行：Gmean：0.967908，mAUC：0.99871
# 第25次执行：Gmean：0.978931，mAUC：0.998236
# 第26次执行：Gmean：0.965695，mAUC：0.998422
# 第27次执行：Gmean：0.963589，mAUC：0.998465
# 第28次执行：Gmean：0.971567，mAUC：0.998049
# 第29次执行：Gmean：0.975107，mAUC：0.998746
# 第30次执行：Gmean：0.96695，mAUC：0.998702
# 第31次执行：Gmean：0.966364，mAUC：0.998419
# 第32次执行：Gmean：0.957197，mAUC：0.99798
# 第33次执行：Gmean：0.978535，mAUC：0.99878
# 第34次执行：Gmean：0.943776，mAUC：0.99795
# 第35次执行：Gmean：0.959577，mAUC：0.998837
# 第36次执行：Gmean：0.981858，mAUC：0.999093
# 第37次执行：Gmean：0.958908，mAUC：0.998223
# 第38次执行：Gmean：0.95852，mAUC：0.999225
# 第39次执行：Gmean：0.975727，mAUC：0.999173
# 第40次执行：Gmean：0.972544，mAUC：0.998781
# Excel 文件已保存至: C:/Users/Lenovo/Desktop/Non-constraints/Penbased/Penbased.xlsx
# 集成分类结果（平均值）：[ 0.96925478  0.99863548  0.96992433  0.9699767   0.09701623 30.        ]
# 集成分类结果（标准差）：[0.00904303 0.00037972 0.00858134 0.0086164  0.00086272 0.        ]
# 第1次执行：Gmean：0.963334，mAUC：0.998518
# 第2次执行：Gmean：0.959332，mAUC：0.998488
# 第3次执行：Gmean：0.962863，mAUC：0.998377
# 第4次执行：Gmean：0.958839，mAUC：0.998525
# 第5次执行：Gmean：0.962143，mAUC：0.998702
# 第6次执行：Gmean：0.962891，mAUC：0.998417
# 第7次执行：Gmean：0.962628，mAUC：0.998611
# 第8次执行：Gmean：0.95987，mAUC：0.998637
# 第9次执行：Gmean：0.960553，mAUC：0.998411
# 第10次执行：Gmean：0.9615，mAUC：0.998449
# 第11次执行：Gmean：0.962751，mAUC：0.998467
# 第12次执行：Gmean：0.961421，mAUC：0.99846
# 第13次执行：Gmean：0.961401，mAUC：0.998379
# 第14次执行：Gmean：0.959973，mAUC：0.998703
# 第15次执行：Gmean：0.961671，mAUC：0.998531
# 第16次执行：Gmean：0.962984，mAUC：0.998652
# 第17次执行：Gmean：0.962614，mAUC：0.998181
# 第18次执行：Gmean：0.965016，mAUC：0.998524
# 第19次执行：Gmean：0.961566，mAUC：0.998453
# 第20次执行：Gmean：0.960667，mAUC：0.99865
# 第21次执行：Gmean：0.960596，mAUC：0.99857
# 第22次执行：Gmean：0.95974，mAUC：0.998196
# 第23次执行：Gmean：0.9578，mAUC：0.998225
# 第24次执行：Gmean：0.962851，mAUC：0.998445
# 第25次执行：Gmean：0.962794，mAUC：0.99851
# 第26次执行：Gmean：0.959811，mAUC：0.998676
# 第27次执行：Gmean：0.959435，mAUC：0.99865
# 第28次执行：Gmean：0.960509，mAUC：0.998284
# 第29次执行：Gmean：0.961569，mAUC：0.998399
# 第30次执行：Gmean：0.961842，mAUC：0.998792
# 第31次执行：Gmean：0.961305，mAUC：0.998497
# 第32次执行：Gmean：0.964811，mAUC：0.998655
# 第33次执行：Gmean：0.960592，mAUC：0.998538
# 第34次执行：Gmean：0.961741，mAUC：0.998488
# 第35次执行：Gmean：0.961098，mAUC：0.998213
# 第36次执行：Gmean：0.962673，mAUC：0.998547
# 第37次执行：Gmean：0.96123，mAUC：0.998373
# 第38次执行：Gmean：0.960554，mAUC：0.998562
# 第39次执行：Gmean：0.961679，mAUC：0.998577
# 第40次执行：Gmean：0.961293，mAUC：0.998472
# Excel 文件已保存至: C:/Users/Lenovo/Desktop/Non-constraints/USPS/USPS.xlsx
# 集成分类结果（平均值）：[ 0.9614485   0.9984951   0.96497315  0.9616383   0.09588508 30.        ]
# 集成分类结果（标准差）：[0.00148581 0.00014342 0.00126713 0.00145353 0.00016626 0.        ]
# 第1次执行：Gmean：0.870738，mAUC：0.984605
# 第2次执行：Gmean：0.872832，mAUC：0.984751
# 第3次执行：Gmean：0.872019，mAUC：0.984911
# 第4次执行：Gmean：0.877418，mAUC：0.98519
# 第5次执行：Gmean：0.875552，mAUC：0.985447
# 第6次执行：Gmean：0.873382，mAUC：0.985187
# 第7次执行：Gmean：0.869165，mAUC：0.984325
# 第8次执行：Gmean：0.873992，mAUC：0.984702
# 第9次执行：Gmean：0.871499，mAUC：0.984795
# 第10次执行：Gmean：0.876227，mAUC：0.985002
# 第11次执行：Gmean：0.874228，mAUC：0.985004
# 第12次执行：Gmean：0.872806，mAUC：0.984904
# 第13次执行：Gmean：0.86982，mAUC：0.984629
# 第14次执行：Gmean：0.873112，mAUC：0.984714
# 第15次执行：Gmean：0.869616，mAUC：0.985085
# 第16次执行：Gmean：0.872269，mAUC：0.984743
# 第17次执行：Gmean：0.868099，mAUC：0.983912
# 第18次执行：Gmean：0.877717，mAUC：0.984703
# 第19次执行：Gmean：0.880454，mAUC：0.985236
# 第20次执行：Gmean：0.873136，mAUC：0.984546
# 第21次执行：Gmean：0.871099，mAUC：0.984685
# 第22次执行：Gmean：0.869723，mAUC：0.985249
# 第23次执行：Gmean：0.871549，mAUC：0.984687
# 第24次执行：Gmean：0.875424，mAUC：0.985171
# 第25次执行：Gmean：0.873962，mAUC：0.984973
# 第26次执行：Gmean：0.870675，mAUC：0.984922
# 第27次执行：Gmean：0.872776，mAUC：0.98525
# 第28次执行：Gmean：0.875607，mAUC：0.98486
# 第29次执行：Gmean：0.874878，mAUC：0.984977
# 第30次执行：Gmean：0.874673，mAUC：0.985219
# 第31次执行：Gmean：0.871564，mAUC：0.984937
# 第32次执行：Gmean：0.872149，mAUC：0.984887
# 第33次执行：Gmean：0.873083，mAUC：0.984939
# 第34次执行：Gmean：0.871267，mAUC：0.984032
# 第35次执行：Gmean：0.869954，mAUC：0.985263
# 第36次执行：Gmean：0.873961，mAUC：0.985767
# 第37次执行：Gmean：0.86833，mAUC：0.984127
# 第38次执行：Gmean：0.875539，mAUC：0.984997
# 第39次执行：Gmean：0.867542，mAUC：0.984387
# 第40次执行：Gmean：0.876386，mAUC：0.984708
# Excel 文件已保存至: C:/Users/Lenovo/Desktop/Non-constraints/Satellite/Satellite.xlsx
# 集成分类结果（平均值）：[ 0.87285555  0.9848607   0.89743655  0.8807925   0.1435414  30.        ]
# 集成分类结果（标准差）：[0.0027958  0.00036765 0.00244542 0.00240086 0.00066894 0.        ]
# 第1次执行：Gmean：0.796019，mAUC：0.976643
# 第2次执行：Gmean：0.799075，mAUC：0.976353
# 第3次执行：Gmean：0.793648，mAUC：0.976206
# 第4次执行：Gmean：0.81861，mAUC：0.974069
# 第5次执行：Gmean：0.829732，mAUC：0.978229
# 第6次执行：Gmean：0.785576，mAUC：0.975124
# 第7次执行：Gmean：0.787712，mAUC：0.976094
# 第8次执行：Gmean：0.791329，mAUC：0.973356
# 第9次执行：Gmean：0.7968，mAUC：0.978875
# 第10次执行：Gmean：0.815164，mAUC：0.976283
# 第11次执行：Gmean：0.816482，mAUC：0.97833
# 第12次执行：Gmean：0.818386，mAUC：0.977865
# 第13次执行：Gmean：0.796812，mAUC：0.981186
# 第14次执行：Gmean：0.808576，mAUC：0.976624
# 第15次执行：Gmean：0.809828，mAUC：0.975585
# 第16次执行：Gmean：0.801957，mAUC：0.978247
# 第17次执行：Gmean：0.789099，mAUC：0.979481
# 第18次执行：Gmean：0.800954，mAUC：0.976173
# 第19次执行：Gmean：0.820284，mAUC：0.975728
# 第20次执行：Gmean：0.795404，mAUC：0.978329
# 第21次执行：Gmean：0.824717，mAUC：0.978619
# 第22次执行：Gmean：0.785361，mAUC：0.974542
# 第23次执行：Gmean：0.800441，mAUC：0.979097
# 第24次执行：Gmean：0.815084，mAUC：0.975743
# 第25次执行：Gmean：0.806179，mAUC：0.973673
# 第26次执行：Gmean：0.795404，mAUC：0.974589
# 第27次执行：Gmean：0.787339，mAUC：0.976142
# 第28次执行：Gmean：0.796564，mAUC：0.975184
# 第29次执行：Gmean：0.804101，mAUC：0.978499
# 第30次执行：Gmean：0.795295，mAUC：0.978496
# 第31次执行：Gmean：0.811786，mAUC：0.978186
# 第32次执行：Gmean：0.795295，mAUC：0.976588
# 第33次执行：Gmean：0.805139，mAUC：0.977322
# 第34次执行：Gmean：0.804589，mAUC：0.974939
# 第35次执行：Gmean：0.792271，mAUC：0.97325
# 第36次执行：Gmean：0.795077，mAUC：0.977263
# 第37次执行：Gmean：0.802397，mAUC：0.978815
# 第38次执行：Gmean：0.800661，mAUC：0.977912
# 第39次执行：Gmean：0.834319，mAUC：0.978011
# 第40次执行：Gmean：0.806321，mAUC：0.978298
# Excel 文件已保存至: C:/Users/Lenovo/Desktop/Non-constraints/Page_Blocks/Page_Blocks.xlsx
# 集成分类结果（平均值）：[ 0.80324467  0.9768487   0.97056908  0.81145435  0.14458207 30.        ]
# 集成分类结果（标准差）：[0.01196511 0.00182281 0.00188882 0.01058908 0.0065464  0.        ]
# 第1次执行：Gmean：1.0，mAUC：1.0
# 第2次执行：Gmean：1.0，mAUC：1.0
# 第3次执行：Gmean：1.0，mAUC：1.0
# 第4次执行：Gmean：1.0，mAUC：1.0
# 第5次执行：Gmean：1.0，mAUC：1.0
# 第6次执行：Gmean：1.0，mAUC：1.0
# 第7次执行：Gmean：1.0，mAUC：1.0
# 第8次执行：Gmean：1.0，mAUC：1.0
# 第9次执行：Gmean：1.0，mAUC：1.0
# 第10次执行：Gmean：1.0，mAUC：1.0
# 第11次执行：Gmean：1.0，mAUC：1.0
# 第12次执行：Gmean：1.0，mAUC：1.0
# 第13次执行：Gmean：1.0，mAUC：1.0
# 第14次执行：Gmean：1.0，mAUC：1.0
# 第15次执行：Gmean：1.0，mAUC：1.0
# 第16次执行：Gmean：1.0，mAUC：1.0
# 第17次执行：Gmean：1.0，mAUC：1.0
# 第18次执行：Gmean：1.0，mAUC：1.0
# 第19次执行：Gmean：1.0，mAUC：1.0
# 第20次执行：Gmean：1.0，mAUC：1.0
# 第21次执行：Gmean：1.0，mAUC：1.0
# 第22次执行：Gmean：1.0，mAUC：1.0
# 第23次执行：Gmean：1.0，mAUC：1.0
# 第24次执行：Gmean：1.0，mAUC：1.0
# 第25次执行：Gmean：1.0，mAUC：1.0
# 第26次执行：Gmean：1.0，mAUC：1.0
# 第27次执行：Gmean：1.0，mAUC：1.0
# 第28次执行：Gmean：1.0，mAUC：1.0
# 第29次执行：Gmean：1.0，mAUC：1.0
# 第30次执行：Gmean：1.0，mAUC：1.0
# 第31次执行：Gmean：1.0，mAUC：1.0
# 第32次执行：Gmean：1.0，mAUC：1.0
# 第33次执行：Gmean：1.0，mAUC：1.0
# 第34次执行：Gmean：1.0，mAUC：1.0
# 第35次执行：Gmean：1.0，mAUC：1.0
# 第36次执行：Gmean：1.0，mAUC：1.0
# 第37次执行：Gmean：1.0，mAUC：1.0
# 第38次执行：Gmean：1.0，mAUC：1.0
# 第39次执行：Gmean：1.0，mAUC：1.0
# 第40次执行：Gmean：1.0，mAUC：1.0
# Excel 文件已保存至: C:/Users/Lenovo/Desktop/Non-constraints/Shuttle/Shuttle.xlsx
# 集成分类结果（平均值）：[ 1.        1.        1.        1.        0.333333 30.      ]
# 集成分类结果（标准差）：[0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.22044605e-16 0.00000000e+00]
# 第1次执行：Gmean：0.527512，mAUC：0.736879
# 第2次执行：Gmean：0.553073，mAUC：0.745192
# 第3次执行：Gmean：0.540556，mAUC：0.743248
# 第4次执行：Gmean：0.501828，mAUC：0.744529
# 第5次执行：Gmean：0.54924，mAUC：0.743291
# 第6次执行：Gmean：0.538454，mAUC：0.744513
# 第7次执行：Gmean：0.547237，mAUC：0.743272
# 第8次执行：Gmean：0.514024，mAUC：0.734739
# 第9次执行：Gmean：0.512809，mAUC：0.736595
# 第10次执行：Gmean：0.520314，mAUC：0.739221
# 第11次执行：Gmean：0.546409，mAUC：0.742932
# 第12次执行：Gmean：0.540337，mAUC：0.743515
# 第13次执行：Gmean：0.536212，mAUC：0.739085
# 第14次执行：Gmean：0.52024，mAUC：0.73115
# 第15次执行：Gmean：0.501395，mAUC：0.736122
# 第16次执行：Gmean：0.515302，mAUC：0.738516
# 第17次执行：Gmean：0.539083，mAUC：0.741788
# 第18次执行：Gmean：0.530704，mAUC：0.742214
# 第19次执行：Gmean：0.53734，mAUC：0.748272
# 第20次执行：Gmean：0.525723，mAUC：0.740927
# 第21次执行：Gmean：0.55104，mAUC：0.73818
# 第22次执行：Gmean：0.531935，mAUC：0.74219
# 第23次执行：Gmean：0.52344，mAUC：0.738243
# 第24次执行：Gmean：0.534622，mAUC：0.751473
# 第25次执行：Gmean：0.526119，mAUC：0.740256
# 第26次执行：Gmean：0.546214，mAUC：0.74306
# 第27次执行：Gmean：0.553556，mAUC：0.74033
# 第28次执行：Gmean：0.51844，mAUC：0.748423
# 第29次执行：Gmean：0.548474，mAUC：0.740367
# 第30次执行：Gmean：0.529997，mAUC：0.746347
# 第31次执行：Gmean：0.506155，mAUC：0.738142
# 第32次执行：Gmean：0.54532，mAUC：0.738506
# 第33次执行：Gmean：0.518239，mAUC：0.737113
# 第34次执行：Gmean：0.538359，mAUC：0.741782
# 第35次执行：Gmean：0.545553，mAUC：0.731536
# 第36次执行：Gmean：0.538454，mAUC：0.733303
# 第37次执行：Gmean：0.531004，mAUC：0.742243
# 第38次执行：Gmean：0.542138，mAUC：0.741923
# 第39次执行：Gmean：0.538247，mAUC：0.742774
# 第40次执行：Gmean：0.529833，mAUC：0.740305
# Excel 文件已保存至: C:/Users/Lenovo/Desktop/Non-constraints/Contraceptive/Contraceptive.xlsx
# 集成分类结果（平均值）：[ 0.53237328  0.7408124   0.55842762  0.54001565  0.17288555 30.        ]
# 集成分类结果（标准差）：[0.01383917 0.00427729 0.00950343 0.01099756 0.00506605 0.        ]
# 第1次执行：Gmean：0.659454，mAUC：0.919596
# 第2次执行：Gmean：0.71254，mAUC：0.939149
# 第3次执行：Gmean：0.727714，mAUC：0.926101
# 第4次执行：Gmean：0.737552，mAUC：0.944383
# 第5次执行：Gmean：0.657039，mAUC：0.92603
# 第6次执行：Gmean：0.741719，mAUC：0.923417
# 第7次执行：Gmean：0.687026，mAUC：0.935114
# 第8次执行：Gmean：0.73485，mAUC：0.930376
# 第9次执行：Gmean：0.775571，mAUC：0.934084
# 第10次执行：Gmean：0.707409，mAUC：0.916785
# 第11次执行：Gmean：0.687026，mAUC：0.933423
# 第12次执行：Gmean：0.747799，mAUC：0.937103
# 第13次执行：Gmean：0.689552，mAUC：0.929833
# 第14次执行：Gmean：0.675173，mAUC：0.923668
# 第15次执行：Gmean：0.768388，mAUC：0.939692
# 第16次执行：Gmean：0.751746，mAUC：0.946858
# 第17次执行：Gmean：0.71516，mAUC：0.934524
# 第18次执行：Gmean：0.73485，mAUC：0.934514
# 第19次执行：Gmean：0.760927，mAUC：0.923819
# 第20次执行：Gmean：0.821503，mAUC：0.95994
# 第21次执行：Gmean：0.71516，mAUC：0.940575
# 第22次执行：Gmean：0.784751，mAUC：0.951795
# 第23次执行：Gmean：0.71516，mAUC：0.921018
# 第24次执行：Gmean：0.805992，mAUC：0.913979
# 第25次执行：Gmean：0.71516，mAUC：0.931089
# 第26次执行：Gmean：0.750499，mAUC：0.933612
# 第27次执行：Gmean：0.671031，mAUC：0.90753
# 第28次执行：Gmean：0.741719，mAUC：0.933891
# 第29次执行：Gmean：0.784751，mAUC：0.941908
# 第30次执行：Gmean：0.757083，mAUC：0.931127
# 第31次执行：Gmean：0.770812，mAUC：0.929346
# 第32次执行：Gmean：0.659454，mAUC：0.924443
# 第33次执行：Gmean：0.695951，mAUC：0.921036
# 第34次执行：Gmean：0.727714，mAUC：0.899849
# 第35次执行：Gmean：0.689552，mAUC：0.919605
# 第36次执行：Gmean：0.671031，mAUC：0.915221
# 第37次执行：Gmean：0.755132，mAUC：0.926299
# 第38次执行：Gmean：0.718381，mAUC：0.936598
# 第39次执行：Gmean：0.727714，mAUC：0.93433
# 第40次执行：Gmean：0.683945，mAUC：0.931623
# Excel 文件已保存至: C:/Users/Lenovo/Desktop/Non-constraints/Automobile/Automobile.xlsx
# 集成分类结果（平均值）：[ 0.72584975  0.93008207  0.73723395  0.7310318   0.14548567 30.        ]
# 集成分类结果（标准差）：[0.04059262 0.01137289 0.04024313 0.03837728 0.00744732 0.        ]
# 第1次执行：Gmean：0.971242，mAUC：0.999244
# 第2次执行：Gmean：0.971242，mAUC：0.999244
# 第3次执行：Gmean：0.971242，mAUC：0.996221
# 第4次执行：Gmean：0.971242，mAUC：0.999244
# 第5次执行：Gmean：0.989743，mAUC：0.99093
# 第6次执行：Gmean：0.971242，mAUC：0.996977
# 第7次执行：Gmean：0.989743，mAUC：0.995465
# 第8次执行：Gmean：0.989743，mAUC：0.997732
# 第9次执行：Gmean：0.971242，mAUC：0.996221
# 第10次执行：Gmean：0.971242，mAUC：0.997732
# 第11次执行：Gmean：0.989743，mAUC：0.997732
# 第12次执行：Gmean：0.989743，mAUC：0.996977
# 第13次执行：Gmean：0.989743，mAUC：0.996977
# 第14次执行：Gmean：0.971242，mAUC：0.996977
# 第15次执行：Gmean：0.971242，mAUC：0.997732
# 第16次执行：Gmean：0.989743，mAUC：0.996977
# 第17次执行：Gmean：0.952381，mAUC：0.997732
# 第18次执行：Gmean：0.971242，mAUC：0.997732
# 第19次执行：Gmean：0.989743，mAUC：0.999244
# 第20次执行：Gmean：0.971242，mAUC：0.993953
# 第21次执行：Gmean：0.989743，mAUC：0.995465
# 第22次执行：Gmean：0.989743，mAUC：0.997732
# 第23次执行：Gmean：0.971242，mAUC：0.995465
# 第24次执行：Gmean：0.989743，mAUC：1.0
# 第25次执行：Gmean：0.971242，mAUC：0.996977
# 第26次执行：Gmean：0.989743，mAUC：0.996977
# 第27次执行：Gmean：0.989743，mAUC：0.997732
# 第28次执行：Gmean：0.989743，mAUC：0.996977
# 第29次执行：Gmean：0.971242，mAUC：0.996977
# 第30次执行：Gmean：0.971242，mAUC：0.999244
# 第31次执行：Gmean：0.971242，mAUC：0.996977
# 第32次执行：Gmean：0.971242，mAUC：0.996977
# 第33次执行：Gmean：0.989743，mAUC：0.997732
# 第34次执行：Gmean：0.971242，mAUC：0.996977
# 第35次执行：Gmean：0.971242，mAUC：0.997732
# 第36次执行：Gmean：0.989743，mAUC：0.997732
# 第37次执行：Gmean：0.952381，mAUC：0.996977
# 第38次执行：Gmean：0.989743，mAUC：0.997732
# 第39次执行：Gmean：0.971242，mAUC：0.995465
# 第40次执行：Gmean：0.989743，mAUC：0.991686
# Excel 文件已保存至: C:/Users/Lenovo/Desktop/Non-constraints/Ovarian/Ovarian.xlsx
# 集成分类结果（平均值）：[ 0.9786244   0.9970144   0.9789472   0.97868465  0.48921675 30.        ]
# 集成分类结果（标准差）：[0.01083126 0.00177209 0.00767237 0.01079822 0.00689347 0.        ]
# *****************算法执行结束！******************
# 数据已成功写入到 C:/Users/Lenovo/Desktop/Non-constraints/avg_results.xlsx
