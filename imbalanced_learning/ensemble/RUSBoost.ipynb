# %%
import os
from openpyxl.workbook import Workbook
from sklearn import clone
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imbens.ensemble import BalancedRandomForestClassifier
from imbens.ensemble import EasyEnsembleClassifier
from imbens.ensemble import KmeansSMOTEBoostClassifier
from instance_selection.operator.metrics import calculate_gmean_mauc
from instance_selection.parameter.parameter import *  # 导入参数的设定
import scipy.io as sio  # 从.mat文件中读取数据集


def data_process(dataset=None):
    mat_data = sio.loadmat(IMBALANCED_DATASET_PATH + dataset.DATASETNAME)  # 加载、划分数据集
    x = mat_data['X']
    y = mat_data['Y'][:, 0]  # mat_data['Y']得到的形状为[n,1]，通过[:,0]，得到形状[n,]
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y,
                                                        random_state=RANDOM_SEED)  # 划分数据集
    scaler = StandardScaler()  # 数据的标准化
    x_train = scaler.fit_transform(x_train)
    x_test = scaler.transform(x_test)
    model = MLPClassifier(hidden_layer_sizes=(dataset.HIDDEN_SIZE,), max_iter=dataset.MAX_ITER,
                          random_state=RANDOM_SEED, learning_rate_init=dataset.LEARNING_RATE)
    return x_train, x_test, y_train, y_test, clone(model)


def save_to_excel(data, save_path, filename='avg_results'):
    """
    将列表数据逐行写入Excel文件
    参数:
        data: 二维列表，每个子列表代表一行数据
        filename: 输出的Excel文件名(默认为output.xlsx)
    """
    # 创建一个新的工作簿
    wb = Workbook()
    # 获取活动的工作表
    ws = wb.active
    # 逐行写入数据
    for row in data:
        avg = row[1].tolist()
        avg.insert(0, row[0])
        std = row[2].tolist()
        std.insert(0, row[0])
        ws.append(avg)
        ws.append(std)
    # 创建 Excel 文件完整路径
    file_path = os.path.join(save_path, filename + ".xlsx")
    # 保存Excel文件
    wb.save(file_path)
    print(f"数据已成功写入到 {file_path}")

# %%
from imblearn.under_sampling import OneSidedSelection, NearMiss
from sklearn.tree import DecisionTreeClassifier
from imblearn.over_sampling import ADASYN
from imbalanced_learning.rbu import RBU
from imblearn.combine import SMOTETomek, SMOTEENN
from imbens.ensemble import BalanceCascadeClassifier, CompatibleBaggingClassifier, RUSBoostClassifier, \
    SMOTEBaggingClassifier
from utils.excel_utils import save_to_excel_2
import numpy as np

DATASETS = [Balance_Scale, Dermatology, Ecoli, Car, Pen_Digits, WallRobot, German, Wine, Nursery, Penbased, USPS,
            Satellite, Page_Blocks, Shuttle, Contraceptive, Automobile, Ovarian]  # 数据集名称（包含对应的参数配置）

if __name__ == "__main__":
    save_path = 'C:/Users/zsc/Desktop/NOS/'
    columns = ['Gmean', 'MAUC']
    datasets_ensembles_results = [[] for _ in range(len(DATASETS))]
    print("*****************算法开始执行：******************")
    for j, dataset in enumerate(DATASETS):
        x_train, x_test, y_train, y_test, model = data_process(dataset=dataset)
        num_run = 40  # 运行次数
        ensembles_results = [[] for _ in range(num_run)]

        for i in range(num_run):
            # clf = EasyEnsembleClassifier(estimator=clone(model), random_state=42 + np.random.randint(0, 1000),
            #                              n_estimators=30) # EasyEnsembleClassifier
            # clf = BalancedRandomForestClassifier(n_estimators=30, random_state=42 + np.random.randint(0, 1000))
            # clf = KmeansSMOTEBoostClassifier(random_state=42 + np.random.randint(0, 1000),
            #                                 n_estimators=30)
            # clf = BalanceCascadeClassifier(estimator=clone(model), random_state=42 + np.random.randint(0, 1000),
            #                               n_estimators=30) 
            clf  = MLPClassifier(hidden_layer_sizes=(dataset.HIDDEN_SIZE,), max_iter=dataset.MAX_ITER,
                          random_state=RANDOM_SEED+ np.random.randint(0, 1000), learning_rate_init=dataset.LEARNING_RATE)
            #resemple = SMOTETomek(random_state=42 + + np.random.randint(0, 1000))
            #resemple = SMOTEENN(random_state=42 + + np.random.randint(0, 1000))
            # resemple = NearMiss()
            # x_res, y_res = resemple.fit_resample(x_train, y_train)
            clf.fit(x_train, y_train)
            y_pred_prob = clf.predict_proba(x_test)  # 默认预测结果是软标签
            gmean, mauc, recall_per_class = calculate_gmean_mauc(y_pred_prob, y_test)

            ensembles_results[i] = [gmean, mauc]
            print(f"第{i + 1}次执行：Gmean：{gmean}，mAUC：{mauc}")
        save_to_excel_2(save_path + dataset.DATASETNAME.split('.')[0] + '/', dataset.DATASETNAME.split('.')[0], columns,
                        ensembles_results)
        ensembles_result_mean = np.mean(ensembles_results, axis=0)
        # 计算ensembles_resultsz中每一列的标准差
        ensembles_result_std = np.std(ensembles_results, axis=0)
        print(f'集成分类结果（平均值）：{ensembles_result_mean}')
        print(f'集成分类结果（标准差）：{ensembles_result_std}')
        datasets_ensembles_results[j] = [dataset.DATASETNAME.split('.')[0], ensembles_result_mean, ensembles_result_std]
    print("*****************算法执行结束！******************")
    # 写入到Excel     
    save_to_excel(datasets_ensembles_results, save_path)
# Out:
# *****************算法开始执行：******************
# 第1次执行：Gmean：0.958173，mAUC：0.991059
# 第2次执行：Gmean：0.958354，mAUC：0.988783
# 第3次执行：Gmean：0.923704，mAUC：0.989085
# 第4次执行：Gmean：0.913867，mAUC：0.991798
# 第5次执行：Gmean：0.869848，mAUC：0.983033
# 第6次执行：Gmean：0.962142，mAUC：0.997419
# 第7次执行：Gmean：0.863422，mAUC：0.989033
# 第8次执行：Gmean：0.980603，mAUC：0.997818
# 第9次执行：Gmean：0.988371，mAUC：0.997933
# 第10次执行：Gmean：0.984525，mAUC：0.998041
# 第11次执行：Gmean：0.980649，mAUC：0.994339
# 第12次执行：Gmean：0.943034，mAUC：0.994878
# 第13次执行：Gmean：0.973506，mAUC：0.998969
# 第14次执行：Gmean：0.923523，mAUC：0.995132
# 第15次执行：Gmean：0.722514，mAUC：0.981933
# 第16次执行：Gmean：0.913952，mAUC：0.992875
# 第17次执行：Gmean：0.927355，mAUC：0.982972
# 第18次执行：Gmean：0.992187，mAUC：0.997523
# 第19次执行：Gmean：0.988371，mAUC：0.999355
# 第20次执行：Gmean：0.873503，mAUC：0.980874
# 第21次执行：Gmean：0.984433，mAUC：0.992579
# 第22次执行：Gmean：0.962142，mAUC：0.995432
# 第23次执行：Gmean：0.996154，mAUC：0.999745
# 第24次执行：Gmean：0.962142，mAUC：0.996298
# 第25次执行：Gmean：0.969718，mAUC：0.999614
# Excel 文件已保存至: C:/Users/zsc/Desktop/NOS/Dermatology/Dermatology.xlsx
# 集成分类结果（平均值）：[0.47548965 0.96011778]
# 集成分类结果（标准差）：[0.45569301 0.03494378]
# 第1次执行：Gmean：0.88519，mAUC：0.982419
# 第2次执行：Gmean：0.893405，mAUC：0.984768
# 第3次执行：Gmean：0.869283，mAUC：0.977468
# 第4次执行：Gmean：0.85304，mAUC：0.97599
# 第5次执行：Gmean：0.861414，mAUC：0.9777
# 第6次执行：Gmean：0.881947，mAUC：0.975761
# 第7次执行：Gmean：0.850367，mAUC：0.978501
# 第8次执行：Gmean：0.834478，mAUC：0.973101
# 第9次执行：Gmean：0.800428，mAUC：0.977168
# 第10次执行：Gmean：0.881947，mAUC：0.979182
# 第11次执行：Gmean：0.893405，mAUC：0.976961
# 第12次执行：Gmean：0.925323，mAUC：0.985415
# 第13次执行：Gmean：0.838714，mAUC：0.982088
# 第14次执行：Gmean：0.846938，mAUC：0.974603
# 第15次执行：Gmean：0.869861，mAUC：0.982298
# 第16次执行：Gmean：0.87078，mAUC：0.985026
# 第17次执行：Gmean：0.869861，mAUC：0.979092
# 第18次执行：Gmean：0.869861，mAUC：0.979946
# 第19次执行：Gmean：0.869861，mAUC：0.977543
# 第20次执行：Gmean：0.886414，mAUC：0.973807
# 第21次执行：Gmean：0.861414，mAUC：0.978699
# 第22次执行：Gmean：0.809432，mAUC：0.979691
# 第23次执行：Gmean：0.802821，mAUC：0.981018
# 第24次执行：Gmean：0.838714，mAUC：0.982098
# 第25次执行：Gmean：0.861615，mAUC：0.977779
# 第26次执行：Gmean：0.834776，mAUC：0.977958
# 第27次执行：Gmean：0.844959，mAUC：0.977659
# 第28次执行：Gmean：0.858706，mAUC：0.981576
# 第29次执行：Gmean：0.881947，mAUC：0.976651
# 第30次执行：Gmean：0.78017，mAUC：0.959329
# 第31次执行：Gmean：0.823171，mAUC：0.976267
# 第32次执行：Gmean：0.756052，mAUC：0.966755
# 第33次执行：Gmean：0.827957，mAUC：0.976121
# 第34次执行：Gmean：0.857064，mAUC：0.976048
# 第35次执行：Gmean：0.854674，mAUC：0.977245
# 第36次执行：Gmean：0.858706，mAUC：0.980357
# 第37次执行：Gmean：0.834478，mAUC：0.984711
# 第38次执行：Gmean：0.723053，mAUC：0.979091
# 第39次执行：Gmean：0.682625，mAUC：0.9763
# 第40次执行：Gmean：0.875315，mAUC：0.979692
# Excel 文件已保存至: C:/Users/zsc/Desktop/NOS/Ecoli/Ecoli.xlsx
# 集成分类结果（平均值）：[0.84550415 0.97809705]
# 集成分类结果（标准差）：[0.04590205 0.00464536]
# 第1次执行：Gmean：0.95379，mAUC：0.997664
# 第2次执行：Gmean：0.885488，mAUC：0.989244
# 第3次执行：Gmean：0.881884，mAUC：0.989337
# 第4次执行：Gmean：0.968583，mAUC：0.996755
# Excel 文件已保存至: C:/Users/zsc/Desktop/NOS/German/German.xlsx
# 集成分类结果（平均值）：[0.63252668 0.70592127]
# 集成分类结果（标准差）：[0.03075259 0.02077833]
# 第1次执行：Gmean：0.967189，mAUC：1.0
# 第2次执行：Gmean：1.0，mAUC：1.0
# 第3次执行：Gmean：1.0，mAUC：1.0
# 第4次执行：Gmean：0.983868，mAUC：1.0
# 第5次执行：Gmean：1.0，mAUC：1.0
# 第6次执行：Gmean：1.0，mAUC：1.0
# 第7次执行：Gmean：1.0，mAUC：1.0
# 第8次执行：Gmean：0.983868，mAUC：1.0
# 第9次执行：Gmean：0.983868，mAUC：1.0
# 第10次执行：Gmean：0.983868，mAUC：1.0
# 第11次执行：Gmean：1.0，mAUC：1.0
# 第12次执行：Gmean：0.983868，mAUC：1.0
# 第13次执行：Gmean：1.0，mAUC：1.0
# 第14次执行：Gmean：1.0，mAUC：1.0
# 第15次执行：Gmean：1.0，mAUC：1.0
# 第16次执行：Gmean：1.0，mAUC：1.0
# 第17次执行：Gmean：1.0，mAUC：1.0
# 第18次执行：Gmean：1.0，mAUC：1.0
# 第19次执行：Gmean：1.0，mAUC：1.0
# 第20次执行：Gmean：1.0，mAUC：1.0
# 第21次执行：Gmean：0.983868，mAUC：1.0
# 第22次执行：Gmean：0.983868，mAUC：1.0
# 第23次执行：Gmean：1.0，mAUC：1.0
# 第24次执行：Gmean：1.0，mAUC：1.0
# 第25次执行：Gmean：0.967189，mAUC：1.0
# 第26次执行：Gmean：1.0，mAUC：1.0
# 第27次执行：Gmean：1.0，mAUC：1.0
# 第28次执行：Gmean：1.0，mAUC：1.0
# 第29次执行：Gmean：0.967189，mAUC：0.999471
# 第30次执行：Gmean：0.983868，mAUC：1.0
# 第31次执行：Gmean：1.0，mAUC：1.0
# 第32次执行：Gmean：1.0，mAUC：1.0
# 第33次执行：Gmean：1.0，mAUC：1.0
# 第34次执行：Gmean：0.983868，mAUC：1.0
# 第35次执行：Gmean：1.0，mAUC：1.0
# 第36次执行：Gmean：1.0，mAUC：1.0
# 第37次执行：Gmean：1.0，mAUC：1.0
# 第38次执行：Gmean：1.0，mAUC：1.0
# 第39次执行：Gmean：1.0，mAUC：1.0
# 第40次执行：Gmean：0.983868，mAUC：1.0
# Excel 文件已保存至: C:/Users/zsc/Desktop/NOS/Wine/Wine.xlsx
# 集成分类结果（平均值）：[0.99350618 0.99998677]
# 集成分类结果（标准差）：[1.01800158e-02 8.25900985e-05]
# 第1次执行：Gmean：0.961403，mAUC：0.997137
# 第2次执行：Gmean：0.948836，mAUC：0.99678
# 第3次执行：Gmean：0.96713，mAUC：0.997727
# 第4次执行：Gmean：0.988795，mAUC：0.99991
# 第5次执行：Gmean：0.922618，mAUC：0.994971
# 第6次执行：Gmean：0.962012，mAUC：0.998039
# 第7次执行：Gmean：0.977293，mAUC：0.99896
# 第8次执行：Gmean：0.981142，mAUC：0.999701
# Excel 文件已保存至: C:/Users/zsc/Desktop/NOS/Satellite/Satellite.xlsx
# 集成分类结果（平均值）：[0.84256417 0.97986267]
# 集成分类结果（标准差）：[0.02050009 0.0020019 ]
# 第1次执行：Gmean：0.781267，mAUC：0.940007
# 第2次执行：Gmean：0.742344，mAUC：0.933786
# 第3次执行：Gmean：0.645956，mAUC：0.95353
# 第4次执行：Gmean：0.695965，mAUC：0.942812
# 第5次执行：Gmean：0.727877，mAUC：0.932843
# 第6次执行：Gmean：0.743079，mAUC：0.96711
# 第7次执行：Gmean：0.799582，mAUC：0.955739
# 第8次执行：Gmean：0.82557，mAUC：0.965428
# 第9次执行：Gmean：0.774248，mAUC：0.954857
# 第10次执行：Gmean：0.820776，mAUC：0.970004
# 第11次执行：Gmean：0.754234，mAUC：0.926584
# 第12次执行：Gmean：0.739087，mAUC：0.926877
# 第13次执行：Gmean：0.613063，mAUC：0.950688
# 第14次执行：Gmean：0.701852，mAUC：0.938966
# 第15次执行：Gmean：0.689026，mAUC：0.943676
# 第16次执行：Gmean：0.64733，mAUC：0.955121
# 第17次执行：Gmean：0.771196，mAUC：0.936051
# 第18次执行：Gmean：0.713504，mAUC：0.929119
# 第19次执行：Gmean：0.773136，mAUC：0.946079
# 第20次执行：Gmean：0.62414，mAUC：0.935955
# 第21次执行：Gmean：0.665455，mAUC：0.938908
# 第22次执行：Gmean：0.0，mAUC：0.936436
# 第23次执行：Gmean：0.775605，mAUC：0.975132
# 第24次执行：Gmean：0.808098，mAUC：0.959699
# 第25次执行：Gmean：0.69054，mAUC：0.926805
# 第26次执行：Gmean：0.77678，mAUC：0.966867
# 第27次执行：Gmean：0.719743，mAUC：0.942841
# 第28次执行：Gmean：0.787927，mAUC：0.965752
# 第29次执行：Gmean：0.779516，mAUC：0.929028
# 第30次执行：Gmean：0.776567，mAUC：0.945537
# 第31次执行：Gmean：0.78854，mAUC：0.939165
# 第32次执行：Gmean：0.795421，mAUC：0.966808
# 第33次执行：Gmean：0.658528，mAUC：0.947091
# 第34次执行：Gmean：0.0，mAUC：0.943904
# 第35次执行：Gmean：0.791448，mAUC：0.943919
# 第36次执行：Gmean：0.778629，mAUC：0.918939
# 第37次执行：Gmean：0.795421，mAUC：0.966808
# 第38次执行：Gmean：0.0，mAUC：0.961588
# 第39次执行：Gmean：0.718557，mAUC：0.952886
# 第40次执行：Gmean：0.754656，mAUC：0.955585
# Excel 文件已保存至: C:/Users/zsc/Desktop/NOS/Page_Blocks/Page_Blocks.xlsx
# 集成分类结果（平均值）：[0.68611658 0.94722325]
# 集成分类结果（标准差）：[0.20272231 0.01417116]
# 第1次执行：Gmean：1.0，mAUC：1.0
# 第2次执行：Gmean：1.0，mAUC：1.0
# 第3次执行：Gmean：1.0，mAUC：1.0
# 第4次执行：Gmean：1.0，mAUC：1.0
# 第5次执行：Gmean：1.0，mAUC：1.0
# 第6次执行：Gmean：1.0，mAUC：1.0
# 第7次执行：Gmean：1.0，mAUC：1.0
# 第8次执行：Gmean：1.0，mAUC：1.0
# 第9次执行：Gmean：1.0，mAUC：1.0
# 第10次执行：Gmean：1.0，mAUC：1.0
# 第11次执行：Gmean：1.0，mAUC：1.0
# 第12次执行：Gmean：1.0，mAUC：1.0
# 第13次执行：Gmean：1.0，mAUC：1.0
# 第14次执行：Gmean：1.0，mAUC：1.0
# 第15次执行：Gmean：1.0，mAUC：1.0
# 第16次执行：Gmean：1.0，mAUC：1.0
# 第17次执行：Gmean：1.0，mAUC：1.0
# 第18次执行：Gmean：1.0，mAUC：1.0
# 第19次执行：Gmean：1.0，mAUC：1.0
# 第20次执行：Gmean：1.0，mAUC：1.0
# 第21次执行：Gmean：1.0，mAUC：1.0
# 第22次执行：Gmean：1.0，mAUC：1.0
# 第23次执行：Gmean：1.0，mAUC：1.0
# 第24次执行：Gmean：1.0，mAUC：1.0
# 第25次执行：Gmean：1.0，mAUC：1.0
# 第26次执行：Gmean：1.0，mAUC：1.0
# 第27次执行：Gmean：1.0，mAUC：1.0
# 第28次执行：Gmean：1.0，mAUC：1.0
# 第29次执行：Gmean：1.0，mAUC：1.0
# 第30次执行：Gmean：1.0，mAUC：1.0
# 第31次执行：Gmean：1.0，mAUC：1.0
# 第32次执行：Gmean：1.0，mAUC：1.0
# 第33次执行：Gmean：1.0，mAUC：1.0
# 第34次执行：Gmean：1.0，mAUC：1.0
# 第35次执行：Gmean：1.0，mAUC：1.0
# 第36次执行：Gmean：1.0，mAUC：1.0
# 第37次执行：Gmean：1.0，mAUC：1.0
# 第38次执行：Gmean：1.0，mAUC：1.0
# 第39次执行：Gmean：1.0，mAUC：1.0
# 第40次执行：Gmean：1.0，mAUC：1.0
# Excel 文件已保存至: C:/Users/zsc/Desktop/NOS/Shuttle/Shuttle.xlsx
# 集成分类结果（平均值）：[1. 1.]
# 集成分类结果（标准差）：[0. 0.]
# 第1次执行：Gmean：0.503623，mAUC：0.727153
# 第2次执行：Gmean：0.482776，mAUC：0.70656
# 第3次执行：Gmean：0.444943，mAUC：0.700047
# 第4次执行：Gmean：0.521176，mAUC：0.731931
# 第5次执行：Gmean：0.487414，mAUC：0.741457
# 第6次执行：Gmean：0.469849，mAUC：0.70293
# 第7次执行：Gmean：0.342911，mAUC：0.696962
# 第8次执行：Gmean：0.543408，mAUC：0.736024
# 第9次执行：Gmean：0.483206，mAUC：0.718545
# 第10次执行：Gmean：0.520594，mAUC：0.723536
# 第11次执行：Gmean：0.506446，mAUC：0.722201
# 第12次执行：Gmean：0.503832，mAUC：0.71071
# 第13次执行：Gmean：0.435268，mAUC：0.706459
# 第14次执行：Gmean：0.496198，mAUC：0.715487
# 第15次执行：Gmean：0.453882，mAUC：0.704997
# 第16次执行：Gmean：0.483264，mAUC：0.709163
# 第17次执行：Gmean：0.510995，mAUC：0.7117
# 第18次执行：Gmean：0.532473，mAUC：0.708953
# 第19次执行：Gmean：0.459327，mAUC：0.710058
# 第20次执行：Gmean：0.515214，mAUC：0.709104
# 第21次执行：Gmean：0.475577，mAUC：0.716924
# 第22次执行：Gmean：0.439151，mAUC：0.702977
# 第23次执行：Gmean：0.513838，mAUC：0.711522
# 第24次执行：Gmean：0.492807，mAUC：0.711783
# 第25次执行：Gmean：0.458499，mAUC：0.720021
# 第26次执行：Gmean：0.325625，mAUC：0.702154
# 第27次执行：Gmean：0.482711，mAUC：0.716831
# 第28次执行：Gmean：0.480331，mAUC：0.702248
# 第29次执行：Gmean：0.513326，mAUC：0.718749
# 第30次执行：Gmean：0.448492，mAUC：0.735678
# 第31次执行：Gmean：0.411817，mAUC：0.701288
# 第32次执行：Gmean：0.50883，mAUC：0.707145
# 第33次执行：Gmean：0.419393，mAUC：0.699538
# 第34次执行：Gmean：0.439755，mAUC：0.7074
# 第35次执行：Gmean：0.277218，mAUC：0.699295
# 第36次执行：Gmean：0.518702，mAUC：0.717376
# 第37次执行：Gmean：0.500211，mAUC：0.708438
# 第38次执行：Gmean：0.456148，mAUC：0.725844
# 第39次执行：Gmean：0.481914，mAUC：0.697389
# 第40次执行：Gmean：0.519088，mAUC：0.720635
# Excel 文件已保存至: C:/Users/zsc/Desktop/NOS/Contraceptive/Contraceptive.xlsx
# 集成分类结果（平均值）：[0.4715058 0.7129303]
# 集成分类结果（标准差）：[0.05480455 0.01107976]
# 第1次执行：Gmean：0.760927，mAUC：0.90607
# 第2次执行：Gmean：0.783251，mAUC：0.904233
# 第3次执行：Gmean：0.853726，mAUC：0.939139
# 第4次执行：Gmean：0.708537，mAUC：0.914824
# 第5次执行：Gmean：0.83852，mAUC：0.935795
# 第6次执行：Gmean：0.867502，mAUC：0.92825
# 第7次执行：Gmean：0.62483，mAUC：0.919019
# 第8次执行：Gmean：0.810245，mAUC：0.935544
# 第9次执行：Gmean：0.832175，mAUC：0.936848
# 第10次执行：Gmean：0.783251，mAUC：0.9047
# 第11次执行：Gmean：0.614051，mAUC：0.918778
# 第12次执行：Gmean：0.764942，mAUC：0.90994
# 第13次执行：Gmean：0.805992，mAUC：0.924929
# 第14次执行：Gmean：0.579718，mAUC：0.905612
# 第15次执行：Gmean：0.83476，mAUC：0.945271
# 第16次执行：Gmean：0.798325，mAUC：0.904866
# 第17次执行：Gmean：0.662425，mAUC：0.918556
# 第18次执行：Gmean：0.76261，mAUC：0.924117
# 第19次执行：Gmean：0.845604，mAUC：0.937977
# 第20次执行：Gmean：0.602457，mAUC：0.841241
# 第21次执行：Gmean：0.599414，mAUC：0.860667
# 第22次执行：Gmean：0.797415，mAUC：0.933385
# 第23次执行：Gmean：0.816463，mAUC：0.940363
# 第24次执行：Gmean：0.708537，mAUC：0.914824
# 第25次执行：Gmean：0.777286，mAUC：0.929734
# 第26次执行：Gmean：0.855144，mAUC：0.936177
# 第27次执行：Gmean：0.798325，mAUC：0.944742
# 第28次执行：Gmean：0.750499，mAUC：0.930858
# 第29次执行：Gmean：0.797415，mAUC：0.912755
# 第30次执行：Gmean：0.589895，mAUC：0.872567
# 第31次执行：Gmean：0.845604，mAUC：0.917989
# 第32次执行：Gmean：0.816463，mAUC：0.905707
# 第33次执行：Gmean：0.76261，mAUC：0.922265
# 第34次执行：Gmean：0.816463，mAUC：0.934599
# 第35次执行：Gmean：0.595409，mAUC：0.885799
# 第36次执行：Gmean：0.798325，mAUC：0.894392
# 第37次执行：Gmean：0.798325，mAUC：0.936036
# 第38次执行：Gmean：0.853726，mAUC：0.94272
# 第39次执行：Gmean：0.798325，mAUC：0.906609
# 第40次执行：Gmean：0.589895，mAUC：0.872567
# Excel 文件已保存至: C:/Users/zsc/Desktop/NOS/Automobile/Automobile.xlsx
# 集成分类结果（平均值）：[0.75748465 0.9162616 ]
# 集成分类结果（标准差）：[0.08914351 0.02349796]
# 第1次执行：Gmean：0.961071，mAUC：0.978836
# 第2次执行：Gmean：0.952381，mAUC：0.995465
# 第3次执行：Gmean：0.933139，mAUC：0.98715
# 第4次执行：Gmean：0.929893，mAUC：0.965231
# 第5次执行：Gmean：0.922958，mAUC：0.995465
# 第6次执行：Gmean：0.816497，mAUC：0.98715
# 第7次执行：Gmean：0.793492，mAUC：0.966742
# 第8次执行：Gmean：0.913492，mAUC：0.993953
# 第9次执行：Gmean：0.923368，mAUC：0.97808
# 第10次执行：Gmean：0.952381，mAUC：0.984883
# 第11次执行：Gmean：0.913492，mAUC：0.993953
# 第12次执行：Gmean：0.96225，mAUC：1.0
# 第13次执行：Gmean：0.950792，mAUC：0.96712
# 第14次执行：Gmean：0.881917，mAUC：0.944822
# 第15次执行：Gmean：0.979379，mAUC：0.997732
# 第16次执行：Gmean：1.0，mAUC：1.0
# 第17次执行：Gmean：0.7698，mAUC：0.993575
# 第18次执行：Gmean：0.96225，mAUC：0.993197
# 第19次执行：Gmean：0.932329，mAUC：0.985261
# 第20次执行：Gmean：0.96225，mAUC：0.996221
# 第21次执行：Gmean：0.923368，mAUC：0.99093
# 第22次执行：Gmean：0.971242，mAUC：0.989418
# 第23次执行：Gmean：0.981307，mAUC：0.999244
# 第24次执行：Gmean：0.933139，mAUC：0.978836
# 第25次执行：Gmean：0.933139，mAUC：0.997732
# 第26次执行：Gmean：0.96225，mAUC：0.995465
# 第27次执行：Gmean：0.979379，mAUC：0.979592
# 第28次执行：Gmean：0.971242，mAUC：0.98715
# 第29次执行：Gmean：0.981307，mAUC：0.998488
# 第30次执行：Gmean：0.913492，mAUC：0.967876
# 第31次执行：Gmean：0.933139，mAUC：0.979592
# 第32次执行：Gmean：0.863731，mAUC：0.974679
# 第33次执行：Gmean：0.96225，mAUC：0.994709
# 第34次执行：Gmean：0.96225，mAUC：0.996977
# 第35次执行：Gmean：0.981307，mAUC：0.999244
# 第36次执行：Gmean：0.830266，mAUC：0.99093
# 第37次执行：Gmean：0.989743，mAUC：1.0
# 第38次执行：Gmean：0.923368，mAUC：0.976568
# 第39次执行：Gmean：0.981307，mAUC：0.999244
# 第40次执行：Gmean：0.923368，mAUC：0.976568
# Excel 文件已保存至: C:/Users/zsc/Desktop/NOS/Ovarian/Ovarian.xlsx
# 集成分类结果（平均值）：[0.93284313 0.98695195]
# 集成分类结果（标准差）：[0.05256271 0.01236615]
# *****************算法执行结束！******************
# 数据已成功写入到 C:/Users/zsc/Desktop/NOS/avg_results.xlsx
