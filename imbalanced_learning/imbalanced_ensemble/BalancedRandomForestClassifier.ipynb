# %%
import os
from openpyxl.workbook import Workbook
from sklearn import clone
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imbens.ensemble import BalancedRandomForestClassifier
from imbens.ensemble import EasyEnsembleClassifier
from imbens.ensemble import KmeansSMOTEBoostClassifier
from instance_selection.operator.metrics import calculate_gmean_mauc
from instance_selection.parameter.parameter import *  # 导入参数的设定
import scipy.io as sio  # 从.mat文件中读取数据集


def data_process(dataset=None):
    mat_data = sio.loadmat(IMBALANCED_DATASET_PATH + dataset.DATASETNAME)  # 加载、划分数据集
    x = mat_data['X']
    y = mat_data['Y'][:, 0]  # mat_data['Y']得到的形状为[n,1]，通过[:,0]，得到形状[n,]
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y,
                                                        random_state=RANDOM_SEED)  # 划分数据集
    scaler = StandardScaler()  # 数据的标准化
    x_train = scaler.fit_transform(x_train)
    x_test = scaler.transform(x_test)
    model = MLPClassifier(hidden_layer_sizes=(dataset.HIDDEN_SIZE,), max_iter=dataset.MAX_ITER,
                          random_state=RANDOM_SEED, learning_rate_init=dataset.LEARNING_RATE)
    return x_train, x_test, y_train, y_test, clone(model)


def save_to_excel(data, save_path, filename='avg_results'):
    """
    将列表数据逐行写入Excel文件
    参数:
        data: 二维列表，每个子列表代表一行数据
        filename: 输出的Excel文件名(默认为output.xlsx)
    """
    # 创建一个新的工作簿
    wb = Workbook()
    # 获取活动的工作表
    ws = wb.active
    # 逐行写入数据
    for row in data:
        avg = row[1].tolist()
        avg.insert(0, row[0])
        std = row[2].tolist()
        std.insert(0, row[0])
        ws.append(avg)
        ws.append(std)
    # 创建 Excel 文件完整路径
    file_path = os.path.join(save_path, filename + ".xlsx")
    # 保存Excel文件
    wb.save(file_path)
    print(f"数据已成功写入到 {file_path}")

# %%
from imbens.ensemble import BalanceCascadeClassifier, CompatibleBaggingClassifier
from utils.excel_utils import save_to_excel_2
import numpy as np

DATASETS = [Balance_Scale, Dermatology, Ecoli, Car, Pen_Digits, WallRobot, German, Wine, Nursery, Penbased, USPS,
            Satellite, Page_Blocks, Shuttle, Contraceptive, Automobile, Ovarian]  # 数据集名称（包含对应的参数配置）

if __name__ == "__main__":
    save_path = 'C:/Users/zsc/Desktop/BalancedRandomForest2/'
    columns = ['Gmean', 'MAUC']
    datasets_ensembles_results = [[] for _ in range(len(DATASETS))]
    print("*****************算法开始执行：******************")
    for j, dataset in enumerate(DATASETS):
        x_train, x_test, y_train, y_test, model = data_process(dataset=dataset)
        num_run = 40  # 运行次数
        ensembles_results = [[] for _ in range(num_run)]

        for i in range(num_run):
            # clf = EasyEnsembleClassifier(estimator=clone(model), random_state=42 + np.random.randint(0, 1000),
            #                              n_estimators=30) # EasyEnsembleClassifier
            # clf = BalancedRandomForestClassifier(n_estimators=30, random_state=42 + np.random.randint(0, 1000))
            # clf = KmeansSMOTEBoostClassifier(random_state=42 + np.random.randint(0, 1000),
            #                                 n_estimators=30)
            # clf = BalanceCascadeClassifier(estimator=clone(model), random_state=42 + np.random.randint(0, 1000),
            #                               n_estimators=30) 
            clf = BalancedRandomForestClassifier(random_state=42 + np.random.randint(0, 1000),
                                          n_estimators=30) 
            clf.fit(x_train, y_train)
            y_pred_prob = clf.predict_proba(x_test)  # 默认预测结果是软标签
            gmean, mauc, recall_per_class = calculate_gmean_mauc(y_pred_prob, y_test)

            ensembles_results[i] = [gmean, mauc]
            print(f"第{i + 1}次执行：Gmean：{gmean}，mAUC：{mauc}")
        save_to_excel_2(save_path + dataset.DATASETNAME.split('.')[0] + '/', dataset.DATASETNAME.split('.')[0], columns,
                        ensembles_results)
        ensembles_result_mean = np.mean(ensembles_results, axis=0)
        # 计算ensembles_resultsz中每一列的标准差
        ensembles_result_std = np.std(ensembles_results, axis=0)
        print(f'集成分类结果（平均值）：{ensembles_result_mean}')
        print(f'集成分类结果（标准差）：{ensembles_result_std}')
        datasets_ensembles_results[j] = [dataset.DATASETNAME.split('.')[0], ensembles_result_mean, ensembles_result_std]
    print("*****************算法执行结束！******************")
    # 写入到Excel     
    save_to_excel(datasets_ensembles_results, save_path)
# Out:
# *****************算法开始执行：******************
# 第1次执行：Gmean：0.674223，mAUC：0.812991
# 第2次执行：Gmean：0.620281，mAUC：0.800722
# 第3次执行：Gmean：0.613539，mAUC：0.790819
# 第4次执行：Gmean：0.588686，mAUC：0.804471
# 第5次执行：Gmean：0.664156，mAUC：0.792832
# 第6次执行：Gmean：0.602876，mAUC：0.808099
# 第7次执行：Gmean：0.62156，mAUC：0.80768
# 第8次执行：Gmean：0.566318，mAUC：0.767527
# 第9次执行：Gmean：0.572537，mAUC：0.801266
# 第10次执行：Gmean：0.595866，mAUC：0.796104
# 第11次执行：Gmean：0.595866，mAUC：0.805939
# 第12次执行：Gmean：0.698695，mAUC：0.799666
# 第13次执行：Gmean：0.665372，mAUC：0.81663
# 第14次执行：Gmean：0.584404，mAUC：0.795788
# 第15次执行：Gmean：0.592365，mAUC：0.7874
# 第16次执行：Gmean：0.60011，mAUC：0.78975
# 第17次执行：Gmean：0.666738，mAUC：0.790387
# 第18次执行：Gmean：0.638696，mAUC：0.784889
# 第19次执行：Gmean：0.619725，mAUC：0.796757
# 第20次执行：Gmean：0.597617，mAUC：0.79792
# 第21次执行：Gmean：0.665238，mAUC：0.791685
# 第22次执行：Gmean：0.550037，mAUC：0.770538
# 第23次执行：Gmean：0.622175，mAUC：0.789014
# 第24次执行：Gmean：0.619864，mAUC：0.78169
# 第25次执行：Gmean：0.601632，mAUC：0.774797
# 第26次执行：Gmean：0.630936，mAUC：0.787615
# 第27次执行：Gmean：0.661852，mAUC：0.836405
# 第28次执行：Gmean：0.534483，mAUC：0.778129
# 第29次执行：Gmean：0.577362，mAUC：0.794646
# 第30次执行：Gmean：0.489657，mAUC：0.785587
# 第31次执行：Gmean：0.562439，mAUC：0.774482
# 第32次执行：Gmean：0.65047，mAUC：0.815865
# 第33次执行：Gmean：0.697964，mAUC：0.789125
# 第34次执行：Gmean：0.623667，mAUC：0.794198
# 第35次执行：Gmean：0.632773，mAUC：0.783861
# 第36次执行：Gmean：0.642259，mAUC：0.801919
# 第37次执行：Gmean：0.594642，mAUC：0.788922
# 第38次执行：Gmean：0.649851，mAUC：0.796386
# 第39次执行：Gmean：0.633995，mAUC：0.805451
# 第40次执行：Gmean：0.596751，mAUC：0.79707
# Excel 文件已保存至: C:/Users/zsc/Desktop/BalancedRandomForest2/
# Excel 文件已保存至: C:/Users/zsc/Desktop/BalancedRandomForest2/Satellite/Satellite.xlsx
# 集成分类结果（平均值）：[0.88063005 0.9857208 ]
# 集成分类结果（标准差）：[0.00379369 0.00086009]
# 第1次执行：Gmean：0.935007，mAUC：0.980273
# 第2次执行：Gmean：0.945794，mAUC：0.985281
# 第3次执行：Gmean：0.924763，mAUC：0.984432
# 第4次执行：Gmean：0.923655，mAUC：0.981824
# 第5次执行：Gmean：0.928364，mAUC：0.98416
# 第6次执行：Gmean：0.924763，mAUC：0.982023
# 第7次执行：Gmean：0.926077，mAUC：0.982083
# 第8次执行：Gmean：0.92532，mAUC：0.982072
# 第9次执行：Gmean：0.942882，mAUC：0.985771
# 第10次执行：Gmean：0.929533，mAUC：0.984406
# 第11次执行：Gmean：0.939532，mAUC：0.980985
# 第12次执行：Gmean：0.927983，mAUC：0.981089
# 第13次执行：Gmean：0.865914，mAUC：0.97853
# 第14次执行：Gmean：0.927296，mAUC：0.985652
# 第15次执行：Gmean：0.920333，mAUC：0.987399
# 第16次执行：Gmean：0.928208，mAUC：0.983833
# 第17次执行：Gmean：0.929681，mAUC：0.98307
# 第18次执行：Gmean：0.922765，mAUC：0.981039
# 第19次执行：Gmean：0.920778，mAUC：0.986022
# 第20次执行：Gmean：0.931519，mAUC：0.983881
# 第21次执行：Gmean：0.920559，mAUC：0.981468
# 第22次执行：Gmean：0.920641，mAUC：0.981819
# 第23次执行：Gmean：0.926169，mAUC：0.981371
# 第24次执行：Gmean：0.922903，mAUC：0.989359
# 第25次执行：Gmean：0.897049，mAUC：0.979822
# 第26次执行：Gmean：0.928976，mAUC：0.984175
# 第27次执行：Gmean：0.928098，mAUC：0.980291
# 第28次执行：Gmean：0.904306，mAUC：0.979606
# 第29次执行：Gmean：0.920093，mAUC：0.982903
# 第30次执行：Gmean：0.934991，mAUC：0.978607
# 第31次执行：Gmean：0.932999，mAUC：0.982485
# 第32次执行：Gmean：0.935174，mAUC：0.985256
# 第33次执行：Gmean：0.931357，mAUC：0.983394
# 第34次执行：Gmean：0.932495，mAUC：0.98265
# 第35次执行：Gmean：0.935271，mAUC：0.985283
# 第36次执行：Gmean：0.926879，mAUC：0.983444
# 第37次执行：Gmean：0.918165，mAUC：0.983629
# 第38次执行：Gmean：0.936133，mAUC：0.987798
# 第39次执行：Gmean：0.924146，mAUC：0.983677
# 第40次执行：Gmean：0.924239，mAUC：0.98245
# Excel 文件已保存至: C:/Users/zsc/Desktop/BalancedRandomForest2/Page_Blocks/Page_Blocks.xlsx
# 集成分类结果（平均值）：[0.92552025 0.9830828 ]
# 集成分类结果（标准差）：[0.01290416 0.00239627]
# 第1次执行：Gmean：1.0，mAUC：1.0
# 第2次执行：Gmean：1.0，mAUC：1.0
# 第3次执行：Gmean：1.0，mAUC：1.0
# 第4次执行：Gmean：1.0，mAUC：1.0
# 第5次执行：Gmean：1.0，mAUC：1.0
# 第6次执行：Gmean：1.0，mAUC：1.0
# 第7次执行：Gmean：1.0，mAUC：1.0
# 第8次执行：Gmean：1.0，mAUC：1.0
# 第9次执行：Gmean：1.0，mAUC：1.0
# 第10次执行：Gmean：1.0，mAUC：1.0
# 第11次执行：Gmean：1.0，mAUC：1.0
# 第12次执行：Gmean：1.0，mAUC：1.0
# 第13次执行：Gmean：1.0，mAUC：1.0
# 第14次执行：Gmean：1.0，mAUC：1.0
# 第15次执行：Gmean：1.0，mAUC：1.0
# 第16次执行：Gmean：1.0，mAUC：1.0
# 第17次执行：Gmean：1.0，mAUC：1.0
# 第18次执行：Gmean：1.0，mAUC：1.0
# 第19次执行：Gmean：1.0，mAUC：1.0
# 第20次执行：Gmean：1.0，mAUC：1.0
# 第21次执行：Gmean：1.0，mAUC：1.0
# 第22次执行：Gmean：1.0，mAUC：1.0
# 第23次执行：Gmean：1.0，mAUC：1.0
# 第24次执行：Gmean：1.0，mAUC：1.0
# 第25次执行：Gmean：1.0，mAUC：1.0
# 第26次执行：Gmean：1.0，mAUC：1.0
# 第27次执行：Gmean：1.0，mAUC：1.0
# 第28次执行：Gmean：1.0，mAUC：1.0
# 第29次执行：Gmean：1.0，mAUC：1.0
# 第30次执行：Gmean：1.0，mAUC：1.0
# 第31次执行：Gmean：1.0，mAUC：1.0
# 第32次执行：Gmean：1.0，mAUC：1.0
# 第33次执行：Gmean：1.0，mAUC：1.0
# 第34次执行：Gmean：1.0，mAUC：1.0
# 第35次执行：Gmean：1.0，mAUC：1.0
# 第36次执行：Gmean：1.0，mAUC：1.0
# 第37次执行：Gmean：1.0，mAUC：1.0
# 第38次执行：Gmean：1.0，mAUC：1.0
# 第39次执行：Gmean：1.0，mAUC：1.0
# 第40次执行：Gmean：1.0，mAUC：1.0
# Excel 文件已保存至: C:/Users/zsc/Desktop/BalancedRandomForest2/Shuttle/Shuttle.xlsx
# 集成分类结果（平均值）：[1. 1.]
# 集成分类结果（标准差）：[0. 0.]
# 第1次执行：Gmean：0.5531，mAUC：0.717502
# 第2次执行：Gmean：0.539162，mAUC：0.715795
# 第3次执行：Gmean：0.513273，mAUC：0.709944
# 第4次执行：Gmean：0.51656，mAUC：0.719895
# 第5次执行：Gmean：0.529889，mAUC：0.729535
# 第6次执行：Gmean：0.535844，mAUC：0.720662
# 第7次执行：Gmean：0.494315，mAUC：0.716258
# 第8次执行：Gmean：0.498681，mAUC：0.725364
# 第9次执行：Gmean：0.539162，mAUC：0.715795
# 第10次执行：Gmean：0.531858，mAUC：0.717579
# 第11次执行：Gmean：0.556346，mAUC：0.716383
# 第12次执行：Gmean：0.51419，mAUC：0.712834
# 第13次执行：Gmean：0.542122，mAUC：0.717031
# 第14次执行：Gmean：0.510013，mAUC：0.720549
# 第15次执行：Gmean：0.508577，mAUC：0.713338
# 第16次执行：Gmean：0.53548，mAUC：0.71688
# 第17次执行：Gmean：0.505831，mAUC：0.711308
# 第18次执行：Gmean：0.52402，mAUC：0.726112
# 第19次执行：Gmean：0.526756，mAUC：0.705183
# 第20次执行：Gmean：0.509306，mAUC：0.711262
# 第21次执行：Gmean：0.523108，mAUC：0.714257
# 第22次执行：Gmean：0.532451，mAUC：0.728427
# 第23次执行：Gmean：0.51249，mAUC：0.71016
# 第24次执行：Gmean：0.502864，mAUC：0.708766
# 第25次执行：Gmean：0.505318，mAUC：0.710304
# 第26次执行：Gmean：0.525652，mAUC：0.716671
# 第27次执行：Gmean：0.534534，mAUC：0.711717
# 第28次执行：Gmean：0.502091，mAUC：0.705653
# 第29次执行：Gmean：0.522348，mAUC：0.709714
# 第30次执行：Gmean：0.528587，mAUC：0.720963
# 第31次执行：Gmean：0.510873，mAUC：0.70921
# 第32次执行：Gmean：0.492816，mAUC：0.708889
# 第33次执行：Gmean：0.529145，mAUC：0.717948
# 第34次执行：Gmean：0.531858，mAUC：0.717579
# 第35次执行：Gmean：0.519985，mAUC：0.730528
# 第36次执行：Gmean：0.522006，mAUC：0.718371
# 第37次执行：Gmean：0.52055，mAUC：0.711065
# 第38次执行：Gmean：0.501909，mAUC：0.72238
# 第39次执行：Gmean：0.522124，mAUC：0.717186
# 第40次执行：Gmean：0.520566，mAUC：0.722231
# Excel 文件已保存至: C:/Users/zsc/Desktop/BalancedRandomForest2/Contraceptive/Contraceptive.xlsx
# 集成分类结果（平均值）：[0.521144  0.7162807]
# 集成分类结果（标准差）：[0.01490447 0.00620686]
# 第1次执行：Gmean：0.750499，mAUC：0.928708
# 第2次执行：Gmean：0.692041，mAUC：0.935821
# 第3次执行：Gmean：0.799854，mAUC：0.93327
# 第4次执行：Gmean：0.73368，mAUC：0.929001
# 第5次执行：Gmean：0.816887，mAUC：0.955745
# 第6次执行：Gmean：0.831227，mAUC：0.943873
# 第7次执行：Gmean：0.763724，mAUC：0.926611
# 第8次执行：Gmean：0.598091，mAUC：0.901738
# 第9次执行：Gmean：0.744446，mAUC：0.911173
# 第10次执行：Gmean：0.685321，mAUC：0.905173
# 第11次执行：Gmean：0.792087，mAUC：0.93421
# 第12次执行：Gmean：0.677611，mAUC：0.905808
# 第13次执行：Gmean：0.821503，mAUC：0.924239
# 第14次执行：Gmean：0.770812，mAUC：0.930974
# 第15次执行：Gmean：0.760927，mAUC：0.934276
# 第16次执行：Gmean：0.73039，mAUC：0.907152
# 第17次执行：Gmean：0.701656，mAUC：0.906685
# 第18次执行：Gmean：0.744446，mAUC：0.947314
# 第19次执行：Gmean：0.655408，mAUC：0.925387
# 第20次执行：Gmean：0.805992，mAUC：0.937717
# 第21次执行：Gmean：0.781232，mAUC：0.924419
# 第22次执行：Gmean：0.716599，mAUC：0.923897
# 第23次执行：Gmean：0.710772，mAUC：0.943542
# 第24次执行：Gmean：0.801463，mAUC：0.945302
# 第25次执行：Gmean：0.747799，mAUC：0.921013
# 第26次执行：Gmean：0.787227，mAUC：0.945807
# 第27次执行：Gmean：0.757514，mAUC：0.944952
# 第28次执行：Gmean：0.787227，mAUC：0.95128
# 第29次执行：Gmean：0.69851，mAUC：0.926339
# 第30次执行：Gmean：0.847224，mAUC：0.943344
# 第31次执行：Gmean：0.685321，mAUC：0.909203
# 第32次执行：Gmean：0.741719，mAUC：0.917956
# 第33次执行：Gmean：0.750499，mAUC：0.939692
# 第34次执行：Gmean：0.757514，mAUC：0.92766
# 第35次执行：Gmean：0.71516，mAUC：0.920975
# 第36次执行：Gmean：0.692041，mAUC：0.904025
# 第37次执行：Gmean：0.781232，mAUC：0.933298
# 第38次执行：Gmean：0.73368，mAUC：0.91776
# 第39次执行：Gmean：0.763724，mAUC：0.92504
# 第40次执行：Gmean：0.671031，mAUC：0.919062
# Excel 文件已保存至: C:/Users/zsc/Desktop/BalancedRandomForest2/Automobile/Automobile.xlsx
# 集成分类结果（平均值）：[0.74510225 0.92773602]
# 集成分类结果（标准差）：[0.05219611 0.01414449]
# 第1次执行：Gmean：0.942809，mAUC：1.0
# 第2次执行：Gmean：0.96225，mAUC：0.99811
# 第3次执行：Gmean：0.981307，mAUC：1.0
# 第4次执行：Gmean：0.942809，mAUC：0.999244
# 第5次执行：Gmean：0.981307，mAUC：1.0
# 第6次执行：Gmean：0.96225，mAUC：0.996599
# 第7次执行：Gmean：0.96225，mAUC：0.998488
# 第8次执行：Gmean：0.96225，mAUC：0.987906
# 第9次执行：Gmean：0.96225，mAUC：0.992441
# 第10次执行：Gmean：0.952381，mAUC：0.996221
# 第11次执行：Gmean：0.96225，mAUC：0.996599
# 第12次执行：Gmean：0.96225，mAUC：0.99811
# 第13次执行：Gmean：0.96225，mAUC：0.99811
# 第14次执行：Gmean：0.96225，mAUC：1.0
# 第15次执行：Gmean：0.96225，mAUC：0.999244
# 第16次执行：Gmean：0.96225，mAUC：0.993197
# 第17次执行：Gmean：0.913492，mAUC：0.993197
# 第18次执行：Gmean：0.981307，mAUC：0.998488
# 第19次执行：Gmean：0.981307，mAUC：0.999244
# 第20次执行：Gmean：0.952381，mAUC：0.997354
# 第21次执行：Gmean：1.0，mAUC：1.0
# 第22次执行：Gmean：0.942809，mAUC：0.99811
# 第23次执行：Gmean：0.981307，mAUC：1.0
# 第24次执行：Gmean：0.952381，mAUC：0.997732
# 第25次执行：Gmean：0.96225，mAUC：0.999622
# 第26次执行：Gmean：0.96225，mAUC：0.98904
# 第27次执行：Gmean：0.96225，mAUC：0.996221
# 第28次执行：Gmean：0.952381，mAUC：0.996977
# 第29次执行：Gmean：0.981307，mAUC：0.999244
# 第30次执行：Gmean：0.96225，mAUC：0.996599
# 第31次执行：Gmean：0.981307，mAUC：0.999244
# 第32次执行：Gmean：0.981307，mAUC：0.998866
# 第33次执行：Gmean：0.971242，mAUC：0.999244
# 第34次执行：Gmean：0.942408，mAUC：0.983749
# 第35次执行：Gmean：0.96225，mAUC：0.992063
# 第36次执行：Gmean：0.942809，mAUC：0.998488
# 第37次执行：Gmean：0.952381，mAUC：0.996977
# 第38次执行：Gmean：0.96225，mAUC：0.998488
# 第39次执行：Gmean：0.942809，mAUC：0.996221
# 第40次执行：Gmean：0.952381，mAUC：0.996977
# Excel 文件已保存至: C:/Users/zsc/Desktop/BalancedRandomForest2/Ovarian/Ovarian.xlsx
# 集成分类结果（平均值）：[0.96160448 0.99691035]
# 集成分类结果（标准差）：[0.01552401 0.00355927]
# *****************算法执行结束！******************
# 数据已成功写入到 C:/Users/zsc/Desktop/BalancedRandomForest2/avg_results.xlsx
