# %%
import matplotlib.pyplot as plt
import numpy as np

# Set global font to Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['mathtext.fontset'] = 'stix'  # For mathematical symbols

# Data
y1 = [0.83378, 0.85539, 0.86606, 0.870891, 0.87417, 0.87886, 0.87955, 0.88023, 0.88023, 0.88023, 0.88023]
y2 = [0.87743, 0.8884, 0.88839, 0.88963, 0.89067, 0.89125, 0.8923, 0.8923, 0.8923, 0.8923, 0.8923]
x = np.arange(0, len(y1)*3,step=3)  # Runs from 0 to 10
y3 = [
    0.81028800, 0.83426850, 0.86041550, 0.87967550, 0.90932000, 
    0.93749300, 0.94395950, 0.95038350, 0.95607650, 0.95607650,0.95607650
]
y4 = [
    0.86973350, 0.89330050, 0.91533350, 0.93651300, 0.94769750,
    0.95371550, 0.95701250, 0.95916900, 0.95916900, 0.95916900, 0.95978100
]
y5 = [
    0.85069450, 0.90146300, 0.91995150, 0.93202600, 0.94475350,  0.94690050, 
    0.95099800, 0.95282900, 0.95515300, 0.95515300, 0.95515300
]
y6 = [
    0.92907200, 0.94595450, 0.95317100, 0.95993100, 0.96412650, 0.96856200,
    0.96958400, 0.96995350, 0.97045600, 0.97179300, 0.97179300
]
y7 = [
    0.91789400, 0.93698250, 0.94534450, 0.95356800, 0.96696200, 0.97470550,     
    0.97988050, 0.98668650, 0.98953450, 0.98953450, 0.98953450
]
y8 = [
    0.95905250, 0.97148700, 0.98119650, 0.98514850, 0.99328800, 0.99343850, 
    0.99357600, 0.99366900, 0.99366900, 0.99370850, 0.99370850
]

# Create figure with tight layout
fig, axes = plt.subplots(2,2,figsize=(10, 9),dpi=300)
axes = axes.flatten()  # 将2x2矩阵展平为1D数组
titles=['Wallrobot','Dermatology','Car','BalanceScale']
def plot_data(ax, y1, y2, title,set_xlim,set_ylim,set_yticks):
    # Set axis limits to start from 0 (with slight padding)
    ax.tick_params(axis='both', colors='black', width=1)
    ax.set_xlim(set_xlim[0], set_xlim[1])
    ax.set_ylim(set_ylim[0], set_ylim[1])
    # Configure grid (behind other elements, dashed lines)
    ax.grid(True, linestyle='--', alpha=0.6, which='both')
    ax.set_axisbelow(True)  # Grid behind data
    # Set ticks with consistent spacing
    ax.set_xticks([0,3,6,9,12,15,18,21,24,27,30])
    # ax.set_xticklabels(np.arange(0, len(y1)))  # Run numbers start at 1
    ax.set_yticks(np.arange(set_yticks[0], set_yticks[1], set_yticks[2]))
    # Plot lines with markers (starting at x=0)
    line1, = ax.plot(x, y1, 'o-', color='#1f77b4', markersize=5, linewidth=1.5, label='E-MOSAIC',zorder=100)
    line2, = ax.plot(x, y2, 'o-', color='#ff7f0e', markersize=5, linewidth=1.5, label='MILE',zorder=100)
    # Labels with Times New Roman (size 12)
    ax.set_xlabel('Generation', fontsize=14)
    ax.set_ylabel('G-mean', fontsize=14)
    ax.set_title(title, fontsize=16, fontweight='bold',pad=10)
    # Legend with Times New Roman (size 11)
    if title=='Wallrobot':
        ax.legend(fontsize=12, framealpha=1, loc='center',bbox_to_anchor=(0.70, 0.35))

plot_data(axes[0], y1, y2, titles[0],set_xlim=(-0.5, 30.5),set_ylim=(0.82, 0.90),set_yticks=(0.82, 0.90, 0.01))
plot_data(axes[1], y3, y4, titles[1],set_xlim=(-0.5, 30.5),set_ylim=(0.80, 0.97),set_yticks=(0.79, 0.98, 0.02))
plot_data(axes[2], y5, y6, titles[2],set_xlim=(-0.5, 30.5),set_ylim=(0.85, 0.97),set_yticks=(0.83, 0.99, 0.02))
plot_data(axes[3], y7, y8, titles[3],set_xlim=(-0.5, 30.5),set_ylim=(0.91, 1.00),set_yticks=(0.91, 1.01, 0.01))
# Adjust layout to prevent clipping
plt.tight_layout(pad=2.0, w_pad=1, h_pad=1)

# Save as high-resolution PNG (optional)
plt.savefig('WallRobot.pdf', 
            format='pdf', 
            dpi=300, 
            bbox_inches='tight', 
            pad_inches=0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set global font to Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['mathtext.fontset'] = 'stix'  # For mathematical symbols

# Data
y1 = [0.83378, 0.85539, 0.86606, 0.870891, 0.87417, 0.87886, 0.87955, 0.88023, 0.88023, 0.88023, 0.88023]
y2 = [0.87743, 0.8884, 0.88839, 0.88963, 0.89067, 0.89125, 0.8923, 0.8923, 0.8923, 0.8923, 0.8923]
x = np.arange(0, len(y1)*3,step=3)  # Runs from 0 to 10
y3 = [
    0.81028800, 0.83426850, 0.86041550, 0.87967550, 0.90932000, 
    0.93749300, 0.94395950, 0.95038350, 0.95607650, 0.95607650,0.95607650
]
y4 = [
    0.86973350, 0.89330050, 0.91533350, 0.93651300, 0.94769750,
    0.95371550, 0.95701250, 0.95916900, 0.95916900, 0.95916900, 0.95978100
]
y5 = [
    0.85069450, 0.90146300, 0.91995150, 0.93202600, 0.94475350,  0.94690050, 
    0.95099800, 0.95282900, 0.95515300, 0.95515300, 0.95515300
]
y6 = [
    0.92907200, 0.94595450, 0.95317100, 0.95993100, 0.96412650, 0.96856200,
    0.96958400, 0.96995350, 0.97045600, 0.97179300, 0.97179300
]
y7 = [
    0.91789400, 0.93698250, 0.94534450, 0.95356800, 0.96696200, 0.97470550,     
    0.97988050, 0.98668650, 0.98953450, 0.98953450, 0.98953450
]
y8 = [
    0.95905250, 0.97148700, 0.98119650, 0.98514850, 0.99328800, 0.99343850, 
    0.99357600, 0.99366900, 0.99366900, 0.99370850, 0.99370850
]

# Create figure with tight layout
fig, axes = plt.subplots(2,2,figsize=(14.4, 12.4),dpi=300)
axes = axes.flatten()  # 将2x2矩阵展平为1D数组
titles=['Wallrobot','Dermatology','Car','BalanceScale']
def plot_data(ax, y1, y2, title,set_xlim,set_ylim,set_yticks):
    
    # 绘制两条线
    x_ticks = list(range(0, 31, 3))
    y_ticks = np.arange(set_yticks[0], set_yticks[1], set_yticks[2])
    np.set_printoptions(formatter={'float': '{:.2f}'.format})
    ax.plot(x_ticks, y2,  linestyle='--', marker='o', markersize=7.5,label='MILE', color='#DA0000')
    ax.plot(x_ticks, y1, linestyle='--', marker='^',markersize=7.5, label='E-MOSAIC', color='#3590BD')
    
    # 设置x轴和y轴
    ax.set_xticks(x_ticks)
    ax.set_xticklabels(x_ticks, fontsize=20)
    ax.set_yticks(y_ticks)
    ax.set_yticklabels(np.round(y_ticks,2), fontsize=20)
    ax.grid(True, linestyle='--', alpha=0.6, which='both')
    ax.set_xlabel('Generation', fontsize=22)
    ax.set_ylabel('G-mean', fontsize=22)
    ax.set_title(title, fontsize=24, fontweight='bold',pad=10)
    # Legend with Times New Roman (size 11)
    if title=='Wallrobot':
        ax.legend(fontsize=22, framealpha=1, loc='center',bbox_to_anchor=(0.70, 0.35))

plot_data(axes[0], y1, y2, titles[0],set_xlim=(-0.5, 30.5),set_ylim=(0.82, 0.90),set_yticks=(0.82, 0.90, 0.01))
plot_data(axes[1], y3, y4, titles[1],set_xlim=(-0.5, 30.5),set_ylim=(0.80, 0.97),set_yticks=(0.79, 0.98, 0.02))
plot_data(axes[2], y5, y6, titles[2],set_xlim=(-0.5, 30.5),set_ylim=(0.85, 0.97),set_yticks=(0.83, 0.99, 0.02))
plot_data(axes[3], y7, y8, titles[3],set_xlim=(-0.5, 30.5),set_ylim=(0.91, 1.00),set_yticks=(0.91, 1.01, 0.01))
# Adjust layout to prevent clipping
plt.tight_layout(pad=2.0, w_pad=1.5, h_pad=1.5)

# Save as high-resolution PNG (optional)
plt.savefig('Convergence curve.pdf', 
            format='pdf', 
            dpi=300, 
            bbox_inches='tight', 
            pad_inches=0.1)
plt.show()
